# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 10367453469097820132
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 4986830848
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 5593088441266758605
# physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1660 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5"
# ]

# %%
from google_trans_new import google_translator

from googletrans import Translator
import pandas as pd
import json

from selenium import webdriver
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
from urllib.parse import quote_plus
from selenium.webdriver.common.keys import Keys
import time
import urllib.request
from urllib.request import urlretrieve
import pandas as pd
import time
from tqdm import tqdm
import os

# %%
final_df =  pd.read_csv('food_add3.csv', encoding='utf-8')
del final_df['Unnamed: 0']
final_df
# Out:
#                             식당명                              주소        lat  \
# 0                          서린낙지              서울특별시 종로구 종로1가 24   37.570959
# 1                         달인꽈배기             서울특별시 서대문구 영천동 69-3  37.571210
# 2                      라면 땡기는 날             서울특별시 종로구 화동 138-21  37.579283
# 3                         닭칼원조집              서울특별시 중구 중림동 110-3  37.560158
# 4                          호남식당           서울특별시 중구 충무로4가 127-16  37.562204
# 5                         장원북어국          서울특별시 영등포구 여의도동 226-36  37.521058
# 6                           중림장                서울특별시 중구 중림동 468  37.560234
# 7                         삼숙이라면             서울특별시 종로구 인사동 220-2  37.571564
# 8                        노량진수제비              서울특별시 동작구 노량진로 184  37.513095
# 9                           찬양집                서울특별시 종로구 돈의동 27  37.572787
# 10                      풍남원조골뱅이            서울특별시 중구 을지로3가 350-1  37.565643
# ...

# %%
matzip_df =  pd.read_csv('last_food.csv', encoding='cp949')
del matzip_df['Unnamed: 0']
matzip_df
# Out:
#                    식당명                 대표메뉴                              주소  \
# 0                 서린낙지                 낙지볶음              서울특별시 종로구 종로1가 24
# 1                달인꽈배기                  꽈배기             서울특별시 서대문구 영천동 69-3
# 2             라면 땡기는 날                 짬뽕라면             서울특별시 종로구 화동 138-21
# 3                닭칼원조집                 닭한마리              서울특별시 중구 중림동 110-3
# 4                 호남식당                  쫄갈비           서울특별시 중구 충무로4가 127-16
# 5                장원북어국                  북어국          서울특별시 영등포구 여의도동 226-36
# 6                  중림장                 도가니탕                서울특별시 중구 중림동 468
# 7                삼숙이라면                 파채라면             서울특별시 종로구 인사동 220-2
# 8           노량진 포차 수제비                멸치수제비              서울특별시 동작구 노량진로 184
# 9                  찬양집               바지락칼국수                서울특별시 종로구 돈의동 27
# 10             풍남원조골뱅이                  골뱅이            서울특별시 중구 을지로3가 350-1
# ...

# %%
sub_dict = {}
for i in range(len(matzip_df.index)):
    sub_dict[matzip_df['lat'][i]]=matzip_df['대표메뉴'][i]
    
sub_dict
# Out:
# {37.5709593: '낙지볶음',
#  37.5712096: '꽈배기',
#  37.5792833: '짬뽕라면',
#  37.5601579: '닭한마리',
#  37.5622044: '쫄갈비',
#  37.5210579: '북어국',
#  37.5602339: '도가니탕',
#  37.5715638: '파채라면',
#  37.5130951: '멸치수제비',
#  37.5727867: '바지락칼국수',
#  37.5656427: '골뱅이',
#  37.5199093: '오향장육 쇠고기군만두',
#  37.5625266: '칼국수',
#  37.5672361: '김치찌개',
#  37.5712095: '김치찌개',
#  37.5788633: '메밀',
#  37.5775347: '돈까스',
#  37.5708033: '순두부',
#  37.4960698: '수제버거',
#  37.5110533: '설렁탕',
#  37.5648739: '평양냉면',
#  37.5643209: '인도음식',
#  37.5726662: '청국장',
#  37.5643946: '곰탕',
#  37.5727966: '아구찜',
#  37.5785715: '김밥',
#  37.5580879: '육회비빔밥',
#  37.5787648: '파스타',
#  37.5431963: '베트남쌀국수 #반미',
#  37.5109726: '일본라면',
#  37.5639929: '돈가스',
#  37.5761724: '된장전골',
#  37.5730458: '맥주 안주',
#  37.573978: '바비큐',
#  37.5463549: '삼겹살',
#  37.5125144: '삼계탕',
#  37.5721087: '산낙지 철판볶음',
#  37.5809032: '빨콩떡볶이 #상추튀김',
#  37.5080312: '오모리찌개 #옛날 손짜장',
#  37.5729148: '모둠만두 #떡볶이',
#  37.5589755: '꼬리토막',
#  37.5716911: '해장국',
# ...

# %%
main_dict = {}
lat_list = list(final_df['lat'])
lat_list
# Out:
# [37.5709593,
#  37.5712096,
#  37.5792833,
#  37.5601579,
#  37.5622044,
#  37.5210579,
#  37.5602339,
#  37.5715638,
#  37.5130951,
#  37.5727867,
#  37.5656427,
#  37.5625266,
#  37.5672361,
#  37.5712095,
#  37.5788633,
#  37.5775347,
#  37.5708033,
#  37.4960698,
#  37.5110533,
#  37.5648739,
#  37.5643209,
#  37.5726662,
#  37.5643946,
#  37.5727966,
#  37.5785715,
#  37.5580879,
#  37.5787648,
#  37.5431963,
#  37.5109726,
#  37.5639929,
#  37.5761724,
#  37.5730458,
#  37.573978,
#  37.5463549,
#  37.5125144,
#  37.5721087,
#  37.5809032,
#  37.5080312,
#  37.5729148,
#  37.5589755,
#  37.5716911,
#  37.5620353,
#  37.5096878,
#  37.5099014,
#  37.5658431,
#  37.5582293,
#  37.5560558,
#  37.5685081,
#  37.514848,
#  37.5193776,
#  37.5691757,
#  37.5195933,
#  37.5194647,
#  37.5490343,
#  37.5727479,
#  37.5265765,
#  37.5770902,
#  37.5808101,
#  37.5704383,
#  37.5092786,
#  37.5430796,
#  37.5766177,
#  37.5697551,
#  37.5098232,
#  37.5175877,
#  37.5733535,
# ...

# %%
for key, value in sub_dict.items():
    if key in lat_list:
        main_dict[key]=sub_dict[key]
main_dict
# Out:
# {37.5709593: '낙지볶음',
#  37.5712096: '꽈배기',
#  37.5792833: '짬뽕라면',
#  37.5601579: '닭한마리',
#  37.5622044: '쫄갈비',
#  37.5210579: '북어국',
#  37.5602339: '도가니탕',
#  37.5715638: '파채라면',
#  37.5130951: '멸치수제비',
#  37.5727867: '바지락칼국수',
#  37.5656427: '골뱅이',
#  37.5625266: '칼국수',
#  37.5672361: '김치찌개',
#  37.5712095: '김치찌개',
#  37.5788633: '메밀',
#  37.5775347: '돈까스',
#  37.5708033: '순두부',
#  37.4960698: '수제버거',
#  37.5110533: '설렁탕',
#  37.5648739: '평양냉면',
#  37.5643209: '인도음식',
#  37.5726662: '청국장',
#  37.5643946: '곰탕',
#  37.5727966: '아구찜',
#  37.5785715: '김밥',
#  37.5580879: '육회비빔밥',
#  37.5787648: '파스타',
#  37.5431963: '베트남쌀국수 #반미',
#  37.5109726: '일본라면',
#  37.5639929: '돈가스',
#  37.5761724: '된장전골',
#  37.5730458: '맥주 안주',
#  37.573978: '바비큐',
#  37.5463549: '삼겹살',
#  37.5125144: '삼계탕',
#  37.5721087: '산낙지 철판볶음',
#  37.5809032: '빨콩떡볶이 #상추튀김',
#  37.5080312: '오모리찌개 #옛날 손짜장',
#  37.5729148: '모둠만두 #떡볶이',
#  37.5589755: '꼬리토막',
#  37.5716911: '해장국',
#  37.5620353: '평양냉면',
# ...

# %%
menu_list = []
for value in final_df['lat']:
    menu_list.append(main_dict[value])
menu_list
# Out:
# ['낙지볶음',
#  '꽈배기',
#  '짬뽕라면',
#  '닭한마리',
#  '쫄갈비',
#  '북어국',
#  '도가니탕',
#  '파채라면',
#  '멸치수제비',
#  '바지락칼국수',
#  '골뱅이',
#  '칼국수',
#  '김치찌개',
#  '김치찌개',
#  '메밀',
#  '돈까스',
#  '순두부',
#  '수제버거',
#  '설렁탕',
#  '평양냉면',
#  '인도음식',
#  '청국장',
#  '곰탕',
#  '아구찜',
#  '김밥',
#  '육회비빔밥',
#  '파스타',
#  '베트남쌀국수 #반미',
#  '일본라면',
#  '돈가스',
#  '된장전골',
#  '맥주 안주',
#  '바비큐',
#  '삼겹살',
#  '삼계탕',
#  '산낙지 철판볶음',
#  '빨콩떡볶이 #상추튀김',
#  '오모리찌개 #옛날 손짜장',
#  '모둠만두 #떡볶이',
#  '꼬리토막',
#  '해장국',
#  '평양냉면',
#  '사천요리',
#  '돼지막창구이',
#  '딤섬',
#  '삼겹살',
#  '왕돈가스',
#  '양장피',
#  '곱창',
#  '유럽식',
#  '디저트',
#  '일반중식',
#  '일식',
#  '모던한식',
#  '도가니탕',
#  '모던한식',
#  '유럽식',
#  '프랑스식',
#  '베이징덕# 딤섬# 광둥식요리# 중식',
#  '바비큐',
#  '스테이크',
#  '생크림 굴뚝빵',
#  '모듬해물',
#  '명란돈가쓰',
#  '떡볶이# 라면# 쫄면',
#  '마스카포네 치즈 오믈렛',
#  '갈릭랍스터',
#  '당근 초콜릿 빙수',
#  '샌드마키',
#  '비프 웰링턴',
#  '도동탕면# 도동비면',
#  '해산물 빠에야',
#  '로스티드 치킨',
#  '야끼니꾸 부위별',
#  '서양배 타르트',
#  '꽃게장# 꽃게찜',
#  '파전',
#  '전복 해물뚝배기',
#  '돼지고기',
#  '쫄볶이# 떡튀김',
#  '피자#치킨',
#  'bar# 칵테일# 샴페인',
# ...

# %%
final_df['대표메뉴']=menu_list
final_df
# Out:
#                             식당명                              주소        lat  \
# 0                          서린낙지              서울특별시 종로구 종로1가 24   37.570959
# 1                         달인꽈배기             서울특별시 서대문구 영천동 69-3  37.571210
# 2                      라면 땡기는 날             서울특별시 종로구 화동 138-21  37.579283
# 3                         닭칼원조집              서울특별시 중구 중림동 110-3  37.560158
# 4                          호남식당           서울특별시 중구 충무로4가 127-16  37.562204
# 5                         장원북어국          서울특별시 영등포구 여의도동 226-36  37.521058
# 6                           중림장                서울특별시 중구 중림동 468  37.560234
# 7                         삼숙이라면             서울특별시 종로구 인사동 220-2  37.571564
# 8                        노량진수제비              서울특별시 동작구 노량진로 184  37.513095
# 9                           찬양집                서울특별시 종로구 돈의동 27  37.572787
# 10                      풍남원조골뱅이            서울특별시 중구 을지로3가 350-1  37.565643
# ...

# %%
final_df = final_df[['식당명', '대표메뉴', '주소', 'lat','lng','영어식당명','영어대표메뉴','영어주소','사진이름','서비스 옵션','별점','영업시간','연락처']]
final_df
# Out:
#                             식당명                 대표메뉴  \
# 0                          서린낙지                 낙지볶음
# 1                         달인꽈배기                  꽈배기
# 2                      라면 땡기는 날                 짬뽕라면
# 3                         닭칼원조집                 닭한마리
# 4                          호남식당                  쫄갈비
# 5                         장원북어국                  북어국
# 6                           중림장                 도가니탕
# 7                         삼숙이라면                 파채라면
# 8                        노량진수제비                멸치수제비
# 9                           찬양집               바지락칼국수
# 10                      풍남원조골뱅이                  골뱅이
# 11                      명동교자 본점                  칼국수
# 12                          한옥집                 김치찌개
# 13                         광화문집                 김치찌개
# 14                       메밀꽃필무렵                   메밀
# 15                       긴자 바이린                  돈까스
# 16                           감촌                  순두부
# ...

# %%
final_df.to_csv("sub_food.csv", encoding='euc-kr')

# %%
hotel_df =  pd.read_csv('fix_hotel00.csv', encoding='utf-8')
del hotel_df['Unnamed: 0.1']
del hotel_df['Unnamed: 0']
del hotel_df['rating']
hotel_df
# Out:
#      id                                   name                       address  \
# 0     1                             JW메리어트호텔서울        서울특별시 서초구 반포동 신반포로 176
# 1     2                      메리어트 이그제큐티브 아파트먼트        서울특별시 영등포구 여의도동 여의대로 8
# 2     3                               비스타 W워커힐        서울특별시 광진구 광장동 워커힐로 177
# 3     4                            그랜드앰배서더호텔서울        서울특별시 중구 장충동2가 동호로 287
# 4     5                        그랜드인터컨티넨탈서울파르나스        서울특별시 강남구 삼성동 테헤란로 521
# 5     6                               그랜드하얏트서울             서울특별시 용산구 한남동 소월로
# 6     7                              그랜드힐튼호텔서울        서울특별시 서대문구 홍은동 연희로 353
# 7     8                              노보텔앰배서더강남       서울특별시 강남구 역삼1동 봉은사로 130
# 8     9                             롯데시티호텔김포공항         서울특별시 강서구 방화2동 하늘길 38
# 9    10                               롯데 호텔 서울         서울특별시 중구 을지로1가 을지로 30
# 10   11                               롯데 호텔 월드            서울특별시 송파구 잠실동 40-1
# ...

# %%
hotel_df.to_csv("sub_hotel.csv", encoding='euc-kr')

# %%
# 임의로 자료를 가져와본다.
onlyone_list = []
driver = webdriver.Chrome('chrome_driver/chromedriver.exe') # 여기에 크롬드라이브 다운로드 받은 경로를 입력한다.
driver.get("https://www.google.co.kr/webhp?hl=ko&sa=X&ved=0ahUKEwix65H_lrrzAhWEBN4KHS9jB-wQPAgI")
driver.implicitly_wait(3)
    
elem = driver.find_element_by_name("q")
elem.clear()
real_data =  '서울특별시 중구 명동 2가 31-7 할매낙지'
elem.send_keys(real_data)
elem.send_keys(Keys.RETURN)

try:
    first_value = driver.find_element_by_id("Shyhc")
    onlyone_list.append(first_value.text)

except:
    print('what the!!!')

# %%
address_list = list(matzip_df['주소'])

# %%
len(address_list)
# Out:
# 1911

# %%
closed_list = []

# %%
# 폐업한 맛집들을 가져와본다.
driver = webdriver.Chrome('chrome_driver/chromedriver.exe') # 여기에 크롬드라이브 다운로드 받은 경로를 입력한다.
driver.get("https://www.google.co.kr/webhp?hl=ko&sa=X&ved=0ahUKEwix65H_lrrzAhWEBN4KHS9jB-wQPAgI")
driver.implicitly_wait(3)
    
for i in tqdm(range(len(matzip_df.index))):   
    elem = driver.find_element_by_name("q")
    elem.clear()
    data =  matzip_df['주소'][i] + ' ' + matzip_df['식당명'][i]
    elem.send_keys(data)
    elem.send_keys(Keys.RETURN)

    try:
        first_value = driver.find_element_by_id("Shyhc")
        closed_list.append([matzip_df['주소'][i],first_value.text])

    except:
        pass

    time.sleep(1)
# Out:
#   4%|██▊                                                                           | 68/1911 [06:15<2:49:48,  5.53s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18908/2770366255.py in <module>
#      18         pass
#      19
# ---> 20     time.sleep(1)
#
# KeyboardInterrupt:

# %%
man_list = [['서울특별시 마포구 노고산동 31-74', '폐업'],
 ['서울특별시 종로구 서린동 129-1', '폐업'],
 ['서울특별시 용산구 한남동 683-122', '폐업'],
 ['서울특별시 동대문구 용두동 201-2', '폐업'],
 ['서울특별시 강남구 신사동 645-1', '폐업'],
 ['서울특별시 영등포구 여의도동 23-8', '폐업'],
 ['서울특별시 중구 산림동 84-1', '폐업'],
 ['서울특별시 강남구 논현동 95-4', '폐업'],
 ['서울특별시 용산구 이태원동 650', '폐업'],
 ['서울특별시 마포구 망원동 404-3', '폐업'],
 ['서울특별시 용산구 이태원동 34-16', '폐업'],
 ['서울특별시 마포구 상수동 317-9', '폐업'],
 ['서울특별시 강남구 삼성동 166-6', '폐업'],
 ['서울특별시 강남구 신사동 653-7', '폐업'],
 ['서울특별시 마포구 서교동 332-20', '폐업'],
 ['서울특별시 용산구 이태원동 648', '폐업'],
 ['서울특별시 마포구 망원동 385-39', '폐업'],
 ['서울특별시 송파구 방이동 180-3 2층', '폐업'],
 ['서울특별시 송파구 석촌동 2-1', '현재 위치에서 영업하지 않음'],
 ['서울특별시 동작구 동작대로17길 3 사당1동 1008-15', '폐업'],
 ['서울특별시 용산구 이태원로 136-1 이태원동 34-14 2층', '폐업'],
 ['서울특별시 용산구 녹사평대로54길 20 이태원2동 273-20', '폐업'],
 ['서울특별시 서대문구 연희로25길 92 연희동 90-12', '임시 휴업'],
 ['서울특별시 강남구 도산대로 318 논현동 92 SB타워 별관 C동 2층', '임시 휴업'],
 ['서울특별시특별시 용산구 소월로 268 이태원동 260-18', '폐업'],
 ['서울특별시 중구 을지로 4가 60 을지로 175-5', '폐업'],
 ['서울특별시 강남구 강남대로 628 신사동 502-1 신사빌딩 1층', '폐업'],
 ['서울특별시 마포구 성미산로 152 연남동 239-48', '현재 위치에서 영업하지 않음'],
 ['서울특별시 종로구 평창동 281-1', '폐업'],
 ['서울특별시 동대문구 용신동 767-6', '폐업'],
 ['서울특별시 성북구 길음동 1065', '폐업'],
 ['서울특별시 중구 명동 2가 31-7', '폐업'],
 ['서울특별시 종로구 인의동 112-14 세운스퀘어 401호', '폐업'],
 ['서울특별시 서대문구 대현동 56-33', '폐업'],
 ['서울특별시 강남구 대치동 987-7', '폐업'],
# ...

# %%
len(closed_list)
# Out:
# 1

# %%
one_closed_list = [x[0] for x in man_list]

# %%
new_matzip_df = matzip_df

# %%
value_list = []
for value in new_matzip_df['주소']:
    if value in one_closed_list:
        value_list.append('sibal')
    else:
        value_list.append(value)

# %%
value_list
# Out:
# ['서울특별시 성북구 성북동 109-2',
#  '서울특별시 성북구 성북동 114-2',
#  '서울특별시 종로구 종로3가 167',
#  '서울특별시 마포구 도화동 345-4',
#  '서울특별시 종로구 종로1가 24 르메이에르 종로타운 2층',
#  '서울특별시 용산구 한남동 743-7',
#  '서울특별시 서대문구 영천동 69-3',
#  '서울특별시 광진구 구의동 52-17',
#  '서울특별시 강서구 공항동 73-7',
#  '서울특별시 구로구 오류2동 135-68',
#  '서울특별시 종로구 화동 138-21',
#  '서울특별시 중구 중림동 110-3',
#  'sibal',
#  '서울특별시 종로구 청진동 204-1',
#  '서울특별시 중구 충무로4가 127-16',
#  '서울특별시 종로구 창신1동 142-27',
#  '서울특별시 중구 장충동1가 62-16',
#  '서울특별시 송파구 문정동 44',
#  '서울특별시 관악구 신림동 1640-31',
#  '서울특별시 중구 신당동 368-60',
#  '서울특별시 영등포구 당산동 295',
#  '서울특별시 동대문구 제기동 892-12',
#  '서울특별시 송파구 풍납동 405',
#  '서울특별시 성북구 보문동5가 3-3',
#  '서울특별시 마포구 서교동 358-49',
#  '서울특별시 영등포구 여의도동 226-36',
#  '서울특별시 마포구 망원동 476-1',
#  '서울특별시 중랑구 망우동 407-28',
#  '서울특별시 서대문구 충정로2가 124',
#  '서울특별시 관악구 봉천동 1626-20',
#  '서울특별시 종로구 종로5가 225-27',
#  '서울특별시 성북구 동소문동5가 63-3 돈암제일시장 내',
#  '서울특별시 종로구 혜화동 84-3',
#  '서울특별시 중구 중림동 468',
#  '서울특별시 강남구 논현동 275-3',
#  '서울특별시 노원구 중계4동 140-42',
#  '서울특별시 강북구 수유1동 54-1',
# ...

# %%
len([x for x in value_list if x=='sibal'])
# Out:
# 233

# %%
new_matzip_df['주소']=value_list

# %%
new_matzip_df[new_matzip_df['주소']!='sibal']
# Out:
#             식당명     대표메뉴                               주소
# 0       쌍다리돼지불백     돼지불백              서울특별시 성북구 성북동 109-2
# 1     성북동 돼지갈비집     돼지불백              서울특별시 성북구 성북동 114-2
# 2            계림     닭볶음탕               서울특별시 종로구 종로3가 167
# 3       마포원조떡볶이      떡볶이              서울특별시 마포구 도화동 345-4
# 4          서린낙지     낙지볶음  서울특별시 종로구 종로1가 24 르메이에르 종로타운 2층
# ...         ...      ...                              ...
# 1906       부원면옥     평양냉면              서울특별시 중구 남창동 47-10
# 1907        야마야    일본가정식              서울특별시 종로구 새문안로3길 12
# 1908      정원순두부      순두부              서울특별시 중구 세종대로11길 30
# 1909       원대구탕      대구탕             서울특별시 용산구 한강대로62가길 8
# 1910        목천집  매생이 칼국수              서울특별시 서초구 효령로52길 69
#
# [1678 rows x 3 columns]

# %%
matzip_df = new_matzip_df[new_matzip_df['주소']!='sibal']
matzip_df
# Out:
#             식당명     대표메뉴                               주소
# 0       쌍다리돼지불백     돼지불백              서울특별시 성북구 성북동 109-2
# 1     성북동 돼지갈비집     돼지불백              서울특별시 성북구 성북동 114-2
# 2            계림     닭볶음탕               서울특별시 종로구 종로3가 167
# 3       마포원조떡볶이      떡볶이              서울특별시 마포구 도화동 345-4
# 4          서린낙지     낙지볶음  서울특별시 종로구 종로1가 24 르메이에르 종로타운 2층
# ...         ...      ...                              ...
# 1906       부원면옥     평양냉면              서울특별시 중구 남창동 47-10
# 1907        야마야    일본가정식              서울특별시 종로구 새문안로3길 12
# 1908      정원순두부      순두부              서울특별시 중구 세종대로11길 30
# 1909       원대구탕      대구탕             서울특별시 용산구 한강대로62가길 8
# 1910        목천집  매생이 칼국수              서울특별시 서초구 효령로52길 69
#
# [1678 rows x 3 columns]

# %%
import googlemaps
import folium
import numpy as np
from haversine import haversine

# %%
gmaps_key = "AIzaSyBQj_mdpMJcgLdXQ9-4cuqDFgUd62KwisM"
gmaps = googlemaps.Client(key=gmaps_key)

# %%
matzip_df.index=list(range(len(matzip_df.index)))

# %%
lat_list=[]
lng_list=[]


for i in tqdm(range(len(matzip_df.index))):
    #print(name)
    data = matzip_df['주소'][i] + ' ' + matzip_df['식당명'][i]
    
    item = gmaps.geocode(data, language='ko')
    #print(item[0]['geometry']['location']['lat']) 
    try:
        lat_list.append(item[0]['geometry']['location']['lat'])

        #print(item[0]['geometry']['location']['lng'])
        lng_list.append(item[0]['geometry']['location']['lng'])
        
    except:
        lat_list.append('error!')
        lng_list.append('error!')
        print(data)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1678/1678 [13:17<00:00,  2.10it/s]

# %%
error_list1 = [x for x in lat_list if x=='error!']
error_list2 = [x for x in lng_list if x=='error!']

# %%
matzip_df['lat']=lat_list
matzip_df['lng']=lng_list
# Out:
# C:\Users\lemon\anaconda3\envs\project-env\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\lemon\anaconda3\envs\project-env\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
matzip_df.drop_duplicates(['lat'])
len(matzip_df)
# Out:
# 1678

# %%
matzip_df.drop_duplicates(['lng'])
len(matzip_df)
# Out:
# 1678

# %%
# food_df =  pd.read_csv('total_matzip.csv', encoding='utf-8')
# del food_df['Unnamed: 0']
# food_df
# Out:
#             식당명     대표메뉴                               주소
# 0       쌍다리돼지불백     돼지불백              서울특별시 성북구 성북동 109-2
# 1     성북동 돼지갈비집     돼지불백              서울특별시 성북구 성북동 114-2
# 2            계림     닭볶음탕               서울특별시 종로구 종로3가 167
# 3       마포원조떡볶이      떡볶이              서울특별시 마포구 도화동 345-4
# 4          서린낙지     낙지볶음  서울특별시 종로구 종로1가 24 르메이에르 종로타운 2층
# ...         ...      ...                              ...
# 1906       부원면옥     평양냉면              서울특별시 중구 남창동 47-10
# 1907        야마야    일본가정식              서울특별시 종로구 새문안로3길 12
# 1908      정원순두부      순두부              서울특별시 중구 세종대로11길 30
# 1909       원대구탕      대구탕             서울특별시 용산구 한강대로62가길 8
# 1910        목천집  매생이 칼국수              서울특별시 서초구 효령로52길 69
#
# [1911 rows x 3 columns]

# %%
# food_list = list(food_df['식당명'])
# address_list = list(food_df['주소'])

# %%
# food_list
# Out:
# ['쌍다리돼지불백',
#  '성북동 돼지갈비집',
#  '계림',
#  '마포원조떡볶이',
#  '서린낙지',
#  '바다식당',
#  '달인꽈배기',
#  '신토불이떡볶이',
#  '공항칼국수',
#  '한라산도새기',
#  '라면 땡기는 날',
#  '닭칼원조집',
#  '미스터 칠드런',
#  '남도식당',
#  '호남식당',
#  '옥천매운족발',
#  '평안도 족발집',
#  '골목떡볶이',
#  '전주익산집',
#  '머거보까매운불갈비찜',
#  '이조보쌈',
#  '감초식당',
#  '감미치킨',
#  '소담',
#  '혼가츠',
#  '장원북어국',
#  '일등식당',
#  '용마해장국',
#  '서대문외할머니라면',
#  '나인온스',
#  '호남집',
#  '돈암순대김밥',
#  '혜화 칼국수',
#  '중림장',
#  '가나기사식당',
#  '돈까스먹는 용만이',
#  '만두명가',
#  '효동각',
#  '연신네 불오징어',
#  '복정집',
#  '원조누드김밥',
#  '신계치',
#  '라면점빵',
#  '수목식당',
#  '삼숙이라면',
#  '낙산냉면',
#  '참나무 닭나라',
#  '영일분식',
#  '소문난성수감자탕',
#  '할매집',
#  '원할매 소문난 닭한마리',
#  '청파 쌍대포',
#  '중화원',
#  '우정',
#  '보들이족발',
#  '굴다리식당',
#  '매덕스피자',
#  '하하',
#  '엄마손만두',
#  '노량진 포차 수제비',
#  '순댕이네얼큰수제비',
#  '은성횟집',
#  '찬양집',
#  '피자아일랜드',
#  '왕타이',
#  '가마마루이',
#  '발리비스트로',
#  '홍은손칼국수전문점',
#  '윤씨밀방',
#  '수와래',
#  '한일식당',
#  '너도나도식당',
#  '허파식당',
#  '쿠이신보',
#  '망원양꼬치',
#  '고가네 원조숯불구이통닭',
#  '돈파스팔레',
#  '선다래',
#  '미정이네식당',
#  '장안정',
#  '아차산할아버지 순두부',
# ...

# %%
# first_list = [[x,y] for x,y in zip(food_list,address_list)]
# first_list
# Out:
# [['쌍다리돼지불백', '서울특별시 성북구 성북동 109-2'],
#  ['성북동 돼지갈비집', '서울특별시 성북구 성북동 114-2'],
#  ['계림', '서울특별시 종로구 종로3가 167'],
#  ['마포원조떡볶이', '서울특별시 마포구 도화동 345-4'],
#  ['서린낙지', '서울특별시 종로구 종로1가 24 르메이에르 종로타운 2층'],
#  ['바다식당', '서울특별시 용산구 한남동 743-7'],
#  ['달인꽈배기', '서울특별시 서대문구 영천동 69-3'],
#  ['신토불이떡볶이', '서울특별시 광진구 구의동 52-17'],
#  ['공항칼국수', '서울특별시 강서구 공항동 73-7'],
#  ['한라산도새기', '서울특별시 구로구 오류2동 135-68'],
#  ['라면 땡기는 날', '서울특별시 종로구 화동 138-21'],
#  ['닭칼원조집', '서울특별시 중구 중림동 110-3'],
#  ['미스터 칠드런', '서울특별시 영등포구 여의도동 44-14'],
#  ['남도식당', '서울특별시 종로구 청진동 204-1'],
#  ['호남식당', '서울특별시 중구 충무로4가 127-16'],
#  ['옥천매운족발', '서울특별시 종로구 창신1동 142-27'],
#  ['평안도 족발집', '서울특별시 중구 장충동1가 62-16'],
#  ['골목떡볶이', '서울특별시 송파구 문정동 44'],
#  ['전주익산집', '서울특별시 관악구 신림동 1640-31'],
#  ['머거보까매운불갈비찜', '서울특별시 중구 신당동 368-60'],
#  ['이조보쌈', '서울특별시 영등포구 당산동 295'],
#  ['감초식당', '서울특별시 동대문구 제기동 892-12'],
#  ['감미치킨', '서울특별시 송파구 풍납동 405'],
#  ['소담', '서울특별시 성북구 보문동5가 3-3'],
#  ['혼가츠', '서울특별시 마포구 서교동 358-49'],
#  ['장원북어국', '서울특별시 영등포구 여의도동 226-36'],
# ...

# %%
# new_address_list = list(matzip_df['주소'])
# final_address_list = [x for x in first_list if x[1] in new_address_list]
# len(final_address_list)
# Out:
# 1678

# %%
# final_address_list
# Out:
# [['쌍다리돼지불백', '서울특별시 성북구 성북동 109-2'],
#  ['성북동 돼지갈비집', '서울특별시 성북구 성북동 114-2'],
#  ['계림', '서울특별시 종로구 종로3가 167'],
#  ['마포원조떡볶이', '서울특별시 마포구 도화동 345-4'],
#  ['서린낙지', '서울특별시 종로구 종로1가 24 르메이에르 종로타운 2층'],
#  ['바다식당', '서울특별시 용산구 한남동 743-7'],
#  ['달인꽈배기', '서울특별시 서대문구 영천동 69-3'],
#  ['신토불이떡볶이', '서울특별시 광진구 구의동 52-17'],
#  ['공항칼국수', '서울특별시 강서구 공항동 73-7'],
#  ['한라산도새기', '서울특별시 구로구 오류2동 135-68'],
#  ['라면 땡기는 날', '서울특별시 종로구 화동 138-21'],
#  ['닭칼원조집', '서울특별시 중구 중림동 110-3'],
#  ['남도식당', '서울특별시 종로구 청진동 204-1'],
#  ['호남식당', '서울특별시 중구 충무로4가 127-16'],
#  ['옥천매운족발', '서울특별시 종로구 창신1동 142-27'],
#  ['평안도 족발집', '서울특별시 중구 장충동1가 62-16'],
#  ['골목떡볶이', '서울특별시 송파구 문정동 44'],
#  ['전주익산집', '서울특별시 관악구 신림동 1640-31'],
#  ['머거보까매운불갈비찜', '서울특별시 중구 신당동 368-60'],
#  ['이조보쌈', '서울특별시 영등포구 당산동 295'],
#  ['감초식당', '서울특별시 동대문구 제기동 892-12'],
#  ['감미치킨', '서울특별시 송파구 풍납동 405'],
#  ['소담', '서울특별시 성북구 보문동5가 3-3'],
#  ['혼가츠', '서울특별시 마포구 서교동 358-49'],
#  ['장원북어국', '서울특별시 영등포구 여의도동 226-36'],
#  ['일등식당', '서울특별시 마포구 망원동 476-1'],
# ...

# %%
# matzip_df['식당명']=[x[0] for x in final_address_list]
# Out:
# C:\Users\lemon\anaconda3\envs\project-env\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
matzip_df
# Out:
#             식당명     대표메뉴                               주소        lat  \
# 0       쌍다리돼지불백     돼지불백              서울특별시 성북구 성북동 109-2  37.593475
# 1     성북동 돼지갈비집     돼지불백              서울특별시 성북구 성북동 114-2  37.593248
# 2            계림     닭볶음탕               서울특별시 종로구 종로3가 167  37.570074
# 3       마포원조떡볶이      떡볶이              서울특별시 마포구 도화동 345-4  37.540280
# 4          서린낙지     낙지볶음  서울특별시 종로구 종로1가 24 르메이에르 종로타운 2층  37.570959
# ...         ...      ...                              ...        ...
# 1673       부원면옥     평양냉면              서울특별시 중구 남창동 47-10   37.558418
# 1674        야마야    일본가정식              서울특별시 종로구 새문안로3길 12  37.571431
# 1675      정원순두부      순두부              서울특별시 중구 세종대로11길 30  37.562062
# 1676       원대구탕      대구탕             서울특별시 용산구 한강대로62가길 8  37.534655
# 1677        목천집  매생이 칼국수              서울특별시 서초구 효령로52길 69  37.481324
#
#              lng
# 0     126.995669
# 1     126.996057
# 2     126.994532
# 3     126.948786
# 4     126.979876
# ...          ...
# ...

# %%
# matzip_df.to_csv('opened_matzip.csv')

# %%
landmark_dict={'경복궁': (37.579617, 126.977041),
 '명동성당': (37.563177, 126.9873604),
 '이순신 동상': (37.5710015, 126.9769419),
 '63빌딩': (37.5193776, 126.9402103),
 '탑골공원팔각정': (37.5711455, 126.9883295),
 '독립문': (37.5723906, 126.9596836),
 '남산타워': (37.5511694, 126.9882266),
 '롯데타워': (37.5133315, 127.1018965),
 '코엑스': (37.5101935, 127.0585824),
 '서대문 형무소': (37.574271, 126.956071),
 '구서울역': (37.5559897, 126.9715543)}

# %%
# 맛집 딕셔너리 
food_dict = {}

for i, name in enumerate(matzip_df['식당명']):
    
    food_dict[name] = (matzip_df['lat'][i], matzip_df['lng'][i])

# %%
food_dict
# Out:
# {'쌍다리돼지불백': (37.5934747, 126.9956687),
#  '성북동 돼지갈비집': (37.5932483, 126.9960567),
#  '계림': (37.5700741, 126.9945316),
#  '마포원조떡볶이': (37.5402803, 126.9487861),
#  '서린낙지': (37.5709593, 126.9798759),
#  '바다식당': (37.5368776, 127.0000977),
#  '달인꽈배기': (37.5712096, 126.9607313),
#  '신토불이떡볶이': (37.5525068, 127.090441),
#  '공항칼국수': (37.5609362, 126.8091609),
#  '한라산도새기': (37.4924866, 126.8424984),
#  '라면 땡기는 날': (37.5792833, 126.9822188),
#  '닭칼원조집': (37.5601579, 126.9678207),
#  '남도식당': (37.5722574, 126.9794123),
#  '호남식당': (37.5597847, 126.9769543),
#  '옥천매운족발': (37.5731318, 127.0115462),
#  '평안도 족발집': (37.5602232, 127.0060337),
#  '골목떡볶이': (37.4890197, 127.123457),
#  '전주익산집': (37.4832519, 126.9287583),
#  '머거보까매운불갈비찜': (37.5536645, 127.0106376),
#  '이조보쌈': (37.53492870000001, 126.9030775),
#  '감초식당': (37.5797318, 127.0362824),
#  '감미치킨': (37.5293268, 127.116351),
#  '소담': (37.5838134, 127.0196248),
#  '혼가츠': (37.5525965, 126.9220046),
#  '장원북어국': (37.5210579, 126.9297678),
# ...

# %%
final_list=[]
for key, value in landmark_dict.items():
    sub_list = []
    for second_key, second_value in food_dict.items():
        haversine_value =haversine(value, second_value, unit='km')
        sub_list.append([key,second_key,haversine_value])
    main_list = sorted(sub_list, key=lambda x: x[2])
    addition_list = main_list[:12]
    final_list.append(addition_list)

# %%
final_list
# Out:
# [[['경복궁', '메밀꽃필무렵', 0.30724311475556104],
#   ['경복궁', '더레스토랑', 0.32344846956030066],
#   ['경복궁', '긴자 바이린', 0.37998100856234235],
#   ['경복궁', '두가헌', 0.40082103426797994],
#   ['경복궁', '이태리재', 0.42358457055262344],
#   ['경복궁', '침니펍', 0.426021105328128],
#   ['경복궁', '보라', 0.4370575740362403],
#   ['경복궁', '라면 땡기는 날', 0.4577897368207016],
#   ['경복궁', '경춘자의 라면 땡기는 날', 0.4577897368207016],
#   ['경복궁', '조선김밥', 0.4687281428961669],
#   ['경복궁', '대복집', 0.47472377303846597],
#   ['경복궁', '대선칼국수', 0.4756328346976837]],
#  [['명동성당', '타지 본점', 0.16214593636403818],
#   ['명동성당', '타지', 0.16214593636403818],
#   ['명동성당', '명동교자 본점', 0.17047409878242054],
#   ['명동성당', '하동관', 0.2468591907585142],
#   ['명동성당', '바오차이', 0.3195770852513004],
#   ['명동성당', '코고', 0.3210252876159472],
#   ['명동성당', '평래옥', 0.3256539049834246],
#   ['명동성당', '명동돈가스', 0.3463364690926424],
#   ['명동성당', '풍남원조골뱅이', 0.3548380074532781],
#   ['명동성당', '전주 중앙회관', 0.3793703546064396],
#   ['명동성당', '전주중앙회관', 0.3793703546064396],
# ...

# %%
len(final_list)
# Out:
# 11

# %%
import itertools
final_matzip_list = list(itertools.chain.from_iterable(final_list))
final_matzip_list
# Out:
# [['경복궁', '메밀꽃필무렵', 0.30724311475556104],
#  ['경복궁', '더레스토랑', 0.32344846956030066],
#  ['경복궁', '긴자 바이린', 0.37998100856234235],
#  ['경복궁', '두가헌', 0.40082103426797994],
#  ['경복궁', '이태리재', 0.42358457055262344],
#  ['경복궁', '침니펍', 0.426021105328128],
#  ['경복궁', '보라', 0.4370575740362403],
#  ['경복궁', '라면 땡기는 날', 0.4577897368207016],
#  ['경복궁', '경춘자의 라면 땡기는 날', 0.4577897368207016],
#  ['경복궁', '조선김밥', 0.4687281428961669],
#  ['경복궁', '대복집', 0.47472377303846597],
#  ['경복궁', '대선칼국수', 0.4756328346976837],
#  ['명동성당', '타지 본점', 0.16214593636403818],
#  ['명동성당', '타지', 0.16214593636403818],
#  ['명동성당', '명동교자 본점', 0.17047409878242054],
#  ['명동성당', '하동관', 0.2468591907585142],
#  ['명동성당', '바오차이', 0.3195770852513004],
#  ['명동성당', '코고', 0.3210252876159472],
#  ['명동성당', '평래옥', 0.3256539049834246],
#  ['명동성당', '명동돈가스', 0.3463364690926424],
#  ['명동성당', '풍남원조골뱅이', 0.3548380074532781],
#  ['명동성당', '전주 중앙회관', 0.3793703546064396],
#  ['명동성당', '전주중앙회관', 0.3793703546064396],
#  ['명동성당', '혜민당', 0.3833039175950068],
# ...

# %%
copy_matzip_df = matzip_df

# %%
condition_list = [x[1] for x in final_matzip_list]

# %%
value_list = []
for value in copy_matzip_df['식당명']:
    if value not in condition_list:
        value_list.append('sibal')
    else:
        value_list.append(value)
value_list
# Out:
# ['sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  '서린낙지',
#  'sibal',
#  '달인꽈배기',
#  'sibal',
#  'sibal',
#  'sibal',
#  '라면 땡기는 날',
#  '닭칼원조집',
#  'sibal',
#  '호남식당',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  '장원북어국',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  '중림장',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  '삼숙이라면',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  '노량진 포차 수제비',
#  'sibal',
#  'sibal',
#  '찬양집',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  'sibal',
#  '풍남원조골뱅이',
# ...

# %%
len(condition_list)
# Out:
# 132

# %%
copy_matzip_df['식당명']=value_list
# Out:
# C:\Users\lemon\anaconda3\envs\project-env\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
pd.set_option('display.max_row', 200)

# %%
copy_matzip_df[copy_matzip_df['식당명']!='sibal']
# Out:
#            식당명  대표메뉴                               주소        lat         lng
# 4         서린낙지  낙지볶음  서울특별시 종로구 종로1가 24 르메이에르 종로타운 2층  37.570959  126.979876
# 6        달인꽈배기   꽈배기              서울특별시 서대문구 영천동 69-3  37.571210  126.960731
# 10    라면 땡기는 날  짬뽕라면              서울특별시 종로구 화동 138-21  37.579283  126.982219
# 11       닭칼원조집  닭한마리               서울특별시 중구 중림동 110-3  37.560158  126.967821
# 13        호남식당   쫄갈비            서울특별시 중구 충무로4가 127-16  37.562204  126.995645
# ...        ...   ...                              ...        ...         ...
# 1643        쿠마     회            서울특별시 영등포구 여의대방로69길 7  37.519790  126.931198
# 1645       골목집    수육                서울특별시 종로구 당주동 168  37.571006  126.974553
# 1660       한육감  한우구이                서울특별시 종로구 종로3길 17  37.570910  126.978894
# 1673      부원면옥  평양냉면              서울특별시 중구 남창동 47-10   37.558418  126.977587
# 1675     정원순두부   순두부              서울특별시 중구 세종대로11길 30  37.562062  126.974181
#
# [157 rows x 5 columns]

# %%
matzip_df = copy_matzip_df[copy_matzip_df['식당명']!='sibal']
matzip_df
# Out:
#            식당명  대표메뉴                               주소        lat         lng
# 4         서린낙지  낙지볶음  서울특별시 종로구 종로1가 24 르메이에르 종로타운 2층  37.570959  126.979876
# 6        달인꽈배기   꽈배기              서울특별시 서대문구 영천동 69-3  37.571210  126.960731
# 10    라면 땡기는 날  짬뽕라면              서울특별시 종로구 화동 138-21  37.579283  126.982219
# 11       닭칼원조집  닭한마리               서울특별시 중구 중림동 110-3  37.560158  126.967821
# 13        호남식당   쫄갈비            서울특별시 중구 충무로4가 127-16  37.562204  126.995645
# ...        ...   ...                              ...        ...         ...
# 1643        쿠마     회            서울특별시 영등포구 여의대방로69길 7  37.519790  126.931198
# 1645       골목집    수육                서울특별시 종로구 당주동 168  37.571006  126.974553
# 1660       한육감  한우구이                서울특별시 종로구 종로3길 17  37.570910  126.978894
# 1673      부원면옥  평양냉면              서울특별시 중구 남창동 47-10   37.558418  126.977587
# 1675     정원순두부   순두부              서울특별시 중구 세종대로11길 30  37.562062  126.974181
#
# [157 rows x 5 columns]

# %%
len(matzip_df.index)
# Out:
# 157

# %%
matzip_df
# Out:
#            식당명  대표메뉴                               주소        lat         lng
# 4         서린낙지  낙지볶음  서울특별시 종로구 종로1가 24 르메이에르 종로타운 2층  37.570959  126.979876
# 6        달인꽈배기   꽈배기              서울특별시 서대문구 영천동 69-3  37.571210  126.960731
# 10    라면 땡기는 날  짬뽕라면              서울특별시 종로구 화동 138-21  37.579283  126.982219
# 11       닭칼원조집  닭한마리               서울특별시 중구 중림동 110-3  37.560158  126.967821
# 13        호남식당   쫄갈비            서울특별시 중구 충무로4가 127-16  37.562204  126.995645
# ...        ...   ...                              ...        ...         ...
# 1643        쿠마     회            서울특별시 영등포구 여의대방로69길 7  37.519790  126.931198
# 1645       골목집    수육                서울특별시 종로구 당주동 168  37.571006  126.974553
# 1660       한육감  한우구이                서울특별시 종로구 종로3길 17  37.570910  126.978894
# 1673      부원면옥  평양냉면              서울특별시 중구 남창동 47-10   37.558418  126.977587
# 1675     정원순두부   순두부              서울특별시 중구 세종대로11길 30  37.562062  126.974181
#
# [157 rows x 5 columns]

# %%
matzip_df=matzip_df.drop_duplicates(['lng'])
len(matzip_df)
# Out:
# 117

# %%
matzip_df.index=list(range(len(matzip_df)))

# %%
matzip_df
# Out:
#           식당명  대표메뉴                               주소        lat         lng
# 0        서린낙지  낙지볶음  서울특별시 종로구 종로1가 24 르메이에르 종로타운 2층  37.570959  126.979876
# 1       달인꽈배기   꽈배기              서울특별시 서대문구 영천동 69-3  37.571210  126.960731
# 2    라면 땡기는 날  짬뽕라면              서울특별시 종로구 화동 138-21  37.579283  126.982219
# 3       닭칼원조집  닭한마리               서울특별시 중구 중림동 110-3  37.560158  126.967821
# 4        호남식당   쫄갈비            서울특별시 중구 충무로4가 127-16  37.562204  126.995645
# ..        ...   ...                              ...        ...         ...
# 112     마농트로포   디저트              서울특별시 용산구 한남동 32-22  37.576774  126.968958
# 113        쿠마     회            서울특별시 영등포구 여의대방로69길 7  37.519790  126.931198
# 114       골목집    수육                서울특별시 종로구 당주동 168  37.571006  126.974553
# 115      부원면옥  평양냉면              서울특별시 중구 남창동 47-10   37.558418  126.977587
# 116     정원순두부   순두부              서울특별시 중구 세종대로11길 30  37.562062  126.974181
#
# [117 rows x 5 columns]

# %%
closed_list=[]

# %%
# 마지막 최종 점검
driver = webdriver.Chrome('chrome_driver/chromedriver.exe') # 여기에 크롬드라이브 다운로드 받은 경로를 입력한다.
driver.get("https://www.google.co.kr/webhp?hl=ko&sa=X&ved=0ahUKEwix65H_lrrzAhWEBN4KHS9jB-wQPAgI")
driver.implicitly_wait(3)
    
for i in tqdm(range(len(matzip_df.index))):   
    elem = driver.find_element_by_name("q")
    elem.clear()
    data =  matzip_df['주소'][i] + ' ' + matzip_df['식당명'][i]
    elem.send_keys(data)
    elem.send_keys(Keys.RETURN)

    try:
        first_value = driver.find_element_by_id("Shyhc")
        closed_list.append([matzip_df['주소'][i],first_value.text])
        print('sibal')

    except:
        pass

    time.sleep(1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 117/117 [10:38<00:00,  5.45s/it]

# %%
final_df = matzip_df

# %%
# 번역기로 돌린 결과값을 하나씩 가져온다.
english_list = []
driver = webdriver.Chrome('chrome_driver/chromedriver.exe') # 여기에 크롬드라이브 다운로드 받은 경로를 입력한다.
driver.get("https://papago.naver.com/")
driver.implicitly_wait(3)

for data in tqdm(final_df['식당명']):
    elem = driver.find_element_by_id("txtSource")
    elem.clear()
    elem.send_keys(data)
    
    time.sleep(3)
    
    result = driver.find_element_by_id("txtTarget")
    english_list.append(result.text)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 117/117 [06:02<00:00,  3.09s/it]

# %%
english_list
# Out:
# ['Sore octopus.',
#  'Master twisted bread stick.',
#  'The day I crave ramen.',
#  'Original chicken knife restaurant.',
#  'Honam Restaurant.',
#  'Jangwon dried pollack soup.',
#  'Jungnimjang.',
#  "If it's Samsuk...",
#  'Noryangjin Pocha Sujebi.',
#  'Praise book.',
#  'Pungnam Wonjo Golbaengnam Original Marrow.',
#  'West Palace.',
#  'Myeongdong Gyoja Main Store.',
#  'Hanok house.',
#  'Gwanghwamun house.',
#  'Buckwheat flowers.',
#  'Ginza By Lynn.',
#  'Gamchon.',
#  'Brooklyn The Burger Joint.',
#  'Oegojip seolleongtang (Seolleongtang.',
#  'Pyeongraeok.',
#  'The main branch in other cities.',
#  'Japanese restaurant.',
#  'Hadonggwan.',
#  'Braised Spicy Seafood in Masan.',
#  'Cheongjinok.',
#  'Joseon kimbap.',
#  'Mokmyeoksanbang.',
#  'Italianjae.',
#  'Rehoi.',
#  'Menya Hanabi.',
#  'Myeongdong pork cutlet.',
#  'Daebokjip.',
#  'Craft Roo.',
#  "About Jin's",
#  'Charcoal from Sarangbang.',
#  'Gobong Samgyetang.',
#  'Jongnojin Octopus.',
# ...

# %%
english_list[7]='Samsuk ramen'

# %%
final_df['영어식당명']=english_list
final_df
# Out:
#           식당명  대표메뉴                               주소        lat         lng  \
# 0        서린낙지  낙지볶음  서울특별시 종로구 종로1가 24 르메이에르 종로타운 2층  37.570959  126.979876
# 1       달인꽈배기   꽈배기              서울특별시 서대문구 영천동 69-3  37.571210  126.960731
# 2    라면 땡기는 날  짬뽕라면              서울특별시 종로구 화동 138-21  37.579283  126.982219
# 3       닭칼원조집  닭한마리               서울특별시 중구 중림동 110-3  37.560158  126.967821
# 4        호남식당   쫄갈비            서울특별시 중구 충무로4가 127-16  37.562204  126.995645
# ..        ...   ...                              ...        ...         ...
# 112     마농트로포   디저트              서울특별시 용산구 한남동 32-22  37.576774  126.968958
# 113        쿠마     회            서울특별시 영등포구 여의대방로69길 7  37.519790  126.931198
# 114       골목집    수육                서울특별시 종로구 당주동 168  37.571006  126.974553
# 115      부원면옥  평양냉면              서울특별시 중구 남창동 47-10   37.558418  126.977587
# 116     정원순두부   순두부              서울특별시 중구 세종대로11길 30  37.562062  126.974181
#
#                                   영어식당명
# ...

# %%
# 번역기로 돌린 결과값을 하나씩 가져온다.
english_list = []
driver = webdriver.Chrome('chrome_driver/chromedriver.exe') # 여기에 크롬드라이브 다운로드 받은 경로를 입력한다.
driver.get("https://papago.naver.com/")
driver.implicitly_wait(3)

for data in tqdm(final_df['대표메뉴']):
    elem = driver.find_element_by_id("txtSource")
    elem.clear()
    elem.send_keys(data)
    
    time.sleep(3)
    
    result = driver.find_element_by_id("txtTarget")
    english_list.append(result.text)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 117/117 [06:03<00:00,  3.11s/it]

# %%
english_list
# Out:
# ['Stir-fried octopus.',
#  'Twisted bread stick.',
#  'Spicy Seafood Noodles.',
#  'One chicken.',
#  'Jjolgalbi.',
#  'Dried pollack soup.',
#  'Dog knee soup.',
#  "If it's seasoned green onion,",
#  'Anchovy Sujebi.',
#  'Kalguksu with clams.',
#  'whelk',
#  'Ohyang Jangyuk, beef fried dumpling.',
#  'Kalguksu',
#  'Kimchi stew',
#  'Kimchi stew',
#  'Buckwheat',
#  'Pork cutlet',
#  'soft tofu',
#  'Handmade burger.',
#  'Seolleongtang',
#  'Pyongyang naengmyeon.',
#  'Indian food.',
#  'Cheonggukjang',
#  'Beef-bone soup',
#  'Steamed monkfish.',
#  'Ox blood hangover soup.',
#  'rice roll',
#  'Raw beef mixed with rice',
#  'Pasta',
#  'Vietnamese rice noodles #Banh Mi.',
#  'Japanese ramen.',
#  'Pork Cutlet',
#  'Soybean paste hot pot.',
#  'A snack for beer.',
#  'Barbecue.',
#  'Pork belly',
#  'Samgyetang',
#  'Stir-fried raw octopus.',
#  'Brooklyn Works.',
#  'Red bean tteokbokki #Fried lettuce.',
#  'Omori stew #Old-fashioned black bean noodles.',
# ...

# %%
english_list[7]='seasoned green onion ramen'

# %%
final_df['영어대표메뉴']=english_list
final_df
# Out:
#           식당명  대표메뉴                               주소        lat         lng  \
# 0        서린낙지  낙지볶음  서울특별시 종로구 종로1가 24 르메이에르 종로타운 2층  37.570959  126.979876
# 1       달인꽈배기   꽈배기              서울특별시 서대문구 영천동 69-3  37.571210  126.960731
# 2    라면 땡기는 날  짬뽕라면              서울특별시 종로구 화동 138-21  37.579283  126.982219
# 3       닭칼원조집  닭한마리               서울특별시 중구 중림동 110-3  37.560158  126.967821
# 4        호남식당   쫄갈비            서울특별시 중구 충무로4가 127-16  37.562204  126.995645
# ..        ...   ...                              ...        ...         ...
# 112     마농트로포   디저트              서울특별시 용산구 한남동 32-22  37.576774  126.968958
# 113        쿠마     회            서울특별시 영등포구 여의대방로69길 7  37.519790  126.931198
# 114       골목집    수육                서울특별시 종로구 당주동 168  37.571006  126.974553
# 115      부원면옥  평양냉면              서울특별시 중구 남창동 47-10   37.558418  126.977587
# 116     정원순두부   순두부              서울특별시 중구 세종대로11길 30  37.562062  126.974181
#
# ...

# %%
final_df.to_csv('file.csv',encoding='euc-kr')

# %%
final_df = pd.read_csv('file.csv',encoding='cp949')
del final_df['Unnamed: 0']
final_df
# Out:
#           식당명  대표메뉴                     주소        lat         lng  \
# 0        서린낙지  낙지볶음     서울특별시 종로구 종로1가 24   37.570959  126.979876
# 1       달인꽈배기   꽈배기    서울특별시 서대문구 영천동 69-3  37.571210  126.960731
# 2    라면 땡기는 날  짬뽕라면    서울특별시 종로구 화동 138-21  37.579283  126.982219
# 3       닭칼원조집  닭한마리     서울특별시 중구 중림동 110-3  37.560158  126.967821
# 4        호남식당   쫄갈비  서울특별시 중구 충무로4가 127-16  37.562204  126.995645
# ..        ...   ...                    ...        ...         ...
# 112     마농트로포   디저트    서울특별시 용산구 한남동 32-22  37.576774  126.968958
# 113        쿠마     회  서울특별시 영등포구 여의대방로69길 7  37.519790  126.931198
# 114       골목집    수육      서울특별시 종로구 당주동 168  37.571006  126.974553
# 115      부원면옥  평양냉면    서울특별시 중구 남창동 47-10   37.558419  126.977587
# 116     정원순두부   순두부    서울특별시 중구 세종대로11길 30  37.562062  126.974181
#
#                                   영어식당명                  영어대표메뉴
# 0                         Sore octopus.     Stir-fried octopus.
# ...

# %%
# 번역기로 돌린 결과값을 하나씩 가져온다.
english_list = []
driver = webdriver.Chrome('chrome_driver/chromedriver.exe') # 여기에 크롬드라이브 다운로드 받은 경로를 입력한다.
driver.get("https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&query=%EC%98%81%EB%AC%B8%EC%A3%BC%EC%86%8C&oquery\
=Pork+cutlet&tqi=hSxaYlprvTossAgQ2k0ssssstDV-171026")
driver.implicitly_wait(3)

for data in tqdm(final_df['주소']):
    
    try:       
        elem = driver.find_element_by_id("search_addreng")
        elem.clear()
        elem.send_keys(data)
        elem.send_keys(Keys.RETURN)

        time.sleep(3)

        result = driver.find_element_by_class_name("detail")
        english_list.append(result.text)
        
    except:
        english_list.append('error!!!\nerror!!!\nerror!!!\nerror!!!')
        print(data, "니가 직접 찾아라")
        
        new_element = driver.find_element_by_id("nx_query")
        new_element.clear()
        new_element.send_keys('영어주소')
        new_element.send_keys(Keys.RETURN)
# Out:
#   4%|███▌                                                                              | 5/117 [00:19<07:05,  3.80s/it]
# 서울특별시 영등포구 여의도동 226-36 니가 직접 찾아라
#  15%|███████████▊                                                                     | 17/117 [01:07<06:15,  3.76s/it]
# 서울특별시 종로구 청진동 166 니가 직접 찾아라
#  42%|█████████████████████████████████▉                                               | 49/117 [03:13<04:17,  3.79s/it]
# 서울특별시 중구 을지로 2가 148-28 니가 직접 찾아라
#  54%|███████████████████████████████████████████▌                                     | 63/117 [04:09<03:19,  3.70s/it]
# 서울특별시 종로구 사간동 109 니가 직접 찾아라
#  64%|███████████████████████████████████████████████████▉                             | 75/117 [04:58<02:38,  3.78s/it]
# 서울특별시 용산구 두텁바위로 후암동 43-14 니가 직접 찾아라
#  84%|███████████████████████████████████████████████████████████████████▊             | 98/117 [06:30<01:12,  3.81s/it]
# 서울특별시 종로구 당주동29 니가 직접 찾아라
# ...

# %%
english_list
# Out:
# ['주소 우편번호\n서울특별시 종로구 종로 19 (종로1가, 르메이에르종로타운1)\n19, Jong-ro, Jongno-gu, Seoul, Republic of Korea\n03157',
#  '주소 우편번호\n서울특별시 서대문구 영천시장길 4 (영천동)\n4, Yeongcheonsijang-gil, Seodaemun-gu, Seoul, Republic of Korea\n03734',
#  '주소 우편번호\n서울특별시 종로구 율곡로3길 82 (화동)\n82, Yulgok-ro 3-gil, Jongno-gu, Seoul, Republic of Korea\n03061',
#  '주소 우편번호\n서울특별시 중구 중림동 110-3\n110-3, Jungnim-dong, Jung-gu, Seoul, Republic of Korea\n100-858',
#  '주소 우편번호\n서울특별시 중구 퇴계로41길 9 (충무로4가)\n9, Toegye-ro 41-gil, Jung-gu, Seoul, Republic of Korea\n04557',
#  'error!!!\nerror!!!\nerror!!!\nerror!!!',
#  '주소 우편번호\n서울특별시 중구 청파로 459-1 (중림동)\n459-1, Cheongpa-ro, Jung-gu, Seoul, Republic of Korea\n04505',
#  '주소 우편번호\n서울특별시 종로구 종로11길 30 (인사동)\n30, Jong-ro 11-gil, Jongno-gu, Seoul, Republic of Korea\n03164\n서울특별시 종로구 종로11길 29 (인사동)\n29, Jong-ro 11-gil, Jongno-gu, Seoul, Republic of Korea\n03164\n서울특별시 종로구 종로11길 30-1 (인사동)\n30-1, Jong-ro 11-gil, Jongno-gu, Seoul, Republic of Korea\n03164',
# ...

# %%
arrray_list = list(map(lambda x: x.split('\n'),english_list))

# %%
result_list = [x[2] for x in arrray_list]

# %%
result_list
# Out:
# ['19, Jong-ro, Jongno-gu, Seoul, Republic of Korea',
#  '4, Yeongcheonsijang-gil, Seodaemun-gu, Seoul, Republic of Korea',
#  '82, Yulgok-ro 3-gil, Jongno-gu, Seoul, Republic of Korea',
#  '110-3, Jungnim-dong, Jung-gu, Seoul, Republic of Korea',
#  '9, Toegye-ro 41-gil, Jung-gu, Seoul, Republic of Korea',
#  'error!!!',
#  '459-1, Cheongpa-ro, Jung-gu, Seoul, Republic of Korea',
#  '30, Jong-ro 11-gil, Jongno-gu, Seoul, Republic of Korea',
#  '184, Noryangjin-ro, Dongjak-gu, Seoul, Republic of Korea',
#  '5, Donhwamun-ro 11da-gil, Jongno-gu, Seoul, Republic of Korea',
#  '50-1, Supyo-ro, Jung-gu, Seoul, Republic of Korea',
#  '78, Gukjegeumyung-ro, Yeongdeungpo-gu, Seoul, Republic of Korea',
#  '29, Myeongdong 10-gil, Jung-gu, Seoul, Republic of Korea',
#  '14, Tongil-ro 9an-gil, Seodaemun-gu, Seoul, Republic of Korea',
#  '12, Saemunan-ro 5-gil, Jongno-gu, Seoul, Republic of Korea',
#  '31-1, Hyoja-ro, Jongno-gu, Seoul, Republic of Korea',
# ...

# %%
result_list[5]= '226-36, Yeouido-dong, Yeongdeungpo-gu, Seoul, Republic of Korea'
result_list[17]= '166 Cheongjin-dong, Jongno-gu, Seoul, Republic of Korea'
result_list[49]= '148-28, Euljiro 2-ga, Jung-gu, Seoul, Republic of Korea'
result_list[63]= '109, Sagan-dong, Jongno-gu, Seoul, Republic of Korea'
result_list[75]= '43-14 Huam-dong, Duibawi-ro, Yongsan-gu, Seoul, Republic of Korea.'
result_list[98]=  '29, Dangju-dong, Jongno-gu, Seoul, Republic of Korea.'
result_list[109]= '249, Cheongjin-dong, Jongno-gu, Seoul, Republic of Korea'

# %%
final_df['영어주소']=result_list
final_df
# Out:
#           식당명  대표메뉴                     주소        lat         lng  \
# 0        서린낙지  낙지볶음     서울특별시 종로구 종로1가 24   37.570959  126.979876
# 1       달인꽈배기   꽈배기    서울특별시 서대문구 영천동 69-3  37.571210  126.960731
# 2    라면 땡기는 날  짬뽕라면    서울특별시 종로구 화동 138-21  37.579283  126.982219
# 3       닭칼원조집  닭한마리     서울특별시 중구 중림동 110-3  37.560158  126.967821
# 4        호남식당   쫄갈비  서울특별시 중구 충무로4가 127-16  37.562204  126.995645
# ..        ...   ...                    ...        ...         ...
# 112     마농트로포   디저트    서울특별시 용산구 한남동 32-22  37.576774  126.968958
# 113        쿠마     회  서울특별시 영등포구 여의대방로69길 7  37.519790  126.931198
# 114       골목집    수육      서울특별시 종로구 당주동 168  37.571006  126.974553
# 115      부원면옥  평양냉면    서울특별시 중구 남창동 47-10   37.558419  126.977587
# 116     정원순두부   순두부    서울특별시 중구 세종대로11길 30  37.562062  126.974181
#
#                                   영어식당명                  영어대표메뉴  \
# 0                         Sore octopus.     Stir-fried octopus.
# ...

# %%
menu_list = list(final_df['대표메뉴'])
englis_menu_list = list(final_df['영어대표메뉴'])
revision_list = list(map(lambda x: x.replace(',','#'),menu_list))
english_revision_list = list(map(lambda x: x.replace(',','#'),englis_menu_list))
final_df['대표메뉴']=revision_list
final_df['영어대표메뉴']=english_revision_list
final_df
# Out:
#           식당명  대표메뉴                     주소        lat         lng  \
# 0        서린낙지  낙지볶음     서울특별시 종로구 종로1가 24   37.570959  126.979876
# 1       달인꽈배기   꽈배기    서울특별시 서대문구 영천동 69-3  37.571210  126.960731
# 2    라면 땡기는 날  짬뽕라면    서울특별시 종로구 화동 138-21  37.579283  126.982219
# 3       닭칼원조집  닭한마리     서울특별시 중구 중림동 110-3  37.560158  126.967821
# 4        호남식당   쫄갈비  서울특별시 중구 충무로4가 127-16  37.562204  126.995645
# ..        ...   ...                    ...        ...         ...
# 112     마농트로포   디저트    서울특별시 용산구 한남동 32-22  37.576774  126.968958
# 113        쿠마     회  서울특별시 영등포구 여의대방로69길 7  37.519790  126.931198
# 114       골목집    수육      서울특별시 종로구 당주동 168  37.571006  126.974553
# 115      부원면옥  평양냉면    서울특별시 중구 남창동 47-10   37.558419  126.977587
# 116     정원순두부   순두부    서울특별시 중구 세종대로11길 30  37.562062  126.974181
#
#                                   영어식당명                  영어대표메뉴  \
# 0                         Sore octopus.     Stir-fried octopus.
# ...

# %%
file_list = []
for i in range(len(final_df.index)):
    file_name = "matzip" + str(i+1)
    file_list.append(file_name)
final_df['picture_name']=file_list
final_df
# Out:
#           식당명  대표메뉴                     주소        lat         lng  \
# 0        서린낙지  낙지볶음     서울특별시 종로구 종로1가 24   37.570959  126.979876
# 1       달인꽈배기   꽈배기    서울특별시 서대문구 영천동 69-3  37.571210  126.960731
# 2    라면 땡기는 날  짬뽕라면    서울특별시 종로구 화동 138-21  37.579283  126.982219
# 3       닭칼원조집  닭한마리     서울특별시 중구 중림동 110-3  37.560158  126.967821
# 4        호남식당   쫄갈비  서울특별시 중구 충무로4가 127-16  37.562204  126.995645
# ..        ...   ...                    ...        ...         ...
# 112     마농트로포   디저트    서울특별시 용산구 한남동 32-22  37.576774  126.968958
# 113        쿠마     회  서울특별시 영등포구 여의대방로69길 7  37.519790  126.931198
# 114       골목집    수육      서울특별시 종로구 당주동 168  37.571006  126.974553
# 115      부원면옥  평양냉면    서울특별시 중구 남창동 47-10   37.558419  126.977587
# 116     정원순두부   순두부    서울특별시 중구 세종대로11길 30  37.562062  126.974181
#
#                                   영어식당명                  영어대표메뉴  \
# 0                         Sore octopus.     Stir-fried octopus.
# ...

# %%
final_df.to_csv('file.csv',encoding='euc-kr')

# %%
jinsu_matzip =  pd.read_csv('last_food.csv', encoding='cp949')
del jinsu_matzip['Unnamed: 0']
jinsu_matzip
# Out:
#                 식당명  대표메뉴                     주소        lat         lng  \
# 0              서린낙지  낙지볶음     서울특별시 종로구 종로1가 24   37.570959  126.979876
# 1             달인꽈배기   꽈배기    서울특별시 서대문구 영천동 69-3  37.571210  126.960731
# 2          라면 땡기는 날  짬뽕라면    서울특별시 종로구 화동 138-21  37.579283  126.982219
# 3             닭칼원조집  닭한마리     서울특별시 중구 중림동 110-3  37.560158  126.967821
# 4              호남식당   쫄갈비  서울특별시 중구 충무로4가 127-16  37.562204  126.995645
# ..              ...   ...                    ...        ...         ...
# 106  철판남 by 대한의 건아들  철판구이    서울특별시 종로구 자하문로1길 53  37.576909  126.969488
# 107           마농트로포   디저트    서울특별시 용산구 한남동 32-22  37.576774  126.968958
# 108              쿠마     회  서울특별시 영등포구 여의대방로69길 7  37.519790  126.931198
# 109            부원면옥  평양냉면    서울특별시 중구 남창동 47-10   37.558419  126.977587
# 110           정원순두부   순두부    서울특별시 중구 세종대로11길 30  37.562062  126.974181
#
#                                   영어식당명                  영어대표메뉴  \
# ...

# %%
jinsu_matzip =  pd.read_csv('last_food.csv', encoding='cp949')
del jinsu_matzip['Unnamed: 0']
jinsu_matzip
