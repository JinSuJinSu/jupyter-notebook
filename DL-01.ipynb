# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# - y = 1 / ( 1 + e<sup>-x</sup>)

# %%
def sigmoid_function(x):
    return 1/(1+np.exp(-x))
x = np.linspace(-5,5)
y = sigmoid_function(x)

plt.plot(x,y)
plt.show()

# %% [markdown]
# - y<sup>'</sup> = ( 1-y ) * y

# %% [markdown]
# ### tanh
# y = (e<sup>x</sup> - e<sup>-x</sup>) / (e<sup>x</sup> + e<sup>-x</sup>)

# %%
def tanh_function(x):
    return np.tanh(x)

x = np.linspace(-5,5)
y = tanh_function(x)

plt.plot(x,y)
plt.show()

# %% [markdown]
# ### ReLU(Rectified Linear Unit)
# y = if x <= 0 then 0 else x

# %%
def relu_function(x):
    return np.where(x<=0, 0, x)

x = np.linspace(-5,5)
y = relu_function(x)

plt.plot(x,y)
plt.show()

# %% [markdown]
# ### Leaky ReLU
# - y = if x <= 0 then 0.01x else x
# - x가 음수인 영역에서 아주 작은 기울기를 생성
# - 출력이 0이 되어 더 이상 학습이 진행되지 않는 뉴런이 발생하는 dying ReLU현상을 피하기 위해 사용

# %%
def leaky_relu_function(x):
    return np.where(x<=0, 0.01*x, x)

x = np.linspace(-5,5)
y = leaky_relu_function(x)

plt.plot(x,y)
plt.show()

# %% [markdown]
# ### Softmax
# - 입력받은 값을 출력으로 0~1사이의 값으로 모두 정규화
# - 출력 값들의 총합은 항상 1

# %%
def softmax_function(x):
    return np.exp(x) / np.sum(np.exp(x))

y = softmax_function(np.array([1,2,3]))
print(y)
# Out:
# [0.09003057 0.24472847 0.66524096]

# %% [markdown]
# ### 단일 신경망 구축
# - 딥러닝에서 가중치(w)와 bias(b) 는 임의의 수로 설정 후 학습하는 과정에서 갱신함
# - 지금은 가중치와 bias를 고정하고, 이 값들이 실제 신경망출력에 어떤 의미를 가지는지 확인함
# - 입력으로 단 두개의 값(feature) x<sub>1</sub>, x<sub>2</sub>
# - 활성화 함수로 시그모이드 함수 사용

# %%
x1=np.arange(-1.0,1.0,0.2)
x2=np.arange(-1.0,1.0,0.2)
Z = np.zeros((10,10))

w_x1 = 2.5
w_x2 = 3.0

bias=0.1

# %%
np.exp(-0.1)
# Out:
# 0.9048374180359595

# %%
1/1.9
# Out:
# 0.5263157894736842

# %%
for i in range(10):
    for j in range(10):
        u = (x1[i]*w_x1 + x2[j]*w_x2)  + bias
        y = 1/(1+ np.exp(-u))
        Z[i][j] = y
        
plt.imshow(Z, 'gray',  vmin=0.0, vmax=1.0)
plt.colorbar()
plt.show()

# %%
x1=np.arange(-1.0,1.0,0.2)
x2=np.arange(-1.0,1.0,0.2)
Z = np.zeros((10,10))

W=np.array([2.5,3.0])

bias=np.array([0.1])

# %%
for i in range(10):
    for j in range(10):
        list1 = [x1[i],x2[j]]
        X=np.array(list1)
        u = np.dot(X,W.T) + bias
        y = 1/(1+ np.exp(-u))
        Z[i][j] = y
        
plt.imshow(Z, 'gray',  vmin=0.0, vmax=1.0)
plt.colorbar()
plt.show()

# %%
x1=np.arange(-1.0,1.0,0.2)
x2=np.arange(-1.0,1.0,0.2)
Z = np.zeros((10,10))

W=np.array([-2.5,-3.0])

bias=np.array([0.1])

# %%
for i in range(10):
    for j in range(10):
        list1 = [x1[i],x2[j]]
        X=np.array(list1)
        u = np.dot(X,W.T) + bias
        y = 1/(1+ np.exp(-u))
        Z[i][j] = y
        
plt.imshow(Z, 'gray',  vmin=0.0, vmax=1.0)
plt.colorbar()
plt.show()

# %%
x1=np.arange(-1.0,1.0,0.2)
x2=np.arange(-1.0,1.0,0.2)
Z = np.zeros((10,10))

W=np.array([0.0,3.0])

bias=np.array([0.1])


for i in range(10):
    for j in range(10):
        list1 = [x1[i],x2[j]]
        X=np.array(list1)
        u = np.dot(X,W.T) + bias
        y = 1/(1+ np.exp(-u))
        Z[i][j] = y
        
plt.imshow(Z, 'gray',  vmin=0.0, vmax=1.0)
plt.colorbar()
plt.show()

# %%
x1=np.arange(-1.0,1.0,0.2)
x2=np.arange(-1.0,1.0,0.2)
Z = np.zeros((10,10))

W=np.array([2.5,0.0])

bias=np.array([0.1])


for i in range(10):
    for j in range(10):
        list1 = [x1[i],x2[j]]
        X=np.array(list1)
        u = np.dot(X,W.T) + bias
        y = 1/(1+ np.exp(-u))
        Z[i][j] = y
        
plt.imshow(Z, 'gray',  vmin=0.0, vmax=1.0)
plt.colorbar()
plt.show()

# %%
x1=np.arange(-1.0,1.0,0.2)
x2=np.arange(-1.0,1.0,0.2)
Z = np.zeros((10,10))

W=np.array([2.5,3.0])

bias=np.array([-2.0])


for i in range(10):
    for j in range(10):
        list1 = [x1[i],x2[j]]
        X=np.array(list1)
        u = np.dot(X,W.T) + bias
        y = 1/(1+ np.exp(-u))
        Z[i][j] = y
        
plt.imshow(Z, 'gray',  vmin=0.0, vmax=1.0)
plt.colorbar()
plt.show()

# %%
x1=np.arange(-1.0,1.0,0.2)
x2=np.arange(-1.0,1.0,0.2)
Z = np.zeros((10,10))

W=np.array([2.5,3.0])

bias=np.array([2.0])


for i in range(10):
    for j in range(10):
        list1 = [x1[i],x2[j]]
        X=np.array(list1)
        u = np.dot(X,W.T) + bias
        y = 1/(1+ np.exp(-u))
        Z[i][j] = y
        
plt.imshow(Z, 'gray',  vmin=0.0, vmax=1.0)
plt.colorbar()
plt.show()

# %% [markdown]
# - Input Layer 입력 2개, Hidden Layer 노드 2개, Output Layer 노드 1개
# - Hidden Layer 활성화함수 시그모이드
# - Output Layer 활성화함수 항등함수

# %%
X = np.arange(-1.0,1.0,0.2)
Y = np.arange(-1.0,1.0,0.2)
Z = np.zeros((10,10))

w_im = np.array([[4.0,4.0],[4.0,4.0]])
w_mo = np.array([[1.0],[-1.0]])

b_im = np.array([3.0,-3.0])
b_mo = np.array([0.1])

def middle_layer(x, w, b):
    u = np.dot(x,w)+b
    return 1 / (1 + np.exp(-u))

def output_layer(x, w, b):
    u = np.dot(x,w)+b
    return u

for i in range(10):
    for j in range(10):
        np_input = np.array([X[i],Y[j]])
        np_middle = middle_layer(np_input, w_im, b_im)
        np_output = output_layer(np_middle, w_mo, b_mo)
        
        Z[i][j] = np_output[0]
        
plt.imshow(Z, 'gray',  vmin=0.0, vmax=1.0)
plt.colorbar()
plt.show()

# %%
w_im = np.array([[-5.0,-5.0],[5.0,-5.0]])
w_mo = np.array([[1.0],[-1.0]])
b_im = np.array([0.0,0.0])
b_mo = np.array([0.0])

# %%
for i in range(10):
    for j in range(10):
        np_input = np.array([X[i],Y[j]])
        np_middle = middle_layer(np_input, w_im, b_im)
        np_output = output_layer(np_middle, w_mo, b_mo)
        
        Z[i][j] = np_output[0]
        
plt.imshow(Z, 'gray',  vmin=0.0, vmax=1.0)
plt.colorbar()
plt.show()

# %%
w_im = np.array([[4.0, 4.0],[4.0,4.0]])
w_mo = np.array([[-1.0], [1.0]])
b_im = np.array([3.0,-3.0])
b_mo = np.array([1.0])

# %%
for i in range(10):
    for j in range(10):
        np_input = np.array([X[i],Y[j]])
        np_middle = middle_layer(np_input, w_im, b_im)
        np_output = output_layer(np_middle, w_mo, b_mo)
        
        Z[i][j] = np_output[0]
        
plt.imshow(Z, 'gray',  vmin=0.0, vmax=1.0)
plt.colorbar()
plt.show()

# %%
w_im = np.array([[-4.0, 4.0], [-4.0,-4.0]])
w_mo = np.array([[1.0], [-1.0]])
b_im = np.array([3.0,-3.0])
b_mo = np.array([0.0])

# %%
for i in range(10):
    for j in range(10):
        np_input = np.array([X[i],Y[j]])
        np_middle = middle_layer(np_input, w_im, b_im)
        np_output = output_layer(np_middle, w_mo, b_mo)
        
        Z[i][j] = np_output[0]
        
plt.imshow(Z, 'gray',  vmin=0.0, vmax=1.0)
plt.colorbar()
plt.show()

# %%
X = np.arange(-1.0,1.0,0.1)
Y = np.arange(-1.0,1.0,0.1)

w_im = np.array([[1.0, 2.0], [2.0,3.0]])
w_mo = np.array([[-1.0,1.0], [1.0,-1.0]])
b_im = np.array([0.3,-0.3])
b_mo = np.array([0.4,0.1])

def middle_layer(x, w, b):
    u = np.dot(x,w)+b
    return 1 / (1 + np.exp(-u)) #시그모이드


def output_layer(x, w, b):
    u = np.dot(x,w)+b
    return np.exp(u) / np.sum(np.exp(u)) # 소프트 맥스

x_1 = []
y_1 = []
x_2 = []
y_2 = []


for i in range(20):
    for j in range(20):
        np_input = np.array([X[i],Y[j]])
        np_middle = middle_layer(np_input, w_im, b_im)
        np_output = output_layer(np_middle, w_mo, b_mo)
        print(np_output[0],np_output[1])
        
        if np_output[0] > np_output[1]:
            x_1.append(X[i])
            y_1.append(Y[j])
        else:
            x_2.append(X[i])
            y_2.append(Y[j])
            
        
plt.scatter(x_1, y_1, marker='+')
plt.scatter(x_2, y_2, marker='o')
plt.show()
# Out:
# 0.584243513693373 0.4157564863066269
# 0.5917367705083549 0.408263229491645
# 0.5968523291454775 0.4031476708545225
# 0.5998005412231229 0.4001994587768771
# 0.6009510882174349 0.399048911782565
# 0.6007282937067259 0.39927170629327413
# 0.5995391554642812 0.4004608445357189
# 0.5977337919043033 0.40226620809569663
# 0.5955905141453779 0.40440948585462205
# 0.5933164825050584 0.4066835174949417
# 0.591056523544904 0.4089434764550961
# 0.5111981296043036 0.48880187039569656
# 0.5135624336692786 0.4864375663307215
# 0.5188601262609113 0.4811398737390886
# 0.5270623726973402 0.47293762730265965
# 0.5377070132817032 0.4622929867182968
# 0.5499161727846699 0.4500838272153301
# 0.5625480578601724 0.4374519421398277
# 0.5744425168116589 0.42555748318834113
# 0.5846641337880476 0.41533586621195234
# 0.5926502826906354 0.4073497173093647
# 0.5982309314988833 0.40176906850111666
# 0.601550588539826 0.398449411460174
# 0.602949408710376 0.39705059128962406
# 0.6028505675084697 0.39714943249153034
# 0.6016773857121065 0.3983226142878936
# 0.5998041737401212 0.4001958262598789
# 0.5975345891286428 0.40246541087135723
# 0.5950984381030988 0.40490156189690113
# 0.5926588120301604 0.40734118796983954
# 0.5903236971282504 0.40967630287174955

# %%
X = np.arange(-1.0,1.0,0.1)
Y = np.arange(-1.0,1.0,0.1)

w_im = np.array([[2.0,1.0],[0.0,3.0]])
w_mo = np.array([[-2.0,1.0],[-1.0,-1.0]])
b_im = np.array([-0.3,-0.3])
b_mo = np.array([0.4,-1.2])

def middle_layer(x, w, b):
    u = np.dot(x,w)+b
    return 1 / (1 + np.exp(-u)) #시그모이드


def output_layer(x, w, b):
    u = np.dot(x,w)+b
    return np.exp(u) / np.sum(np.exp(u)) # 소프트 맥스

x_1 = []
y_1 = []
x_2 = []
y_2 = []


for i in range(20):
    for j in range(20):
        np_input = np.array([X[i],Y[j]])
        np_middle = middle_layer(np_input, w_im, b_im)
        np_output = output_layer(np_middle, w_mo, b_mo)
        print(np_output)
        
        if np_output[0] > np_output[1]:
            x_1.append(X[i])
            y_1.append(Y[j])
        else:
            x_2.append(X[i])
            y_2.append(Y[j])
            
        
plt.scatter(x_1, y_1, marker='+')
plt.scatter(x_2, y_2, marker='o')
plt.show()
# Out:
# [0.79028284 0.20971716]
# [0.79028284 0.20971716]
# [0.79028284 0.20971716]
# [0.79028284 0.20971716]
# [0.79028284 0.20971716]
# [0.79028284 0.20971716]
# [0.79028284 0.20971716]
# [0.79028284 0.20971716]
# [0.79028284 0.20971716]
# [0.79028284 0.20971716]
# [0.79028284 0.20971716]
# [0.79028284 0.20971716]
# [0.79028284 0.20971716]
# [0.79028284 0.20971716]
# [0.79028284 0.20971716]
# [0.79028284 0.20971716]
# [0.79028284 0.20971716]
# [0.79028284 0.20971716]
# [0.79028284 0.20971716]
# [0.79028284 0.20971716]
# [0.78120622 0.21879378]
# [0.78120622 0.21879378]
# [0.78120622 0.21879378]
# [0.78120622 0.21879378]
# [0.78120622 0.21879378]
# [0.78120622 0.21879378]
# [0.78120622 0.21879378]
# [0.78120622 0.21879378]
# [0.78120622 0.21879378]
# [0.78120622 0.21879378]
# [0.78120622 0.21879378]
# [0.78120622 0.21879378]
# [0.78120622 0.21879378]
# [0.78120622 0.21879378]
# [0.78120622 0.21879378]
# [0.78120622 0.21879378]
# [0.78120622 0.21879378]
# [0.78120622 0.21879378]
# [0.78120622 0.21879378]
# [0.78120622 0.21879378]
# [0.77024136 0.22975864]
# [0.77024136 0.22975864]
# [0.77024136 0.22975864]
# [0.77024136 0.22975864]
# [0.77024136 0.22975864]
# [0.77024136 0.22975864]
# [0.77024136 0.22975864]
# [0.77024136 0.22975864]
# [0.77024136 0.22975864]
# [0.77024136 0.22975864]
# [0.77024136 0.22975864]
# [0.77024136 0.22975864]
# [0.77024136 0.22975864]
# [0.77024136 0.22975864]
# [0.77024136 0.22975864]
# [0.77024136 0.22975864]
# [0.77024136 0.22975864]
# [0.77024136 0.22975864]
# [0.77024136 0.22975864]
# [0.77024136 0.22975864]
# [0.75705562 0.24294438]
# [0.75705562 0.24294438]
# [0.75705562 0.24294438]
# [0.75705562 0.24294438]
# [0.75705562 0.24294438]
# [0.75705562 0.24294438]
# [0.75705562 0.24294438]
# [0.75705562 0.24294438]
# [0.75705562 0.24294438]
# [0.75705562 0.24294438]
# [0.75705562 0.24294438]
# [0.75705562 0.24294438]
# [0.75705562 0.24294438]
# [0.75705562 0.24294438]
# [0.75705562 0.24294438]
# [0.75705562 0.24294438]
# [0.75705562 0.24294438]
# [0.75705562 0.24294438]
# [0.75705562 0.24294438]
# [0.75705562 0.24294438]
# [0.74129753 0.25870247]
# [0.74129753 0.25870247]
# [0.74129753 0.25870247]
# [0.74129753 0.25870247]
# [0.74129753 0.25870247]
# [0.74129753 0.25870247]
# [0.74129753 0.25870247]
# [0.74129753 0.25870247]
# [0.74129753 0.25870247]
# [0.74129753 0.25870247]
# [0.74129753 0.25870247]
# [0.74129753 0.25870247]
# [0.74129753 0.25870247]
# [0.74129753 0.25870247]
# [0.74129753 0.25870247]
# [0.74129753 0.25870247]
# [0.74129753 0.25870247]
# [0.74129753 0.25870247]
# [0.74129753 0.25870247]
# [0.74129753 0.25870247]
# [0.72262198 0.27737802]
# [0.72262198 0.27737802]
# [0.72262198 0.27737802]
# [0.72262198 0.27737802]
# [0.72262198 0.27737802]
# [0.72262198 0.27737802]
# [0.72262198 0.27737802]
# [0.72262198 0.27737802]
# [0.72262198 0.27737802]
# [0.72262198 0.27737802]
# [0.72262198 0.27737802]
# [0.72262198 0.27737802]
# [0.72262198 0.27737802]
# [0.72262198 0.27737802]
# [0.72262198 0.27737802]
# [0.72262198 0.27737802]
# [0.72262198 0.27737802]
# [0.72262198 0.27737802]
# [0.72262198 0.27737802]
# [0.72262198 0.27737802]
# [0.70073081 0.29926919]
# [0.70073081 0.29926919]
# [0.70073081 0.29926919]
# [0.70073081 0.29926919]
# [0.70073081 0.29926919]
# [0.70073081 0.29926919]
# [0.70073081 0.29926919]
# [0.70073081 0.29926919]
# [0.70073081 0.29926919]
# [0.70073081 0.29926919]
# [0.70073081 0.29926919]
# [0.70073081 0.29926919]
# [0.70073081 0.29926919]
# [0.70073081 0.29926919]
# [0.70073081 0.29926919]
# [0.70073081 0.29926919]
# [0.70073081 0.29926919]
# [0.70073081 0.29926919]
# [0.70073081 0.29926919]
# [0.70073081 0.29926919]
# [0.67543005 0.32456995]
# [0.67543005 0.32456995]
# [0.67543005 0.32456995]
# [0.67543005 0.32456995]
# [0.67543005 0.32456995]
# [0.67543005 0.32456995]
# [0.67543005 0.32456995]
# [0.67543005 0.32456995]
# [0.67543005 0.32456995]
# [0.67543005 0.32456995]
# [0.67543005 0.32456995]
# [0.67543005 0.32456995]
# [0.67543005 0.32456995]
# [0.67543005 0.32456995]
# [0.67543005 0.32456995]
# [0.67543005 0.32456995]
# [0.67543005 0.32456995]
# [0.67543005 0.32456995]
# [0.67543005 0.32456995]
# [0.67543005 0.32456995]
# [0.64669963 0.35330037]
# [0.64669963 0.35330037]
# [0.64669963 0.35330037]
# [0.64669963 0.35330037]
# [0.64669963 0.35330037]
# [0.64669963 0.35330037]
# [0.64669963 0.35330037]
# [0.64669963 0.35330037]
# [0.64669963 0.35330037]
# [0.64669963 0.35330037]
# [0.64669963 0.35330037]
# [0.64669963 0.35330037]
# [0.64669963 0.35330037]
# [0.64669963 0.35330037]
# [0.64669963 0.35330037]
# [0.64669963 0.35330037]
# [0.64669963 0.35330037]
# [0.64669963 0.35330037]
# [0.64669963 0.35330037]
# [0.64669963 0.35330037]
# [0.61476298 0.38523702]
# [0.61476298 0.38523702]
# [0.61476298 0.38523702]
# [0.61476298 0.38523702]
# [0.61476298 0.38523702]
# [0.61476298 0.38523702]
# [0.61476298 0.38523702]
# [0.61476298 0.38523702]
# [0.61476298 0.38523702]
# [0.61476298 0.38523702]
# [0.61476298 0.38523702]
# [0.61476298 0.38523702]
# [0.61476298 0.38523702]
# [0.61476298 0.38523702]
# [0.61476298 0.38523702]
# [0.61476298 0.38523702]
# [0.61476298 0.38523702]
# [0.61476298 0.38523702]
# [0.61476298 0.38523702]
# [0.61476298 0.38523702]
# [0.58013499 0.41986501]
# [0.58013499 0.41986501]
# [0.58013499 0.41986501]
# [0.58013499 0.41986501]
# [0.58013499 0.41986501]
# [0.58013499 0.41986501]
# [0.58013499 0.41986501]
# [0.58013499 0.41986501]
# [0.58013499 0.41986501]
# [0.58013499 0.41986501]
# [0.58013499 0.41986501]
# [0.58013499 0.41986501]
# [0.58013499 0.41986501]
# [0.58013499 0.41986501]
# [0.58013499 0.41986501]
# [0.58013499 0.41986501]
# [0.58013499 0.41986501]
# [0.58013499 0.41986501]
# [0.58013499 0.41986501]
# [0.58013499 0.41986501]
# [0.5436232 0.4563768]
# [0.5436232 0.4563768]
# [0.5436232 0.4563768]
# [0.5436232 0.4563768]
# [0.5436232 0.4563768]
# [0.5436232 0.4563768]
# [0.5436232 0.4563768]
# [0.5436232 0.4563768]
# [0.5436232 0.4563768]
# [0.5436232 0.4563768]
# [0.5436232 0.4563768]
# [0.5436232 0.4563768]
# [0.5436232 0.4563768]
# [0.5436232 0.4563768]
# [0.5436232 0.4563768]
# [0.5436232 0.4563768]
# [0.5436232 0.4563768]
# [0.5436232 0.4563768]
# [0.5436232 0.4563768]
# [0.5436232 0.4563768]
# [0.50626528 0.49373472]
# [0.50626528 0.49373472]
# [0.50626528 0.49373472]
# [0.50626528 0.49373472]
# [0.50626528 0.49373472]
# [0.50626528 0.49373472]
# [0.50626528 0.49373472]
# [0.50626528 0.49373472]
# [0.50626528 0.49373472]
# [0.50626528 0.49373472]
# [0.50626528 0.49373472]
# [0.50626528 0.49373472]
# [0.50626528 0.49373472]
# [0.50626528 0.49373472]
# [0.50626528 0.49373472]
# [0.50626528 0.49373472]
# [0.50626528 0.49373472]
# [0.50626528 0.49373472]
# [0.50626528 0.49373472]
# [0.50626528 0.49373472]
# [0.46920713 0.53079287]
# [0.46920713 0.53079287]
# [0.46920713 0.53079287]
# [0.46920713 0.53079287]
# [0.46920713 0.53079287]
# [0.46920713 0.53079287]
# [0.46920713 0.53079287]
# [0.46920713 0.53079287]
# [0.46920713 0.53079287]
# [0.46920713 0.53079287]
# [0.46920713 0.53079287]
# [0.46920713 0.53079287]
# [0.46920713 0.53079287]
# [0.46920713 0.53079287]
# [0.46920713 0.53079287]
# [0.46920713 0.53079287]
# [0.46920713 0.53079287]
# [0.46920713 0.53079287]
# [0.46920713 0.53079287]
# [0.46920713 0.53079287]
# [0.43355091 0.56644909]
# [0.43355091 0.56644909]
# [0.43355091 0.56644909]
# [0.43355091 0.56644909]
# [0.43355091 0.56644909]
# [0.43355091 0.56644909]
# [0.43355091 0.56644909]
# [0.43355091 0.56644909]
# [0.43355091 0.56644909]
# [0.43355091 0.56644909]
# [0.43355091 0.56644909]
# [0.43355091 0.56644909]
# [0.43355091 0.56644909]
# [0.43355091 0.56644909]
# [0.43355091 0.56644909]
# [0.43355091 0.56644909]
# [0.43355091 0.56644909]
# [0.43355091 0.56644909]
# [0.43355091 0.56644909]
# [0.43355091 0.56644909]
# [0.40021645 0.59978355]
# [0.40021645 0.59978355]
# [0.40021645 0.59978355]
# [0.40021645 0.59978355]
# [0.40021645 0.59978355]
# [0.40021645 0.59978355]
# [0.40021645 0.59978355]
# [0.40021645 0.59978355]
# [0.40021645 0.59978355]
# [0.40021645 0.59978355]
# [0.40021645 0.59978355]
# [0.40021645 0.59978355]
# [0.40021645 0.59978355]
# [0.40021645 0.59978355]
# [0.40021645 0.59978355]
# [0.40021645 0.59978355]
# [0.40021645 0.59978355]
# [0.40021645 0.59978355]
# [0.40021645 0.59978355]
# [0.40021645 0.59978355]
# [0.36985276 0.63014724]
# [0.36985276 0.63014724]
# [0.36985276 0.63014724]
# [0.36985276 0.63014724]
# [0.36985276 0.63014724]
# [0.36985276 0.63014724]
# [0.36985276 0.63014724]
# [0.36985276 0.63014724]
# [0.36985276 0.63014724]
# [0.36985276 0.63014724]
# [0.36985276 0.63014724]
# [0.36985276 0.63014724]
# [0.36985276 0.63014724]
# [0.36985276 0.63014724]
# [0.36985276 0.63014724]
# [0.36985276 0.63014724]
# [0.36985276 0.63014724]
# [0.36985276 0.63014724]
# [0.36985276 0.63014724]
# [0.36985276 0.63014724]
# [0.34281372 0.65718628]
# [0.34281372 0.65718628]
# [0.34281372 0.65718628]
# [0.34281372 0.65718628]
# [0.34281372 0.65718628]
# [0.34281372 0.65718628]
# [0.34281372 0.65718628]
# [0.34281372 0.65718628]
# [0.34281372 0.65718628]
# [0.34281372 0.65718628]
# [0.34281372 0.65718628]
# [0.34281372 0.65718628]
# [0.34281372 0.65718628]
# [0.34281372 0.65718628]
# [0.34281372 0.65718628]
# [0.34281372 0.65718628]
# [0.34281372 0.65718628]
# [0.34281372 0.65718628]
# [0.34281372 0.65718628]
# [0.34281372 0.65718628]
# [0.31918821 0.68081179]
# [0.31918821 0.68081179]
# [0.31918821 0.68081179]
# [0.31918821 0.68081179]
# [0.31918821 0.68081179]
# [0.31918821 0.68081179]
# [0.31918821 0.68081179]
# [0.31918821 0.68081179]
# [0.31918821 0.68081179]
# [0.31918821 0.68081179]
# [0.31918821 0.68081179]
# [0.31918821 0.68081179]
# [0.31918821 0.68081179]
# [0.31918821 0.68081179]
# [0.31918821 0.68081179]
# [0.31918821 0.68081179]
# [0.31918821 0.68081179]
# [0.31918821 0.68081179]
# [0.31918821 0.68081179]
# [0.31918821 0.68081179]
# [0.29886187 0.70113813]
# [0.29886187 0.70113813]
# [0.29886187 0.70113813]
# [0.29886187 0.70113813]
# [0.29886187 0.70113813]
# [0.29886187 0.70113813]
# [0.29886187 0.70113813]
# [0.29886187 0.70113813]
# [0.29886187 0.70113813]
# [0.29886187 0.70113813]
# [0.29886187 0.70113813]
# [0.29886187 0.70113813]
# [0.29886187 0.70113813]
# [0.29886187 0.70113813]
# [0.29886187 0.70113813]
# [0.29886187 0.70113813]
# [0.29886187 0.70113813]
# [0.29886187 0.70113813]
# [0.29886187 0.70113813]
# [0.29886187 0.70113813]

# %%
np.dot(np.array([-1,-1]),w_im)
# Out:
# array([-2., -4.])

# %%
1/(np.exp(-(np.dot(np.array([-1,-1]),w_im))))
# Out:
# array([0.13533528, 0.01831564])
