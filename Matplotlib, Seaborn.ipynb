# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# 나중에 다시 하기


labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(12, 10))
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)



plt.show()

# %%
np.random.seed(19680801)

# %%
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
performance = 3 + 10 * np.random.rand(len(people))

fig, ax = plt.subplots(figsize=(7, 5))

ax.barh(people, performance, xerr=np.random.rand(len(people)), align='center',alpha=0.8, color='red')
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go to today?')
ax.invert_yaxis() 
plt.show()

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(8, 7))
ax.bar(x, men_means, width, label='Men', yerr=women_std)
ax.bar(x, women_means, width, label='Women',bottom =men_means, yerr=men_std)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()





plt.show()

# %%
data = {'apple': 10, 'orange': 15, 'lemon': 5, 'lime': 20}

x_list = data.keys()
y_list = data.values()


fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True)


axs[0].bar(x_list,y_list)
axs[1].plot(x_list,y_list)
axs[2].scatter(x_list,y_list)

fig.suptitle("Categorical Plotting")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


# 나중에 하기 너무 어렵다
category_names = ['Strongly disagree', 'Disagree',
                  'Neither agree nor disagree', 'Agree', 'Strongly agree']
results = {
    'Question 1': [10, 15, 17, 32, 26],
    'Question 2': [26, 22, 29, 10, 13],
    'Question 3': [35, 37, 7, 2, 19],
    'Question 4': [32, 11, 9, 15, 33],
    'Question 5': [21, 29, 5, 5, 40],
    'Question 6': [8, 19, 5, 30, 38]
}

fig, ax = plt.subplots()

question_list = list(results.keys())



ax.barh(question_list, results[0],  align='center',alpha=0.8)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-8a9be26ed98c> in <module>
#      21
#      22
# ---> 23 ax.barh(question_list, results[0],  align='center',alpha=0.8)
#      24
#      25
#
# KeyError: 0

# %%
# Scatter Custom Symbol
# 나중에 다시 한번 확인해본다
rx, ry = 3., 1.
area = rx * ry * np.pi
theta = np.arange(0, 2 * np.pi + 0.01, 0.1)
verts = np.column_stack([rx / area * np.cos(theta), ry / area * np.sin(theta)])

x, y, s, c = np.random.rand(4, 30)
s *= 10**2.
print('x={}'.format(x))
print('y={}'.format(y))
print('s={}'.format(s))

x = np.linspace(0,1,30)
y = np.linspace(0,1,30)
c = np.linspace(0,1,30)
print(c)


fig, ax = plt.subplots()
ax.scatter(x,y,s,c, marker=verts)

plt.show()
# Out:
# x=[0.53228294 0.55716523 0.79139304 0.47745748 0.64508171 0.63989247
#  0.42777024 0.20228225 0.14389478 0.14868343 0.5611178  0.71240549
#  0.96898673 0.30730454 0.63526127 0.61513753 0.32601419 0.50653916
#  0.23116536 0.64606287 0.59775801 0.61430073 0.86422258 0.93437785
#  0.79676385 0.19727061 0.87462463 0.23005798 0.98372881 0.724374  ]
# y=[0.45122606 0.89547657 0.19267168 0.29812098 0.45426791 0.16810631
#  0.57656526 0.43331294 0.75222444 0.75213093 0.80389815 0.05736451
#  0.45568336 0.08513175 0.68747856 0.99065191 0.5905647  0.43374663
#  0.83911582 0.59906015 0.76194259 0.3222999  0.46144177 0.09842699
#  0.95862063 0.18658334 0.03826011 0.68272141 0.64175888 0.35706734]
# s=[73.41470896 77.56816982 12.73903128  1.88242866 59.85242863 34.30553612
#  58.51098129 42.22716489 88.31778363 52.74866359 10.4005791  26.22824012
#   3.29023308 62.41271969 21.93596226 39.93334809 75.99185551 83.03649679
#  83.8619888  72.82369409 15.81204224 58.19060595 35.17861317 28.30189112
#  16.1620297  84.07830268 56.58003792 57.09549658 75.87319384 48.24312823]
# [0.         0.03448276 0.06896552 0.10344828 0.13793103 0.17241379
#  0.20689655 0.24137931 0.27586207 0.31034483 0.34482759 0.37931034
#  0.4137931  0.44827586 0.48275862 0.51724138 0.55172414 0.5862069
#  0.62068966 0.65517241 0.68965517 0.72413793 0.75862069 0.79310345
#  0.82758621 0.86206897 0.89655172 0.93103448 0.96551724 1.        ]

# %%
#나중에 다시 해본다
A = [[0, 0, 0],
     [1, 2, 3],
     [2, 4, 6],
     [3, 6, 9]]

for i in range(len(A) - 1):
    plt.stairs(A[i+1], baseline=A[i], fill=True)

# %%
x = np.arange(0.0, 50.0, 2.0)
y = x ** 1.3 + np.random.rand(*x.shape) * 30.0
s = np.random.rand(*x.shape) * 800 + 500

plt.scatter(x, y, s, c="g", alpha=0.5, marker=r'$\clubsuit$',
            label="Luck")
plt.xlabel("Leprechauns")
plt.ylabel("Gold")
plt.legend(loc='upper left')
plt.show()

# %%
x = np.linspace(0.1, 2 * np.pi, 41)
y = np.exp(np.sin(x))

plt.stem(x,y)
# Out:
# <StemContainer object of 3 artists>

# %%
N_points = 100000
n_bins = 20

# Generate a normal distribution, center at x=0 and y=5
x = np.random.randn(N_points)
y = .4 * x + np.random.randn(100000) + 5

fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)
