# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome('chrome_driver/chromedriver.exe')
driver.get('https://www.opinet.co.kr')

# %%
print(driver.current_url)
# Out:
# https://www.opinet.co.kr/

# %%
driver.implicitly_wait(time_to_wait=5)

# %%
search_box  = driver.find_element_by_class_name('gnb')

# %%
driver.execute_script('goSubPage(0,0,99)')

# %%
gu_list_temp = driver.find_element_by_xpath("""//*[@id="SIGUNGU_NM0"]""")

# %%
gu_list = gu_list_temp.find_elements_by_tag_name('option')

# %%
gu_list
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="89b5edae98c12293d534282372e1769c", element="0f6e1603-ecfb-4778-b78c-5afb944476b5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="89b5edae98c12293d534282372e1769c", element="6fa36fb5-2909-4bc6-94a2-fb4e04bb2059")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="89b5edae98c12293d534282372e1769c", element="a1bb34b6-621d-4890-aa77-9436f81b9ead")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="89b5edae98c12293d534282372e1769c", element="2fd8c898-02a6-4ee2-8789-d1aa751d6dce")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="89b5edae98c12293d534282372e1769c", element="9373ccc5-2127-4772-9d65-51ea7a538cc5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="89b5edae98c12293d534282372e1769c", element="a50abc31-8bb9-4412-8b7b-9f3eb1a0ac50")>,
# ...

# %%
gu_name = [option.get_attribute('value') for option in gu_list]
gu_name
# Out:
# ['',
#  '강남구',
#  '강동구',
#  '강북구',
#  '강서구',
#  '관악구',
#  '광진구',
#  '구로구',
#  '금천구',
#  '노원구',
#  '도봉구',
#  '동대문구',
#  '동작구',
#  '마포구',
#  '서대문구',
#  '서초구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '양천구',
#  '영등포구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '중구',
#  '중랑구']

# %%
gu_name.remove('')
gu_name
# Out:
# ['강남구',
#  '강동구',
#  '강북구',
#  '강서구',
#  '관악구',
#  '광진구',
#  '구로구',
#  '금천구',
#  '노원구',
#  '도봉구',
#  '동대문구',
#  '동작구',
#  '마포구',
#  '서대문구',
#  '서초구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '양천구',
#  '영등포구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '중구',
#  '중랑구']

# %%
element = driver.find_element_by_id('SIGUNGU_NM0')
# element.send_keys(gu_name[0])

# %%
# element_excel = driver.find_element_by_xpath("""//*[@id="glopopd_excel"]""").click()

# %%
import time

for name in gu_name:
    element = driver.find_element_by_id('SIGUNGU_NM0')
    element.send_keys(name)
    time.sleep(5)
    element_excel = driver.find_element_by_xpath("""//*[@id="glopopd_excel"]""").click()
    time.sleep(5)

# %%
len(gu_name)
# Out:
# 25

# %%
driver.close()

# %%
import pandas as pd
from glob import glob

# %%
glob('data/지역_위치별*xls')
# Out:
# ['data\\지역_위치별(주유소) (1).xls',
#  'data\\지역_위치별(주유소) (10).xls',
#  'data\\지역_위치별(주유소) (11).xls',
#  'data\\지역_위치별(주유소) (12).xls',
#  'data\\지역_위치별(주유소) (13).xls',
#  'data\\지역_위치별(주유소) (14).xls',
#  'data\\지역_위치별(주유소) (15).xls',
#  'data\\지역_위치별(주유소) (16).xls',
#  'data\\지역_위치별(주유소) (17).xls',
#  'data\\지역_위치별(주유소) (18).xls',
#  'data\\지역_위치별(주유소) (19).xls',
#  'data\\지역_위치별(주유소) (2).xls',
#  'data\\지역_위치별(주유소) (20).xls',
#  'data\\지역_위치별(주유소) (21).xls',
#  'data\\지역_위치별(주유소) (22).xls',
#  'data\\지역_위치별(주유소) (23).xls',
#  'data\\지역_위치별(주유소) (24).xls',
#  'data\\지역_위치별(주유소) (3).xls',
#  'data\\지역_위치별(주유소) (4).xls',
#  'data\\지역_위치별(주유소) (5).xls',
#  'data\\지역_위치별(주유소) (6).xls',
#  'data\\지역_위치별(주유소) (7).xls',
#  'data\\지역_위치별(주유소) (8).xls',
#  'data\\지역_위치별(주유소) (9).xls',
#  'data\\지역_위치별(주유소).xls']

# %%
station_list  = glob('data/지역_위치별*xls')

# %%
pop_Seoul = pd.read_excel('data/지역_위치별(주유소).xls', header=2)
tmp_list = []

for station in station_list:
    data_frame = pd.read_excel(station, header=2)
    tmp_list.append(data_frame)

# %%
tmp_list[0]
# Out:
#        지역                    상호                            주소      상표  \
# 0   서울특별시  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  현대오일뱅크
# 1   서울특별시                구천면주유소         서울 강동구 구천면로 357 (암사동)  현대오일뱅크
# 2   서울특별시     현대오일뱅크㈜직영 명일셀프주유소          서울 강동구 고덕로 168 (명일동)  현대오일뱅크
# 3   서울특별시        지에스칼텍스㈜ 동서울주유소        서울 강동구 천호대로 1456 (상일동)   GS칼텍스
# 4   서울특별시      주)지유에너지직영 오렌지주유소          서울 강동구 성안로 102 (성내동)   SK에너지
# 5   서울특별시       대성석유(주)직영 길동주유소              서울 강동구 천호대로 1168   GS칼텍스
# 6   서울특별시       (주)퍼스트오일 코알라주유소     서울특별시 강동구  올림픽로 556 (성내동)   S-OIL
# 7   서울특별시               방아다리주유소          서울 강동구 동남로 811 (명일동)   SK에너지
# 8   서울특별시     현대오일뱅크㈜직영 암사셀프주유소         서울 강동구 올림픽로 749 (암사동)  현대오일뱅크
# 9   서울특별시         지에스칼텍스㈜ 신월주유소        서울 강동구 양재대로 1323 (성내동)   GS칼텍스
# 10  서울특별시              sk해뜨는주유소         서울 강동구  상일로 132 (강일동)   SK에너지
# 11  서울특별시               천호현대주유소           서울 강동구 천중로 67 (천호동)  현대오일뱅크
# ...

# %%
station_raw = pd.concat(tmp_list)

# %%
pd.set_option('display.max_rows', 20)
station_raw
# Out:
#        지역                    상호                            주소      상표  \
# 0   서울특별시  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  현대오일뱅크
# 1   서울특별시                구천면주유소         서울 강동구 구천면로 357 (암사동)  현대오일뱅크
# 2   서울특별시     현대오일뱅크㈜직영 명일셀프주유소          서울 강동구 고덕로 168 (명일동)  현대오일뱅크
# 3   서울특별시        지에스칼텍스㈜ 동서울주유소        서울 강동구 천호대로 1456 (상일동)   GS칼텍스
# 4   서울특별시      주)지유에너지직영 오렌지주유소          서울 강동구 성안로 102 (성내동)   SK에너지
# ..    ...                   ...                           ...     ...
# 34  서울특별시                학여울주유소      서울 강남구 남부순환로 3170 (일원2동)   GS칼텍스
# 35  서울특별시              (주)만정에너지         서울 강남구 봉은사로 433 (삼성동)   GS칼텍스
# 36  서울특별시               뉴서울(강남)                서울 강남구 언주로 716   SK에너지
# 37  서울특별시                 삼성주유소          서울 강남구 삼성로 521 (삼성동)   SK에너지
# 38  서울특별시                 동우주유소     서울특별시 강남구  봉은사로 311 (논현동)   SK에너지
#
#             전화번호 셀프여부 고급휘발유   휘발유    경유  실내등유
# 0    02-487-2030    Y     -  1589  1389     -
# ...

# %%
station_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 483 entries, 0 to 38
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      483 non-null    object
#  1   상호      483 non-null    object
#  2   주소      483 non-null    object
#  3   상표      483 non-null    object
#  4   전화번호    483 non-null    object
#  5   셀프여부    483 non-null    object
#  6   고급휘발유   483 non-null    object
#  7   휘발유     483 non-null    object
#  8   경유      483 non-null    object
#  9   실내등유    483 non-null    object
# dtypes: object(10)
# memory usage: 41.5+ KB

# %%
station_raw
# Out:
#        지역                    상호                            주소      상표  \
# 0   서울특별시  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  현대오일뱅크
# 1   서울특별시                구천면주유소         서울 강동구 구천면로 357 (암사동)  현대오일뱅크
# 2   서울특별시     현대오일뱅크㈜직영 명일셀프주유소          서울 강동구 고덕로 168 (명일동)  현대오일뱅크
# 3   서울특별시        지에스칼텍스㈜ 동서울주유소        서울 강동구 천호대로 1456 (상일동)   GS칼텍스
# 4   서울특별시      주)지유에너지직영 오렌지주유소          서울 강동구 성안로 102 (성내동)   SK에너지
# ..    ...                   ...                           ...     ...
# 34  서울특별시                학여울주유소      서울 강남구 남부순환로 3170 (일원2동)   GS칼텍스
# 35  서울특별시              (주)만정에너지         서울 강남구 봉은사로 433 (삼성동)   GS칼텍스
# 36  서울특별시               뉴서울(강남)                서울 강남구 언주로 716   SK에너지
# 37  서울특별시                 삼성주유소          서울 강남구 삼성로 521 (삼성동)   SK에너지
# 38  서울특별시                 동우주유소     서울특별시 강남구  봉은사로 311 (논현동)   SK에너지
#
#             전화번호 셀프여부 고급휘발유   휘발유    경유  실내등유
# 0    02-487-2030    Y     -  1589  1389     -
# ...

# %%
station_raw.head(20)
# Out:
#        지역                    상호                            주소      상표  \
# 0   서울특별시  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  현대오일뱅크
# 1   서울특별시                구천면주유소         서울 강동구 구천면로 357 (암사동)  현대오일뱅크
# 2   서울특별시     현대오일뱅크㈜직영 명일셀프주유소          서울 강동구 고덕로 168 (명일동)  현대오일뱅크
# 3   서울특별시        지에스칼텍스㈜ 동서울주유소        서울 강동구 천호대로 1456 (상일동)   GS칼텍스
# 4   서울특별시      주)지유에너지직영 오렌지주유소          서울 강동구 성안로 102 (성내동)   SK에너지
# 5   서울특별시       대성석유(주)직영 길동주유소              서울 강동구 천호대로 1168   GS칼텍스
# 6   서울특별시       (주)퍼스트오일 코알라주유소     서울특별시 강동구  올림픽로 556 (성내동)   S-OIL
# 7   서울특별시               방아다리주유소          서울 강동구 동남로 811 (명일동)   SK에너지
# 8   서울특별시     현대오일뱅크㈜직영 암사셀프주유소         서울 강동구 올림픽로 749 (암사동)  현대오일뱅크
# 9   서울특별시         지에스칼텍스㈜ 신월주유소        서울 강동구 양재대로 1323 (성내동)   GS칼텍스
# 10  서울특별시              sk해뜨는주유소         서울 강동구  상일로 132 (강일동)   SK에너지
# 11  서울특별시               천호현대주유소           서울 강동구 천중로 67 (천호동)  현대오일뱅크
# ...

# %%
stations = pd.DataFrame({'주유소':station_raw['상호'],
                         '주소':station_raw['주소'],
                         '가격':station_raw['휘발유'],
                         '셀프':station_raw['셀프여부'],
                         '상표':station_raw['상표']})

stations
# Out:
#                      주유소                            주소    가격 셀프      상표
# 0   재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  1589  Y  현대오일뱅크
# 1                 구천면주유소         서울 강동구 구천면로 357 (암사동)  1623  N  현대오일뱅크
# 2      현대오일뱅크㈜직영 명일셀프주유소          서울 강동구 고덕로 168 (명일동)  1635  Y  현대오일뱅크
# 3         지에스칼텍스㈜ 동서울주유소        서울 강동구 천호대로 1456 (상일동)  1645  Y   GS칼텍스
# 4       주)지유에너지직영 오렌지주유소          서울 강동구 성안로 102 (성내동)  1663  N   SK에너지
# ..                   ...                           ...   ... ..     ...
# 34                학여울주유소      서울 강남구 남부순환로 3170 (일원2동)  2089  N   GS칼텍스
# 35              (주)만정에너지         서울 강남구 봉은사로 433 (삼성동)  2113  N   GS칼텍스
# 36               뉴서울(강남)                서울 강남구 언주로 716  2225  N   SK에너지
# 37                 삼성주유소          서울 강남구 삼성로 521 (삼성동)     -  N   SK에너지
# 38                 동우주유소     서울특별시 강남구  봉은사로 311 (논현동)     -  N   SK에너지
#
# [483 rows x 5 columns]

# %%
gu_list = []

for address in stations['주소']:
    first_address = address.split()
    gu_name = first_address[1]
    gu_list.append(gu_name)
    
gu_list

stations['구'] = gu_list

# %%
stations
# Out:
#                      주유소                            주소    가격 셀프      상표    구
# 0   재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  1589  Y  현대오일뱅크  강동구
# 1                 구천면주유소         서울 강동구 구천면로 357 (암사동)  1623  N  현대오일뱅크  강동구
# 2      현대오일뱅크㈜직영 명일셀프주유소          서울 강동구 고덕로 168 (명일동)  1635  Y  현대오일뱅크  강동구
# 3         지에스칼텍스㈜ 동서울주유소        서울 강동구 천호대로 1456 (상일동)  1645  Y   GS칼텍스  강동구
# 4       주)지유에너지직영 오렌지주유소          서울 강동구 성안로 102 (성내동)  1663  N   SK에너지  강동구
# ..                   ...                           ...   ... ..     ...  ...
# 34                학여울주유소      서울 강남구 남부순환로 3170 (일원2동)  2089  N   GS칼텍스  강남구
# 35              (주)만정에너지         서울 강남구 봉은사로 433 (삼성동)  2113  N   GS칼텍스  강남구
# 36               뉴서울(강남)                서울 강남구 언주로 716  2225  N   SK에너지  강남구
# 37                 삼성주유소          서울 강남구 삼성로 521 (삼성동)     -  N   SK에너지  강남구
# 38                 동우주유소     서울특별시 강남구  봉은사로 311 (논현동)     -  N   SK에너지  강남구
#
# [483 rows x 6 columns]

# %%
jinsu = [x.split()[1] for x in stations['주소']]
print(jinsu)
# Out:
# ['강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동작구', '동작구', '동작구', '동작구', '동작구', '동작구', '동작구', '동작구', '동작구', '동작구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '성동구', '성동구', '성동구', '성동구', '성동구', '성동구', '성동구', '성동구', '성동구', '성동구', '성동구', '성동구', '성동구', '성동구', '성동구', '성동구', '성동구', '성북구', '성북구', '성북구', '성북구', '성북구', '성북구', '성북구', '성북구', '성북구', '성북구', '성북구', '성북구', '성북구
# ...

# %%
stations['구'].unique()
# Out:
# array(['강동구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '강북구', '용산구', '은평구', '종로구', '중구', '중랑구', '강서구',
#        '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '강남구'], dtype=object)

# %%
pd.set_option('display.max_rows', 500)
stations.head(400)
# Out:
#                       주유소                             주소    가격 셀프      상표  \
# 0    재건에너지 재정제2주유소 고속셀프지점   서울특별시 강동구  천호대로 1246 (둔촌제2동)  1589  Y  현대오일뱅크
# 1                  구천면주유소          서울 강동구 구천면로 357 (암사동)  1623  N  현대오일뱅크
# 2       현대오일뱅크㈜직영 명일셀프주유소           서울 강동구 고덕로 168 (명일동)  1635  Y  현대오일뱅크
# 3          지에스칼텍스㈜ 동서울주유소         서울 강동구 천호대로 1456 (상일동)  1645  Y   GS칼텍스
# 4        주)지유에너지직영 오렌지주유소           서울 강동구 성안로 102 (성내동)  1663  N   SK에너지
# 5         대성석유(주)직영 길동주유소               서울 강동구 천호대로 1168  1668  N   GS칼텍스
# 6         (주)퍼스트오일 코알라주유소      서울특별시 강동구  올림픽로 556 (성내동)  1668  Y   S-OIL
# 7                 방아다리주유소           서울 강동구 동남로 811 (명일동)  1668  Y   SK에너지
# 8       현대오일뱅크㈜직영 암사셀프주유소          서울 강동구 올림픽로 749 (암사동)  1673  Y  현대오일뱅크
# 9           지에스칼텍스㈜ 신월주유소         서울 강동구 양재대로 1323 (성내동)  1674  N   GS칼텍스
# 10               sk해뜨는주유소          서울 강동구  상일로 132 (강일동)  1679  Y   SK에너지
# 11                천호현대주유소            서울 강동구 천중로 67 (천호동)  1697  N  현대오일뱅크
# ...

# %%
stations[stations['가격']=='-']
# Out:
#                   주유소                         주소 가격 셀프      상표     구
# 12              서강주유소       서울 마포구 독막로 134 (창전동)  -  N   SK에너지   마포구
# 27      지에스칼텍스㈜ 화일주유소            서울 영등포구 도림로 415  -  Y   GS칼텍스  영등포구
# 28  현대오일뱅크㈜직영 대일셀프주유소           서울 영등포구 영등포로 168  -  Y  현대오일뱅크  영등포구
# 16              삼융주유소       서울 은평구 수색로 299 (수색동)  -  N   SK에너지   은평구
# 10    지에스칼텍스(주)직영 역전점               서울 중구 퇴계로 15  -  N   GS칼텍스    중구
# 13      지에스칼텍스㈜ 소망주유소             서울 중랑구 망우로 475  -  Y   GS칼텍스   중랑구
# 14              대양주유소      서울 중랑구 봉우재로 105 (상봉동)  -  N   GS칼텍스   중랑구
# 14            구의스타주유소             서울 광진구 자양로 103  -  N   GS칼텍스   광진구
# 14     양지진흥개발(주)상계주유소       서울 노원구 노해로 527 (상계동)  -  N   SK에너지   노원구
# 37              삼성주유소       서울 강남구 삼성로 521 (삼성동)  -  N   SK에너지   강남구
# 38              동우주유소  서울특별시 강남구  봉은사로 311 (논현동)  -  N   SK에너지   강남구

# %%
stations = stations[stations['가격']!='-']

# %%
price_list = stations['가격'].tolist()
price_list = list(map(float,price_list))
print(type(price_list[0]))
# Out:
# <class 'float'>

# %%
print(price_list)
# Out:
# [1589.0, 1623.0, 1635.0, 1645.0, 1663.0, 1668.0, 1668.0, 1668.0, 1673.0, 1674.0, 1679.0, 1697.0, 1698.0, 1758.0, 1798.0, 2098.0, 1569.0, 1575.0, 1579.0, 1585.0, 1589.0, 1597.0, 1605.0, 1614.0, 1617.0, 1625.0, 1627.0, 1637.0, 1637.0, 1638.0, 1648.0, 1659.0, 1668.0, 1699.0, 1770.0, 1594.0, 1599.0, 1599.0, 1608.0, 1614.0, 1624.0, 1634.0, 1649.0, 1653.0, 1755.0, 1598.0, 1637.0, 1647.0, 1658.0, 1678.0, 1678.0, 1696.0, 1698.0, 1708.0, 1788.0, 1857.0, 1897.0, 1584.0, 1589.0, 1589.0, 1599.0, 1602.0, 1607.0, 1607.0, 1608.0, 1617.0, 1617.0, 1617.0, 1618.0, 1628.0, 1637.0, 1637.0, 1529.0, 1603.0, 1605.0, 1607.0, 1609.0, 1609.0, 1610.0, 1618.0, 1619.0, 1619.0, 1624.0, 1625.0, 1625.0, 1625.0, 1626.0, 1628.0, 1634.0, 1635.0, 1638.0, 1638.0, 1647.0, 1648.0, 1669.0, 1680.0, 1680.0, 1688.0, 1688.0, 1689.0, 1695.0, 1748.0, 1795.0, 1842.0, 1997.0, 1998.0, 2107.0, 1579.0, 1588.0, 1594.0, 1608.0, 1624.0, 1638.0, 1668.0, 1668.0, 1668.0, 1669.0, 1686.0, 1719.0, 1734.0, 1848.0, 1889.0, 1895.0, 1898.0, 1567.
# ...

# %%
stations['가격'] = price_list
stations
# Out:
# C:\Users\BIT\anaconda3\envs\data-anal-env\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                       주유소                             주소      가격 셀프      상표  \
# 0    재건에너지 재정제2주유소 고속셀프지점   서울특별시 강동구  천호대로 1246 (둔촌제2동)  1589.0  Y  현대오일뱅크
# 1                  구천면주유소          서울 강동구 구천면로 357 (암사동)  1623.0  N  현대오일뱅크
# 2       현대오일뱅크㈜직영 명일셀프주유소           서울 강동구 고덕로 168 (명일동)  1635.0  Y  현대오일뱅크
# 3          지에스칼텍스㈜ 동서울주유소         서울 강동구 천호대로 1456 (상일동)  1645.0  Y   GS칼텍스
# 4        주)지유에너지직영 오렌지주유소           서울 강동구 성안로 102 (성내동)  1663.0  N   SK에너지
# 5         대성석유(주)직영 길동주유소               서울 강동구 천호대로 1168  1668.0  N   GS칼텍스
# ...

# %%
stations
# Out:
#                       주유소                             주소      가격 셀프      상표  \
# 0    재건에너지 재정제2주유소 고속셀프지점   서울특별시 강동구  천호대로 1246 (둔촌제2동)  1589.0  Y  현대오일뱅크
# 1                  구천면주유소          서울 강동구 구천면로 357 (암사동)  1623.0  N  현대오일뱅크
# 2       현대오일뱅크㈜직영 명일셀프주유소           서울 강동구 고덕로 168 (명일동)  1635.0  Y  현대오일뱅크
# 3          지에스칼텍스㈜ 동서울주유소         서울 강동구 천호대로 1456 (상일동)  1645.0  Y   GS칼텍스
# 4        주)지유에너지직영 오렌지주유소           서울 강동구 성안로 102 (성내동)  1663.0  N   SK에너지
# 5         대성석유(주)직영 길동주유소               서울 강동구 천호대로 1168  1668.0  N   GS칼텍스
# 6         (주)퍼스트오일 코알라주유소      서울특별시 강동구  올림픽로 556 (성내동)  1668.0  Y   S-OIL
# 7                 방아다리주유소           서울 강동구 동남로 811 (명일동)  1668.0  Y   SK에너지
# 8       현대오일뱅크㈜직영 암사셀프주유소          서울 강동구 올림픽로 749 (암사동)  1673.0  Y  현대오일뱅크
# 9           지에스칼텍스㈜ 신월주유소         서울 강동구 양재대로 1323 (성내동)  1674.0  N   GS칼텍스
# 10               sk해뜨는주유소          서울 강동구  상일로 132 (강일동)  1679.0  Y   SK에너지
# ...

# %%
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 472 entries, 0 to 36
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   주유소     472 non-null    object
#  1   주소      472 non-null    object
#  2   가격      472 non-null    float64
#  3   셀프      472 non-null    object
#  4   상표      472 non-null    object
#  5   구       472 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 25.8+ KB

# %%
stations.reset_index(inplace=True)

# %%
stations
# Out:
#      index                    주유소                             주소      가격 셀프  \
# 0        0   재건에너지 재정제2주유소 고속셀프지점   서울특별시 강동구  천호대로 1246 (둔촌제2동)  1589.0  Y
# 1        1                 구천면주유소          서울 강동구 구천면로 357 (암사동)  1623.0  N
# 2        2      현대오일뱅크㈜직영 명일셀프주유소           서울 강동구 고덕로 168 (명일동)  1635.0  Y
# 3        3         지에스칼텍스㈜ 동서울주유소         서울 강동구 천호대로 1456 (상일동)  1645.0  Y
# 4        4       주)지유에너지직영 오렌지주유소           서울 강동구 성안로 102 (성내동)  1663.0  N
# 5        5        대성석유(주)직영 길동주유소               서울 강동구 천호대로 1168  1668.0  N
# 6        6        (주)퍼스트오일 코알라주유소      서울특별시 강동구  올림픽로 556 (성내동)  1668.0  Y
# 7        7                방아다리주유소           서울 강동구 동남로 811 (명일동)  1668.0  Y
# 8        8      현대오일뱅크㈜직영 암사셀프주유소          서울 강동구 올림픽로 749 (암사동)  1673.0  Y
# 9        9          지에스칼텍스㈜ 신월주유소         서울 강동구 양재대로 1323 (성내동)  1674.0  N
# 10      10               sk해뜨는주유소          서울 강동구  상일로 132 (강일동)  1679.0  Y
# ...

# %%
del stations['index']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\data-anal-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-c5e16d7ee6de> in <module>
# ...

# %%
stations
# Out:
#                        주유소                             주소      가격 셀프      상표  \
# 0     재건에너지 재정제2주유소 고속셀프지점   서울특별시 강동구  천호대로 1246 (둔촌제2동)  1589.0  Y  현대오일뱅크
# 1                   구천면주유소          서울 강동구 구천면로 357 (암사동)  1623.0  N  현대오일뱅크
# 2        현대오일뱅크㈜직영 명일셀프주유소           서울 강동구 고덕로 168 (명일동)  1635.0  Y  현대오일뱅크
# 3           지에스칼텍스㈜ 동서울주유소         서울 강동구 천호대로 1456 (상일동)  1645.0  Y   GS칼텍스
# 4         주)지유에너지직영 오렌지주유소           서울 강동구 성안로 102 (성내동)  1663.0  N   SK에너지
# 5          대성석유(주)직영 길동주유소               서울 강동구 천호대로 1168  1668.0  N   GS칼텍스
# 6          (주)퍼스트오일 코알라주유소      서울특별시 강동구  올림픽로 556 (성내동)  1668.0  Y   S-OIL
# 7                  방아다리주유소           서울 강동구 동남로 811 (명일동)  1668.0  Y   SK에너지
# 8        현대오일뱅크㈜직영 암사셀프주유소          서울 강동구 올림픽로 749 (암사동)  1673.0  Y  현대오일뱅크
# 9            지에스칼텍스㈜ 신월주유소         서울 강동구 양재대로 1323 (성내동)  1674.0  N   GS칼텍스
# 10                sk해뜨는주유소          서울 강동구  상일로 132 (강일동)  1679.0  Y   SK에너지
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import platform
from matplotlib import font_manager, rc # Runtime Configuration
path = "c:/Windows/Fonts/malgun.ttf"
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
stations.boxplot(column = '가격', by='셀프', figsize=(12,9))
# Out:
# <AxesSubplot:title={'center':'가격'}, xlabel='셀프'>

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='상표', y='가격', hue='셀프', data=stations, palette='Set3')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='상표', y='가격', hue='셀프', data=stations, palette='Set3')
sns.swarmplot(x='상표', y='가격', hue='셀프', data=stations, color='.6')
plt.show()
# Out:
# C:\Users\BIT\anaconda3\envs\data-anal-env\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 15.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
import json
import folium
import googlemaps

# %%
stations.sort_values(by='가격', ascending=False).head(10)
# Out:
#                  주유소                       주소      가격 셀프     상표    구
# 293            서남주유소             서울 중구 통일로 30  2453.0  N  SK에너지   중구
# 258            서계주유소     서울 용산구 청파로 367 (서계동)  2414.0  N  GS칼텍스  용산구
# 292            필동주유소    서울 중구  퇴계로 196 (필동2가)  2289.0  N  GS칼텍스   중구
# 291  SK에너지(주) 퇴계로주유소     서울 중구 퇴계로 228 (필동2가)  2269.0  N  SK에너지   중구
# 471          뉴서울(강남)           서울 강남구 언주로 716  2225.0  N  SK에너지  강남구
# 257           동자동주유소  서울 용산구 한강대로104길 6 (동자동)  2190.0  N  SK에너지  용산구
# 290            약수주유소            서울 중구 다산로 173  2178.0  N  GS칼텍스   중구
# 283  (주)중앙에너비스 혜화주유소         서울 종로구 창경궁로35길 1  2118.0  N  SK에너지  종로구
# 255             에너비스     서울 용산구 한남대로 82 (한남동)  2118.0  N  SK에너지  용산구
# 256             한남지점   서울 용산구 한남대로21길 4 (한남동)  2118.0  N  SK에너지  용산구

# %%
stations.sort_values(by='가격', ascending=True).head(10)
# Out:
#             주유소                      주소      가격 셀프      상표     구
# 72     만남의광장주유소    서울 서초구 양재대로12길 73-71  1529.0  Y  알뜰(ex)   서초구
# 207       성락주유소  서울 영등포구 가마산로 414 (신길동)  1549.0  Y   S-OIL  영등포구
# 206  영등포제일셀프주유소        서울 영등포구 가마산로 379  1549.0  Y  현대오일뱅크  영등포구
# 180     가로공원주유소  서울 양천구 가로공원로 165 (신월동)  1556.0  N   SK에너지   양천구
# 307      뉴신정주유소   서울 강서구 곰달래로 207 (화곡동)  1557.0  N   알뜰주유소   강서구
# 308      화곡역주유소    서울 강서구 강서로 154 (화곡동)  1557.0  Y   알뜰주유소   강서구
# 233      수유동주유소    서울 강북구 도봉로 395 (수유동)  1557.0  Y   GS칼텍스   강북구
# 209       도림주유소   서울 영등포구 도림로 343 (도림동)  1559.0  Y   알뜰주유소  영등포구
# 208    남서울고속주유소  서울 영등포구 가마산로 367 (대림동)  1559.0  Y   SK에너지  영등포구
# 182  개나리Self주유소  서울 양천구 남부순환로 442 (신월동)  1559.0  Y   SK에너지   양천구

# %%
gu_data = pd.pivot_table(stations, index='구', values=['가격'])
gu_data.head(10)
# Out:
#               가격
# 구
# 강남구  1814.459459
# 강동구  1702.125000
# 강북구  1579.923077
# 강서구  1623.090909
# 관악구  1648.533333
# 광진구  1628.785714
# 구로구  1637.909091
# 금천구  1600.250000
# 노원구  1650.142857
# 도봉구  1594.055556

# %%
geo_path = 'data/skorea_municipalities_geo_simple.json'
geo_data = json.load(open(geo_path, encoding='utf-8'))

# %%
fol_map = folium.Map(location=[37.5502, 126.982], zoom_start=11.2, tiles='Stamen Terrain')
folium.Choropleth(geo_data=geo_data, data=gu_data, columns=[gu_data.index, '가격'],\
                 fill_color='BuPu', key_on='feature.id').add_to(fol_map)

fol_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
oil_price_top10 = stations.sort_values(by='가격', ascending=False).head(10)
oil_price_bottom10 = stations.sort_values(by='가격', ascending=True).head(10)

# %%
oil_price_top10
# Out:
#                  주유소                       주소      가격 셀프     상표    구
# 293            서남주유소             서울 중구 통일로 30  2453.0  N  SK에너지   중구
# 258            서계주유소     서울 용산구 청파로 367 (서계동)  2414.0  N  GS칼텍스  용산구
# 292            필동주유소    서울 중구  퇴계로 196 (필동2가)  2289.0  N  GS칼텍스   중구
# 291  SK에너지(주) 퇴계로주유소     서울 중구 퇴계로 228 (필동2가)  2269.0  N  SK에너지   중구
# 471          뉴서울(강남)           서울 강남구 언주로 716  2225.0  N  SK에너지  강남구
# 257           동자동주유소  서울 용산구 한강대로104길 6 (동자동)  2190.0  N  SK에너지  용산구
# 290            약수주유소            서울 중구 다산로 173  2178.0  N  GS칼텍스   중구
# 283  (주)중앙에너비스 혜화주유소         서울 종로구 창경궁로35길 1  2118.0  N  SK에너지  종로구
# 255             에너비스     서울 용산구 한남대로 82 (한남동)  2118.0  N  SK에너지  용산구
# 256             한남지점   서울 용산구 한남대로21길 4 (한남동)  2118.0  N  SK에너지  용산구

# %%
oil_price_bottom10
# Out:
#             주유소                      주소      가격 셀프      상표     구
# 72     만남의광장주유소    서울 서초구 양재대로12길 73-71  1529.0  Y  알뜰(ex)   서초구
# 207       성락주유소  서울 영등포구 가마산로 414 (신길동)  1549.0  Y   S-OIL  영등포구
# 206  영등포제일셀프주유소        서울 영등포구 가마산로 379  1549.0  Y  현대오일뱅크  영등포구
# 180     가로공원주유소  서울 양천구 가로공원로 165 (신월동)  1556.0  N   SK에너지   양천구
# 307      뉴신정주유소   서울 강서구 곰달래로 207 (화곡동)  1557.0  N   알뜰주유소   강서구
# 308      화곡역주유소    서울 강서구 강서로 154 (화곡동)  1557.0  Y   알뜰주유소   강서구
# 233      수유동주유소    서울 강북구 도봉로 395 (수유동)  1557.0  Y   GS칼텍스   강북구
# 209       도림주유소   서울 영등포구 도림로 343 (도림동)  1559.0  Y   알뜰주유소  영등포구
# 208    남서울고속주유소  서울 영등포구 가마산로 367 (대림동)  1559.0  Y   SK에너지  영등포구
# 182  개나리Self주유소  서울 양천구 남부순환로 442 (신월동)  1559.0  Y   SK에너지   양천구

# %%
gmaps_key = "AIzaSyBQj_mdpMJcgLdXQ9-4cuqDFgUd62KwisM"
gmaps = googlemaps.Client(key=gmaps_key)

# %%
lat = []
lng = []

from tqdm import tqdm
import numpy as np

# loop_value = tqdm(oil_price_top10.index)


# for n in loop_value:
#     try:
#         address_data = gmaps.geocode(loop_value['주소'][n],language='ko')
#         lat.append(address_data[0]['geometry']['location']['lat'])
#         lng.append(address_data[0]['geometry']['location']['lng'])
#         time.sleep(0.05)
        
#     except:
#         lat.append(np.nan)
#         lng.append(np.nan)
#         time.sleep(0.05)
        
for address in oil_price_top10['주소']:
    try:
        address_data = gmaps.geocode(address,language='ko')
        lat.append(address_data[0]['geometry']['location']['lat'])
        lng.append(address_data[0]['geometry']['location']['lng'])
        time.sleep(0.05)

    except:
        lat.append(np.nan)
        lng.append(np.nan)
        time.sleep(0.05)
        
print(lat)
print(lng)
# Out:
# [37.5583477, 37.5524394, 37.5598189, 37.5598189, 37.51763589999999, 37.5502057, 37.5590093, 37.586068, 37.5359518, 37.5346573]
# [126.9720901, 126.9658264, 126.9946111, 126.9946111, 127.0357559, 126.9755461, 127.0126631, 127.0010581, 127.0061296, 127.0060631]

# %%
oil_price_top10['lat'] = lat
oil_price_top10['lng'] = lng
oil_price_top10
# Out:
#                  주유소                       주소      가격 셀프     상표    구  \
# 293            서남주유소             서울 중구 통일로 30  2453.0  N  SK에너지   중구
# 258            서계주유소     서울 용산구 청파로 367 (서계동)  2414.0  N  GS칼텍스  용산구
# 292            필동주유소    서울 중구  퇴계로 196 (필동2가)  2289.0  N  GS칼텍스   중구
# 291  SK에너지(주) 퇴계로주유소     서울 중구 퇴계로 228 (필동2가)  2269.0  N  SK에너지   중구
# 471          뉴서울(강남)           서울 강남구 언주로 716  2225.0  N  SK에너지  강남구
# 257           동자동주유소  서울 용산구 한강대로104길 6 (동자동)  2190.0  N  SK에너지  용산구
# 290            약수주유소            서울 중구 다산로 173  2178.0  N  GS칼텍스   중구
# 283  (주)중앙에너비스 혜화주유소         서울 종로구 창경궁로35길 1  2118.0  N  SK에너지  종로구
# 255             에너비스     서울 용산구 한남대로 82 (한남동)  2118.0  N  SK에너지  용산구
# 256             한남지점   서울 용산구 한남대로21길 4 (한남동)  2118.0  N  SK에너지  용산구
#
#            lat         lng
# 293  37.558348  126.972090
# 258  37.552439  126.965826
# 292  37.559819  126.994611
# 291  37.559819  126.994611
# 471  37.517636  127.035756
# 257  37.550206  126.975546
# ...

# %%
lat = []
lng = []

        
for address in oil_price_bottom10['주소']:
    try:
        address_data = gmaps.geocode(address,language='ko')
        lat.append(address_data[0]['geometry']['location']['lat'])
        lng.append(address_data[0]['geometry']['location']['lng'])
        time.sleep(0.05)

    except:
        lat.append(np.nan)
        lng.append(np.nan)
        time.sleep(0.05)

# %%
print(lat)
print(lng)
# Out:
# [37.4599063, 37.5037504, 37.5023621, 37.5369402, 37.5315539, 37.54065689999999, 37.6421401, 37.5094016, 37.5015666, 37.5280874]
# [127.0420601, 126.9028235, 126.8994521, 126.8342781, 126.8560239, 126.8415062, 127.0295678, 126.8960068, 126.8987908, 126.8329813]

# %%
oil_price_bottom10['lat'] = lat
oil_price_bottom10['lng'] = lng
oil_price_bottom10
# Out:
#             주유소                      주소      가격 셀프      상표     구        lat  \
# 72     만남의광장주유소    서울 서초구 양재대로12길 73-71  1529.0  Y  알뜰(ex)   서초구  37.459906
# 207       성락주유소  서울 영등포구 가마산로 414 (신길동)  1549.0  Y   S-OIL  영등포구  37.503750
# 206  영등포제일셀프주유소        서울 영등포구 가마산로 379  1549.0  Y  현대오일뱅크  영등포구  37.502362
# 180     가로공원주유소  서울 양천구 가로공원로 165 (신월동)  1556.0  N   SK에너지   양천구  37.536940
# 307      뉴신정주유소   서울 강서구 곰달래로 207 (화곡동)  1557.0  N   알뜰주유소   강서구  37.531554
# 308      화곡역주유소    서울 강서구 강서로 154 (화곡동)  1557.0  Y   알뜰주유소   강서구  37.540657
# 233      수유동주유소    서울 강북구 도봉로 395 (수유동)  1557.0  Y   GS칼텍스   강북구  37.642140
# 209       도림주유소   서울 영등포구 도림로 343 (도림동)  1559.0  Y   알뜰주유소  영등포구  37.509402
# 208    남서울고속주유소  서울 영등포구 가마산로 367 (대림동)  1559.0  Y   SK에너지  영등포구  37.501567
# 182  개나리Self주유소  서울 양천구 남부순환로 442 (신월동)  1559.0  Y   SK에너지   양천구  37.528087
#
#             lng
# 72   127.042060
# 207  126.902823
# 206  126.899452
# 180  126.834278
# 307  126.856024
# 308  126.841506
# ...

# %%
# loop_value = tqdm(oil_price_top10.index)

# for n in loop_value:
#     try:
#         tmp_add = oil_price_top1['주소'][n]
#         tmp_gmap = gmaps.geocode(tmp_add)
#         tmp_loc = tmp_gmap[0].get('geometry')
#         lat.append(tmp_loc['location']['lat'])
#         lng.append(tmp_loc['location']['lng'])
        
#     except:
#         lat.append(np.nan)
#         lng.append(np.nan)
#         print('='*20, 'Error')

# tqdm을 쓸 때 참조할 것

# %%
display(oil_price_bottom10)
display(oil_price_top10)
# Out:
#             주유소                      주소      가격 셀프      상표     구        lat  \
# 72     만남의광장주유소    서울 서초구 양재대로12길 73-71  1529.0  Y  알뜰(ex)   서초구  37.459906
# 207       성락주유소  서울 영등포구 가마산로 414 (신길동)  1549.0  Y   S-OIL  영등포구  37.503750
# 206  영등포제일셀프주유소        서울 영등포구 가마산로 379  1549.0  Y  현대오일뱅크  영등포구  37.502362
# 180     가로공원주유소  서울 양천구 가로공원로 165 (신월동)  1556.0  N   SK에너지   양천구  37.536940
# 307      뉴신정주유소   서울 강서구 곰달래로 207 (화곡동)  1557.0  N   알뜰주유소   강서구  37.531554
# 308      화곡역주유소    서울 강서구 강서로 154 (화곡동)  1557.0  Y   알뜰주유소   강서구  37.540657
# 233      수유동주유소    서울 강북구 도봉로 395 (수유동)  1557.0  Y   GS칼텍스   강북구  37.642140
# 209       도림주유소   서울 영등포구 도림로 343 (도림동)  1559.0  Y   알뜰주유소  영등포구  37.509402
# 208    남서울고속주유소  서울 영등포구 가마산로 367 (대림동)  1559.0  Y   SK에너지  영등포구  37.501567
# 182  개나리Self주유소  서울 양천구 남부순환로 442 (신월동)  1559.0  Y   SK에너지   양천구  37.528087
#
#             lng
# 72   127.042060
# 207  126.902823
# 206  126.899452
# 180  126.834278
# 307  126.856024
# 308  126.841506
# ...

# %%
# if pd.notnull()

# # 붉은 계통
# color='#CD3181'
# fill_color='#CD3181'

# # 푸른 계통
# color='#3186cc'
# fill_color='#3186cc'

top_numpy_lat = oil_price_top10['lat']
top_numpy_lng = oil_price_top10['lng']

bottom_numpy_lat = oil_price_bottom10['lat']
bottom_numpy_lng = oil_price_bottom10['lng']

new_numpy_lat = np.hstack((top_numpy_lat,bottom_numpy_lat))
new_numpy_lng = np.hstack((top_numpy_lng,bottom_numpy_lng))

lat_number = new_numpy_lat.mean()
lng_number = new_numpy_lng.mean()


fol_map = folium.Map(location=[lat_number, lng_number], zoom_start=12)


for i in range(len(oil_price_top10.index)):
    if pd.isnull(oil_price_top10['lat'][i]):
        continue
        
    else:
        folium.CircleMarker([oil_price_top10['lat'][i], oil_price_top10['lng'][i]], radius=15, 
                    popup=oil_price_top10['주유소'][i], color='#CD3181', 
                    fill_color='#CD3181').add_to(fol_map)
        
        
        


lat_number = oil_price_bottom10.mean()
lng_number = oil_price_bottom10.mean()

        
        
for i in range(len(oil_price_bottom10.index)):
    if pd.isnull(oil_price_bottom10['lat'][i]):
        continue
        
    else:
        folium.CircleMarker([oil_price_bottom10['lat'][i], oil_price_bottom10['lng'][i]], radius=15, 
                    popup=oil_price_bottom10['주유소'][i], color='#3186cc', 
                    fill_color='#3186cc').add_to(fol_map)
        
        
        
fol_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
