# %%
import pandas as pd
import numpy as np
from dateutil.parser import parse

#Exercise41
#Count the number of missing values in each column of df. Which column has the maximum number of missing values?
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')

df = pd.DataFrame(df.isnull().sum(), columns=['value'])

df.loc[df.value == np.max(df.value)]



# result_df = df.apply(lambda x: x.isnull().sum())
# result_df.argmax()
# Out:
#               value
# Luggage.room     19

# %%
#Exercise42
#Replace missing values in Min.Price and Max.Price columns with their respective mean.
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')


# 아래에 있는 방법은 약간 비효율적
# df['Min.Price'] = np.where(df['Min.Price'].isnull(), df['Min.Price'].mean(),df['Min.Price'])
# df['Max.Price'] = np.where(df['Max.Price'].isnull(), df['Max.Price'].mean(),df['Max.Price'])


df = df[['Min.Price', 'Max.Price']] = df[['Min.Price', 'Max.Price']].apply(lambda x: x.fillna(x.mean()))

df
# Out:
#     Min.Price  Max.Price
# 0   12.900000  18.800000
# 1   29.200000  38.700000
# 2   25.900000  32.300000
# 3   17.118605  44.600000
# 4   17.118605  21.459091
# ..        ...        ...
# 88  16.600000  22.700000
# 89  17.600000  22.400000
# 90  22.900000  23.700000
# 91  21.800000  23.500000
# 92  24.800000  28.500000
#
# [93 rows x 2 columns]

# %%
#Exercise43
#Replace missing values in Min.Price and Max.Price columns with their respective mean.
new_df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')

print(new_df.head(30))


new_df['Min.Price'] = np.where(df['Min.Price'].isnull(), df['Min.Price'].mean(),df['Min.Price'])
new_df['Max.Price'] = np.where(df['Max.Price'].isnull(), df['Max.Price'].median(),df['Max.Price'])

new_df


# new_df1= new_df['Min.Price'] = new_df['Min.Price'].apply(lambda y: y.fillna(y.mean()))
# new_df2 =  new_df['Max.Price'] = new_df['Max.Price'].apply(lambda z: z.fillna(z.median()))
# Out:
#    Manufacturer       Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura     Integra    Small       12.9   15.9       18.8      25.0
# 1           NaN      Legend  Midsize       29.2   33.9       38.7      18.0
# 2          Audi          90  Compact       25.9   29.1       32.3      20.0
# 3          Audi         100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW        535i  Midsize        NaN   30.0        NaN      22.0
# 5         Buick     Century  Midsize       14.2   15.7       17.3      22.0
# 6         Buick     LeSabre    Large       19.9   20.8        NaN      19.0
# 7         Buick  Roadmaster    Large       22.6   23.7       24.9      16.0
# 8         Buick     Riviera  Midsize       26.3   26.3       26.3      19.0
# 9      Cadillac     DeVille    Large       33.0   34.7       36.3      16.0
# 10     Cadillac     Seville  Midsize       37.5   40.1       42.7      16.0
# ...

# %%
#Exercise44
#Get the first column (a) in df as a dataframe (rather than as a Series).
df = pd.DataFrame(np.arange(20).reshape(-1, 5), columns=list('abcde'))

# pd.DataFrame(df.iloc[:,0])
df.loc[:,['a']]
# Out:
#     a
# 0   0
# 1   5
# 2  10
# 3  15

# %%
#Exercise45
#In df, interchange columns 'a' and 'c'.
#Create a generic function to interchange two columns, without hardcoding column names.
#Sort the columns in reverse alphabetical order, that is colume 'e' first through column 'a' last.

df = pd.DataFrame(np.arange(20).reshape(-1, 5), columns=list('abcde'))

display(df)

def swap_colums(df):
    col_list = list(df)
    col_list[0], col_list[2] = col_list[2], col_list[0]
    df.columns = col_list
    return df

swap_colums(df)

df.sort_index(axis=1, ascending=False, inplace=True)

df
# Out:
#     a   b   c   d   e
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19
#     e   d   c   b   a
# 0   4   3   0   1   2
# 1   9   8   5   6   7
# 2  14  13  10  11  12
# 3  19  18  15  16  17

# %%
#Exercise46
#Change the pamdas display settings on printing the dataframe df it shows a maximum of 10 rows and 10 columns.

df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')

pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', 10)

df
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  ...  Rear.seat.room  \
# 0         Acura  Integra    Small       12.9   15.9  ...            26.5
# 1           NaN   Legend  Midsize       29.2   33.9  ...            30.0
# 2          Audi       90  Compact       25.9   29.1  ...            28.0
# 3          Audi      100  Midsize        NaN   37.7  ...            31.0
# 4           BMW     535i  Midsize        NaN   30.0  ...            27.0
# ..          ...      ...      ...        ...    ...  ...             ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7  ...            34.0
# 89   Volkswagen   Passat  Compact       17.6   20.0  ...            31.5
# 90   Volkswagen  Corrado   Sporty       22.9   23.3  ...            26.0
# 91        Volvo      240  Compact       21.8   22.7  ...            29.5
# 92          NaN      850  Midsize       24.8   26.7  ...            30.0
#
#     Luggage.room  Weight   Origin                Make
# ...

# %%
#Exercise47
#Suppress scientific notations like ‘e-03’ in df and print upto 4 numbers after decimal.

df = pd.DataFrame(np.random.random(4)**10, columns=['random'])

pd.set_option('display.float_format', lambda x: '%.4f' % x)
df
# Out:
#    random
# 0  0.0000
# 1  0.0000
# 2  0.9401
# 3  0.0000

# %%
#Exercise48
#Format the values in column 'random' of df as percentages.
#나중에 다시 풀기

df = pd.DataFrame(np.random.random(4), columns=['random'])

# %%
#Exercise49
#From df, filter the 'Manufacturer', 'Model' and 'Type' for every 20th row starting from 1st (row 0).

df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')

df.loc[::20,['Manufacturer','Model','Type']]
# Out:
#    Manufacturer    Model     Type
# 0         Acura  Integra    Small
# 20     Chrysler  LeBaron  Compact
# 40        Honda  Prelude   Sporty
# 60      Mercury   Cougar  Midsize
# 80       Subaru   Loyale    Small

# %%
#Exercise50
#In df, Replace NaNs with ‘missing’ in columns 'Manufacturer', 'Model' and 'Type'
#and create a index as a combination of these three columns and check if the index is a primary key.
# 문제가 조금 이상함


df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv', usecols=[0,1,2,3,5])

df[['Manufacturer','Min.Price', 'Max.Price']] = \
df[['Manufacturer','Min.Price', 'Max.Price']].apply(lambda x: x.fillna('missing'))


# df[['Manufacturer', 'Model', 'Type']] = df[['Manufacturer', 'Model', 'Type']].fillna('missing')
pd.options.display.max_rows = 100


# 상당히 써먹을 수 있는 명령어이다.
df.index = df.Manufacturer + '_' + df.Model + '_' + df.Type
display(df)
print(df.index.is_unique)
# Out:
#                                    Manufacturer           Model     Type  \
# Acura_Integra_Small                       Acura         Integra    Small
# missing_Legend_Midsize                  missing          Legend  Midsize
# Audi_90_Compact                            Audi              90  Compact
# Audi_100_Midsize                           Audi             100  Midsize
# BMW_535i_Midsize                            BMW            535i  Midsize
# Buick_Century_Midsize                     Buick         Century  Midsize
# Buick_LeSabre_Large                       Buick         LeSabre    Large
# Buick_Roadmaster_Large                    Buick      Roadmaster    Large
# Buick_Riviera_Midsize                     Buick         Riviera  Midsize
# Cadillac_DeVille_Large                 Cadillac         DeVille    Large
# Cadillac_Seville_Midsize               Cadillac         Seville  Midsize
# Chevrolet_Cavalier_Compact            Chevrolet        Cavalier  Compact
# ...
