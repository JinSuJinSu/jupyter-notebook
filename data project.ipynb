# %%
import pandas as pd

# %%
import platform
from matplotlib import font_manager, rc # Runtime Configuration
path = "c:/Windows/Fonts/malgun.ttf"
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
import numpy as np

# %%
# from selenium import webdriver
# driver = webdriver.Chrome('chrome_driver/chromedriver.exe')
# driver.get('http://data.seoul.go.kr/dataList/OA-15245/F/1/datasetView.do#')
# driver.implicitly_wait(time_to_wait=5)
# for i in range(41):   
#     driver.execute_script("javascript:downloadFile"+"("+str(i+1)+")")
    
    
pd.set_option('display.max_rows', 1000)

# %%
data1 = pd.read_csv('data/서울특별시 공공자전거 시간대별 대여정보_201812_201905(1).csv', encoding = 'utf-8')
data1
# Out:
#               대여일자  대여시간  대여소번호                대여소명 대여구분코드  성별 연령대코드  이용건수  \
# 0       2018-12-01     0   1721     1721. 창동역 2번출구     정기권  \N  ~10대     1
# 1       2018-12-01     0   3511      3511. 응봉역 1번출구    정기권  \N  ~10대     1
# 2       2018-12-01     0   1975  1975. 대림역 1번 출입구 밑    정기권  \N  ~10대     1
# 3       2018-12-01     0    110            110. 사천교    정기권  \N  ~10대     1
# 4       2018-12-01     0    749      749. 이대 목동병원 앞    정기권  \N  ~10대     1
# ...            ...   ...    ...                 ...    ...  ..   ...   ...
# 999995  2019-02-27    19    214        214. 금융감독원 앞    정기권   F   30대     1
# 999996  2019-02-27    19   1906  1906. 신도림역 1번 출구 앞    정기권   F   30대     1
# 999997  2019-02-27    19   1908   1908. 해원리바파크 육교 밑    정기권   F   30대     1
# 999998  2019-02-27    19   1911    1911. 구로디지털단지역 앞    정기권   F   30대     1
# 999999  2019-02-27    19   2106      2106. 난곡 새마을금고    정기권   F   30대     1
#
#            운동량   탄소량    이동거리  사용시간
# ...

# %%
data2 = pd.read_csv('data/서울특별시 공공자전거 시간대별 대여정보_201812_201905(2).csv', encoding = 'utf-8')
data2
# Out:
# C:\Users\BIT\anaconda3\envs\data-anal-env\lib\site-packages\IPython\core\interactiveshell.py:3166: DtypeWarning: Columns (8,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                대여일자  대여시간  대여소번호                 대여소명 대여구분코드 성별 연령대코드  이용건수  \
# 0        2019-02-27     0    505  505. 자양사거리 광진아크로텔 앞    정기권  F   20대     1
# 1        2019-02-27     0   1448       1448. 코스트코 상봉점    정기권  F   20대     1
# 2        2019-02-27     0   1650        1650. 중계근린공원내    정기권  F   20대     1
# 3        2019-02-27     0   1654      1654. 당고개입구 오거리    정기권  F   20대     1
# 4        2019-02-27     0    302     302. 경복궁역 4번출구 뒤    정기권  F   20대     2
# ...             ...   ...    ...                  ...    ... ..   ...   ...
# 1025258  2019-04-13    23   1113   1113. 서남환경공원 버스정류장    단체권  M   20대     1
# 1025259  2019-04-13    23   1617  1617. 하계동 중평어린이공원 앞    단체권  M   20대     2
# ...

# %%
data1.dtypes
# Out:
# 대여일자       object
# 대여시간        int64
# 대여소번호       int64
# 대여소명       object
# 대여구분코드     object
# 성별         object
# 연령대코드      object
# 이용건수        int64
# 운동량       float64
# 탄소량       float64
# 이동거리      float64
# 사용시간        int64
# dtype: object

# %%
data2.dtypes
# Out:
# 대여일자      object
# 대여시간       int64
# 대여소번호      int64
# 대여소명      object
# 대여구분코드    object
# 성별        object
# 연령대코드     object
# 이용건수       int64
# 운동량       object
# 탄소량       object
# 이동거리       int64
# 사용시간       int64
# dtype: object

# %%
import ast

# %%
# data2['운동량'] = [ast.literal_eval(x) for x in data2['운동량']]
# data2['탄소량'] = [ast.literal_eval(x) for x in data2['탄소량']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-5aedcf434562> in <module>
# ----> 1 data2['운동량'] = [ast.literal_eval(x) for x in data2['운동량']]
#       2 data2['탄소량'] = [ast.literal_eval(x) for x in data2['탄소량']]
#
# <ipython-input-23-5aedcf434562> in <listcomp>(.0)
# ----> 1 data2['운동량'] = [ast.literal_eval(x) for x in data2['운동량']]
#       2 data2['탄소량'] = [ast.literal_eval(x) for x in data2['탄소량']]
#
# ~\anaconda3\envs\data-anal-env\lib\ast.py in literal_eval(node_or_string)
#      89                     return left - right
#      90         return _convert_signed_num(node)
# ---> 91     return _convert(node_or_string)
#      92
#      93
#
# ~\anaconda3\envs\data-anal-env\lib\ast.py in _convert(node)
#      88                 else:
#      89                     return left - right
# ---> 90         return _convert_signed_num(node)
# ...

# %%
data3 = pd.read_csv('data/서울특별시 공공자전거 시간대별 대여정보_201812_201905(3).csv', encoding = 'utf-8')
data3
# Out:
#               대여일자  대여시간  대여소번호                      대여소명 대여구분코드   성별 연령대코드  \
# 0       2019-04-13    17    104           104. 합정역 1번출구 앞    일일권    F   20대
# 1       2019-04-13    17   1601  1601. 석계역 문화광장 내 자전거 보관소    일일권    F   20대
# 2       2019-04-13    17   1637         1637. KT 노원점 건물 앞    일일권    F   20대
# 3       2019-04-13    17   1833   1833. 독산역 1번출구 앞 자전거보관소    일일권    F   20대
# 4       2019-04-13    17    215              215. 여의도고교 앞    일일권    F   20대
# ...            ...   ...    ...                       ...    ...  ...   ...
# 999995  2019-05-05    22   1297   1297. 석촌호수교차로(동호 팔각정 앞)    단체권  NaN   20대
# 999996  2019-05-05    22   2604             2604. 삼표레미콘 앞    단체권  NaN   20대
# 999997  2019-05-05    22   2183                2183. 동방1교    단체권  NaN   20대
# 999998  2019-05-05    22    147           147. 마포역 4번출구 뒤    단체권  NaN   20대
# 999999  2019-05-05    22    530            530. 청계벽산아파트 앞    단체권  NaN   20대
#
#         이용건수     운동량   탄소량     이동거리  사용시간
# ...

# %%
data3.dtypes
# Out:
# 대여일자       object
# 대여시간        int64
# 대여소번호       int64
# 대여소명       object
# 대여구분코드     object
# 성별         object
# 연령대코드      object
# 이용건수        int64
# 운동량        object
# 탄소량        object
# 이동거리      float64
# 사용시간        int64
# dtype: object

# %%
data4 = pd.read_csv('data/서울특별시 공공자전거 시간대별 대여정보_201812_201905(4).csv', encoding = 'utf-8')
data4
# Out:
#               대여일자  대여시간  대여소번호                    대여소명 대여구분코드   성별 연령대코드  \
# 0       2019-05-05    22    613       613. 신설동역 10번출구 앞    단체권  NaN   20대
# 1       2019-05-05    22    263          263. 근로자회관 사거리    단체권  NaN   20대
# 2       2019-05-05    22    816        816. 신용산역 6번출구 앞    단체권  NaN   20대
# 3       2019-05-05    22    204      204. 국회의사당역 5번출구 옆    단체권  NaN   20대
# 4       2019-05-05    22   1610       1610. 화랑대역 2번출구 앞    단체권  NaN   20대
# ...            ...   ...    ...                     ...    ...  ...   ...
# 999995  2019-05-24     9   1712         1712. 창동역공영주차장앞    정기권  NaN   20대
# 999996  2019-05-24     9   1814  1814. 두산위브아파트 옆 상가건물 앞    정기권  NaN   20대
# 999997  2019-05-24     9    220         220. 미성아파트 A동 앞    정기권  NaN   20대
# 999998  2019-05-24     9   1822       1822. 서울 시흥동우체국 앞    정기권  NaN   20대
# 999999  2019-05-24     9   1823          1823. 상신정비공업 앞    정기권  NaN   20대
#
#         이용건수     운동량   탄소량     이동거리  사용시간
# ...

# %%
data4.dtypes
# Out:
# 대여일자       object
# 대여시간        int64
# 대여소번호       int64
# 대여소명       object
# 대여구분코드     object
# 성별         object
# 연령대코드      object
# 이용건수        int64
# 운동량        object
# 탄소량        object
# 이동거리      float64
# 사용시간        int64
# dtype: object

# %%
data5 = pd.read_csv('data/서울특별시 공공자전거 시간대별 대여정보_201812_201905(5).csv', encoding = 'utf-8')
data5
# Out:
#               대여일자  대여시간  대여소번호                           대여소명 대여구분코드   성별  \
# 0       2019-05-24     9   1824                1824. 독산근린공원 입구    정기권  NaN
# 1       2019-05-24     9   1830                1830. 빅마켓 금천점 앞    정기권  NaN
# 2       2019-05-24     9   1831               1831. 메이퀸웨딩컨벤션 앞    정기권  NaN
# 3       2019-05-24     9   1833        1833. 독산역 1번출구 앞 자전거보관소    정기권  NaN
# 4       2019-05-24     9   1503            1503. 이디야 커피 수유역점 앞    정기권  NaN
# ...            ...   ...    ...                            ...    ...  ...
# 428521  2019-05-31    23    432                   432. 마포중앙도서관    단체권    F
# 428522  2019-05-31    23    133                     133. 해담는다리    단체권    F
# 428523  2019-05-31    23   3509                 3509. 세종사이버대학교    단체권    M
# 428524  2019-05-31    23   1235             1235. 잠실트리지움310동 옆    단체권    M
# 428525  2019-05-31    23   2219  2219. 고속터미널역 8-1번, 8-2번 출구 사이    단체권    M
#
#        연령대코드  이용건수      운동량   탄소량     이동거리  사용시간
# ...

# %%
data5.dtypes
# Out:
# 대여일자       object
# 대여시간        int64
# 대여소번호       int64
# 대여소명       object
# 대여구분코드     object
# 성별         object
# 연령대코드      object
# 이용건수        int64
# 운동량        object
# 탄소량        object
# 이동거리      float64
# 사용시간        int64
# dtype: object

# %%
data1 = data1[data1['대여일자']>='2019-01-01']
final_data = pd.concat([data1,data2,data3,data4,data5],ignore_index=True)
final_data
# Out:
#                대여일자  대여시간  대여소번호                           대여소명 대여구분코드 성별  \
# 0        2019-01-01     0    458                 458. 광화문역 5번출구    정기권  F
# 1        2019-01-01     0   2159                     2159. 인헌초교    정기권  F
# 2        2019-01-01     0   1362                1362. 보문역6번출구 앞    정기권  F
# 3        2019-01-01     0   3106                3106. 홍남교 두바퀴쉼터    정기권  F
# 4        2019-01-01     0    118               118. 광흥창역 2번출구 앞    정기권  F
# ...             ...   ...    ...                            ...    ... ..
# 3993748  2019-05-31    23    432                   432. 마포중앙도서관    단체권  F
# 3993749  2019-05-31    23    133                     133. 해담는다리    단체권  F
# 3993750  2019-05-31    23   3509                 3509. 세종사이버대학교    단체권  M
# 3993751  2019-05-31    23   1235             1235. 잠실트리지움310동 옆    단체권  M
# 3993752  2019-05-31    23   2219  2219. 고속터미널역 8-1번, 8-2번 출구 사이    단체권  M
#
#         연령대코드  이용건수      운동량   탄소량     이동거리  사용시간
# ...

# %%
import glob

# %%
path = './data/자전거정보'
all_files = glob.glob(path + "/서울특별시 공공자전거 이용정보(시간대별)*.csv")
ls = []
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    ls.append(df)
total_menu = pd.concat(ls, axis=0, ignore_index=True)
total_menu
# Out:
#                대여일자  대여시간  대여소번호                  대여소명 대여구분코드   성별 연령대코드  \
# 0        2019-06-01     0    740             740. 으뜸공원    정기권  NaN  ~10대
# 1        2019-06-01     0    951       951. 연신내역 6번출구옆    정기권  NaN  ~10대
# 2        2019-06-01     0    512      512. 뚝섬역 1번 출구 옆    정기권  NaN  ~10대
# 3        2019-06-01     0   1531     1531. 미아사거리 1번 출구    정기권  NaN  ~10대
# 4        2019-06-01     0   1656    1656. 중앙하이츠 아파트 입구    정기권  NaN  ~10대
# ...             ...   ...    ...                   ...    ...  ...   ...
# 9520645  2019-11-16    10    107  107. 신한은행 서교동금융센터점 앞    정기권  NaN   30대
# 9520646  2019-11-16    10   1925    1925. 동양미래대학교 정문 옆    정기권  NaN   30대
# 9520647  2019-11-16    10   2032      2032. 이수역 11번출구쪽    정기권  NaN   30대
# 9520648  2019-11-16    10   2034       2034. 사당역 7번출구쪽    정기권  NaN   30대
# 9520649  2019-11-16    10   1221     1221. 삼전사거리 포스코더샵    정기권  NaN   30대
#
#          이용건수     운동량   탄소량    이동거리  사용시간
# 0           1   42.91  0.40  1720.0    10
# ...

# %%
total_menu = total_menu.sort_values(by='대여일자', ascending=True)
total_menu
# Out:
#                대여일자  대여시간  대여소번호                    대여소명 대여구분코드   성별 연령대코드  \
# 0        2019-06-01     0    740               740. 으뜸공원    정기권  NaN  ~10대
# 39978    2019-06-01    18   1185             1185. 등촌9단지    정기권    F   20대
# 39979    2019-06-01    18   2509            2509. KT반포지사    정기권    F   20대
# 39980    2019-06-01    18   3533  3533. 건대입구역 사거리(롯데백화점)    정기권    F   20대
# 39981    2019-06-01    18   3536         3536. 중앙농협(자양동)    정기권    F   20대
# ...             ...   ...    ...                     ...    ...  ...   ...
# 1498537  2019-11-30    11    418     418. 월드컵경기장역 3번출구 옆    정기권    M   30대
# 1498536  2019-11-30    11   2148       2148. 낙성대역 3번출구 뒤    정기권    M   30대
# 1498535  2019-11-30    11    419             419. 홈플러스 앞    정기권    M   30대
# 1498565  2019-11-30    11   3535       3535. 중곡사거리(국민은행)    정기권    M   40대
# 1520648  2019-11-30    23    126           126. 서강대 후문 옆    단체권  NaN   20대
#
#          이용건수      운동량    탄소량     이동거리  사용시간
# ...

# %%
total_menu.dtypes
# Out:
# 대여일자       object
# 대여시간        int64
# 대여소번호       int64
# 대여소명       object
# 대여구분코드     object
# 성별         object
# 연령대코드      object
# 이용건수        int64
# 운동량        object
# 탄소량        object
# 이동거리      float64
# 사용시간        int64
# dtype: object

# %%
added_data = pd.read_csv('data/Bicycle_19_12.csv', encoding = 'utf-8')
added_data
# Out:
#               대여일자  대여시간  대여소번호                     대여소명 대여구분코드   성별 연령대코드  \
# 0       2019-12-01     0    504           504. 신자초교입구교차로    정기권  NaN  ~10대
# 1       2019-12-01     0   1029             1029. 롯데 시네마    정기권  NaN  ~10대
# 2       2019-12-01     0   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  NaN  ~10대
# 3       2019-12-01     0    512         512. 뚝섬역 1번 출구 옆    정기권  NaN  ~10대
# 4       2019-12-01     0   1528          1528. 삼각산동 주민센터    정기권  NaN  ~10대
# ...            ...   ...    ...                      ...    ...  ...   ...
# 776951  2019-12-31    23    544               544. 광남중학교    단체권  NaN  ~10대
# 776952  2019-12-31    23    337              337. 창경궁 입구    단체권  NaN   20대
# 776953  2019-12-31    23    428               428. 명보사거리    단체권    F   20대
# 776954  2019-12-31    23   1059    1059. 래미안 강동팰리스(102동)    단체권    M  ~10대
# 776955  2019-12-31    23   1235       1235. 잠실트리지움310동 옆    단체권    M   20대
#
#         이용건수     운동량   탄소량     이동거리  사용시간
# ...

# %%
final_df = pd.concat([final_data,total_menu,added_data],ignore_index=True)
final_df
# Out:
#                 대여일자  대여시간  대여소번호                   대여소명 대여구분코드   성별 연령대코드  \
# 0         2019-01-01     0    458         458. 광화문역 5번출구    정기권    F  ~10대
# 1         2019-01-01     0   2159             2159. 인헌초교    정기권    F   20대
# 2         2019-01-01     0   1362        1362. 보문역6번출구 앞    정기권    F   20대
# 3         2019-01-01     0   3106        3106. 홍남교 두바퀴쉼터    정기권    F   20대
# 4         2019-01-01     0    118       118. 광흥창역 2번출구 앞    정기권    F   20대
# ...              ...   ...    ...                    ...    ...  ...   ...
# 14291354  2019-12-31    23    544             544. 광남중학교    단체권  NaN  ~10대
# 14291355  2019-12-31    23    337            337. 창경궁 입구    단체권  NaN   20대
# 14291356  2019-12-31    23    428             428. 명보사거리    단체권    F   20대
# 14291357  2019-12-31    23   1059  1059. 래미안 강동팰리스(102동)    단체권    M  ~10대
# 14291358  2019-12-31    23   1235     1235. 잠실트리지움310동 옆    단체권    M   20대
#
#           이용건수     운동량   탄소량     이동거리  사용시간
# ...

# %%
import pandas as pd
# df["'대여일자'"] = df["'대여일자'"].apply(lambda x: str(x)[1:-1])
df = pd.read_csv('data/bicycle2017.csv', encoding = 'utf-8')
df.columns = ['man','대여일자','대여시간','대여소번호','대여소','대여구분코드','성별','연령대코드','이용건수','운동량','탄소량','이동거리(M)','사용시간(분)']
del df['man']

# %%
df
# Out:
#                  대여일자  대여시간   대여소번호                 대여소     대여구분코드   성별  \
# 0        '2017-01-01'  '00'   '230'      ' 영등포구청역 1번출구'       '정기'  'F'
# 1        '2017-01-01'  '00'   '315'     ' 신한은행 안국역지점 옆'       '정기'  'F'
# 2        '2017-01-01'  '00'   '328'           ' 탑골공원 앞'       '정기'  'F'
# 3        '2017-01-01'  '00'   '175'            ' 홍연2교옆'       '정기'  'F'
# 4        '2017-01-01'  '00'   '817'      ' 삼각지역 4번출구 앞'       '정기'  'F'
# ...               ...   ...     ...                 ...        ...  ...
# 4196227  '2017-12-31'  '23'   '502'    ' 뚝섬유원지역 1번출구 앞'  '일일(비회원)'   ''
# 4196228  '2017-12-31'  '23'   '512'      ' 뚝섬역 1번 출구 옆'  '일일(비회원)'  'M'
# 4196229  '2017-12-31'  '23'  '1022'      ' 길동 사거리(초소앞)'       '단체'  'F'
# 4196230  '2017-12-31'  '23'   '540'  ' 군자역 7번출구 베스트샵 앞'       '단체'  'M'
# 4196231  '2017-12-31'  '23'  '1245'         ' 문정 법조단지9'       '단체'  'M'
#
#           연령대코드  이용건수     운동량   탄소량  이동거리(M)  사용시간(분)
# ...

# %%
df[df['연령대코드']=="'a'"]
# Out:
# Empty DataFrame
# Columns: [대여일자, 대여시간, 대여소번호, 대여소, 대여구분코드, 성별, 연령대코드, 이용건수, 운동량, 탄소량, 이동거리(M), 사용시간(분)]
# Index: []

# %%
for i in range(7):
    df[df.columns[i]] = df[df.columns[i]].apply(lambda x: str(x)[1:-1])

# %%
df.to_csv("test.csv")

# %%
df.dtypes
# Out:
# 대여일자        object
# 대여시간        object
# 대여소번호       object
# 대여소         object
# 대여구분코드      object
# 성별          object
# 연령대코드       object
# 이용건수         int64
# 운동량        float64
# 탄소량        float64
# 이동거리(M)      int64
# 사용시간(분)      int64
# dtype: object

# %%
final_df.dtypes
# Out:
# 대여일자       object
# 대여시간        int64
# 대여소번호       int64
# 대여소명       object
# 대여구분코드     object
# 성별         object
# 연령대코드      object
# 이용건수        int64
# 운동량        object
# 탄소량        object
# 이동거리      float64
# 사용시간        int64
# dtype: object

# %%
final_df
# Out:
#                 대여일자  대여시간  대여소번호                   대여소명 대여구분코드   성별 연령대코드  \
# 0         2019-01-01     0    458         458. 광화문역 5번출구    정기권    F  ~10대
# 1         2019-01-01     0   2159             2159. 인헌초교    정기권    F   20대
# 2         2019-01-01     0   1362        1362. 보문역6번출구 앞    정기권    F   20대
# 3         2019-01-01     0   3106        3106. 홍남교 두바퀴쉼터    정기권    F   20대
# 4         2019-01-01     0    118       118. 광흥창역 2번출구 앞    정기권    F   20대
# ...              ...   ...    ...                    ...    ...  ...   ...
# 14291354  2019-12-31    23    544             544. 광남중학교    단체권  NaN  ~10대
# 14291355  2019-12-31    23    337            337. 창경궁 입구    단체권  NaN   20대
# 14291356  2019-12-31    23    428             428. 명보사거리    단체권    F   20대
# 14291357  2019-12-31    23   1059  1059. 래미안 강동팰리스(102동)    단체권    M  ~10대
# 14291358  2019-12-31    23   1235     1235. 잠실트리지움310동 옆    단체권    M   20대
#
#           이용건수     운동량   탄소량     이동거리  사용시간
# ...

# %%
final_df['사용시간'].groupby(final_df['성별']).count()
# Out:
# 성별
# F    2625183
# M    4481939
# f       3737
# m       5832
# Name: 사용시간, dtype: int64

# %%
final_df[(final_df['성별']=='f')|(final_df['성별']=='m')]
# Out:
#                 대여일자  대여시간  대여소번호                   대여소명 대여구분코드 성별 연령대코드  \
# 4592471   2019-06-12    18    311            311. 서울광장 옆    정기권  f   50대
# 4592655   2019-06-12    18   1008  1008. 암사역 3번출구(국민은행앞)    정기권  f   40대
# 4592789   2019-06-12    18   1530            1530. 광산사거리    정기권  m   20대
# 4592819   2019-06-12    18   1412           1412. 면목초등학교    정기권  m  ~10대
# 4593109   2019-06-12    18   1336           1336. 성북3교 위    정기권  m   50대
# ...              ...   ...    ...                    ...    ... ..   ...
# 14285016  2019-12-31    16    807      807. 서울역 12번 출구 앞    정기권  f   20대
# 14287470  2019-12-31    18    155        155. 가좌역1 번출구 뒤    정기권  f   30대
# 14287625  2019-12-31    18    134           134. 연세로 명물길    정기권  m   20대
# 14289293  2019-12-31    20    949       949. 연신내역 1번 출구     정기권  m   20대
# 14290006  2019-12-31    21    905         905. 구파발역 2번출구    정기권  m   20대
#
#           이용건수     운동량   탄소량    이동거리  사용시간
# 4592471      1    0.00  0.00     0.0    38
# ...

# %%
zzzzz
jinsu_df = final_df

# %%
jinsu_df['사용시간'].groupby(jinsu_df['성별']).count()
# Out:
# 성별
# F    2625183
# M    4481939
# f       3737
# m       5832
# Name: 사용시간, dtype: int64

# %%
jinsu_df['성별'] = np.where(jinsu_df['성별']=='f','F',jinsu_df['성별'])
jinsu_df['성별'] = np.where(jinsu_df['성별']=='m','M',jinsu_df['성별'])

jinsu_df
# Out:
#                 대여일자  대여시간  대여소번호                   대여소명 대여구분코드   성별 연령대코드  \
# 0         2019-01-01     0    458         458. 광화문역 5번출구    정기권    F  ~10대
# 1         2019-01-01     0   2159             2159. 인헌초교    정기권    F   20대
# 2         2019-01-01     0   1362        1362. 보문역6번출구 앞    정기권    F   20대
# 3         2019-01-01     0   3106        3106. 홍남교 두바퀴쉼터    정기권    F   20대
# 4         2019-01-01     0    118       118. 광흥창역 2번출구 앞    정기권    F   20대
# ...              ...   ...    ...                    ...    ...  ...   ...
# 14291354  2019-12-31    23    544             544. 광남중학교    단체권  NaN  ~10대
# 14291355  2019-12-31    23    337            337. 창경궁 입구    단체권  NaN   20대
# 14291356  2019-12-31    23    428             428. 명보사거리    단체권    F   20대
# 14291357  2019-12-31    23   1059  1059. 래미안 강동팰리스(102동)    단체권    M  ~10대
# 14291358  2019-12-31    23   1235     1235. 잠실트리지움310동 옆    단체권    M   20대
#
#           이용건수     운동량   탄소량     이동거리  사용시간
# ...

# %%
jinsu_df['년월'] = [x[:7] for x in jinsu_df['대여일자']]
jinsu_df
# Out:
#                 대여일자  대여시간  대여소번호                   대여소명 대여구분코드   성별 연령대코드  \
# 0         2019-01-01     0    458         458. 광화문역 5번출구    정기권    F  ~10대
# 1         2019-01-01     0   2159             2159. 인헌초교    정기권    F   20대
# 2         2019-01-01     0   1362        1362. 보문역6번출구 앞    정기권    F   20대
# 3         2019-01-01     0   3106        3106. 홍남교 두바퀴쉼터    정기권    F   20대
# 4         2019-01-01     0    118       118. 광흥창역 2번출구 앞    정기권    F   20대
# ...              ...   ...    ...                    ...    ...  ...   ...
# 14291354  2019-12-31    23    544             544. 광남중학교    단체권  NaN  ~10대
# 14291355  2019-12-31    23    337            337. 창경궁 입구    단체권  NaN   20대
# 14291356  2019-12-31    23    428             428. 명보사거리    단체권    F   20대
# 14291357  2019-12-31    23   1059  1059. 래미안 강동팰리스(102동)    단체권    M  ~10대
# 14291358  2019-12-31    23   1235     1235. 잠실트리지움310동 옆    단체권    M   20대
#
#           이용건수     운동량   탄소량     이동거리  사용시간       년월
# ...

# %%
final_df
# Out:
#                 대여일자  대여시간  대여소번호                   대여소명 대여구분코드   성별 연령대코드  \
# 0         2019-01-01     0    458         458. 광화문역 5번출구    정기권    F  ~10대
# 1         2019-01-01     0   2159             2159. 인헌초교    정기권    F   20대
# 2         2019-01-01     0   1362        1362. 보문역6번출구 앞    정기권    F   20대
# 3         2019-01-01     0   3106        3106. 홍남교 두바퀴쉼터    정기권    F   20대
# 4         2019-01-01     0    118       118. 광흥창역 2번출구 앞    정기권    F   20대
# ...              ...   ...    ...                    ...    ...  ...   ...
# 14291354  2019-12-31    23    544             544. 광남중학교    단체권  NaN  ~10대
# 14291355  2019-12-31    23    337            337. 창경궁 입구    단체권  NaN   20대
# 14291356  2019-12-31    23    428             428. 명보사거리    단체권    F   20대
# 14291357  2019-12-31    23   1059  1059. 래미안 강동팰리스(102동)    단체권    M  ~10대
# 14291358  2019-12-31    23   1235     1235. 잠실트리지움310동 옆    단체권    M   20대
#
#           이용건수     운동량   탄소량     이동거리  사용시간       년월
# ...

# %%
jinsu_df['사용시간'].groupby(jinsu_df['년월']).count()
# Out:
# 년월
# 2019-01     292732
# 2019-02     277530
# 2019-03     532335
# 2019-04    1197464
# 2019-05    1693692
# 2019-06    1736613
# 2019-07    1645259
# 2019-08    1532322
# 2019-09    1544480
# 2019-10    1817795
# 2019-11    1244181
# 2019-12     776956
# Name: 사용시간, dtype: int64

# %%
jinsu_df['연령대코드'] = np.where(jinsu_df['연령대코드']=='~10대','10대이하',jinsu_df['연령대코드'])
jinsu_df['연령대코드'] = np.where(jinsu_df['연령대코드']=='70대~','70대이상',jinsu_df['연령대코드'])

grouped_data = jinsu_df.groupby(['년월', '연령대코드'])['사용시간']
grouped_data.agg(['mean','std','sum'])
# Out:
#                     mean        std       sum
# 년월      연령대코드
# 2019-01 10대이하  20.338958  37.637306     40983
#         20대    18.531429  26.084058   1985865
#         30대    19.194818  24.215903   1585991
#         40대    21.152071  26.518230   1214150
#         50대    20.524811  25.524389    659729
#         60대    23.657755  25.607856    205302
#         70대이상  21.409679  23.352758     57956
# 2019-02 10대이하  23.959154  29.844646     48685
#         20대    21.423799  28.535461   2277457
#         30대    21.351000  28.166616   1655279
#         40대    22.590053  27.606481   1178252
#         50대    21.825579  24.929608    640297
#         60대    25.251139  27.010696    193954
#         70대이상  23.487149  24.930213     58483
# 2019-03 10대이하  27.049785  41.804830    189078
#         20대    24.559682  33.123623   5608621
#         30대    23.499208  28.585287   3293320
#         40대    24.100127  28.790562   2177085
#         50대    22.948156  26.155039   1149083
# ...

# %%
import googlemaps

# %%
gmaps_key = "AIzaSyBQj_mdpMJcgLdXQ9-4cuqDFgUd62KwisM"
gmaps = googlemaps.Client(key=gmaps_key)

# %%
del jinsu_df['대여구분코드']
del jinsu_df['이용건수']
jinsu_df
# Out:
#                 대여일자  대여시간  대여소번호                   대여소명   성별  연령대코드     운동량  \
# 0         2019-01-01     0    458         458. 광화문역 5번출구    F  10대이하   41.96
# 1         2019-01-01     0   2159             2159. 인헌초교    F    20대   27.23
# 2         2019-01-01     0   1362        1362. 보문역6번출구 앞    F    20대   20.18
# 3         2019-01-01     0   3106        3106. 홍남교 두바퀴쉼터    F    20대    7.48
# 4         2019-01-01     0    118       118. 광흥창역 2번출구 앞    F    20대    25.7
# ...              ...   ...    ...                    ...  ...    ...     ...
# 14291354  2019-12-31    23    544             544. 광남중학교  NaN  10대이하  340.36
# 14291355  2019-12-31    23    337            337. 창경궁 입구  NaN    20대  106.35
# 14291356  2019-12-31    23    428             428. 명보사거리    F    20대   77.82
# 14291357  2019-12-31    23   1059  1059. 래미안 강동팰리스(102동)    M  10대이하  179.67
# 14291358  2019-12-31    23   1235     1235. 잠실트리지움310동 옆    M    20대  285.44
#
#            탄소량     이동거리  사용시간       년월
# ...

# %%
index = jinsu_df.loc[0,'대여소명']

# %%
jinsu_100df = jinsu_df.loc[0:100,:]

# %%
jinsu_100df
# Out:
#            대여일자  대여시간  대여소번호                        대여소명 성별  연령대코드      운동량  \
# 0    2019-01-01     0    458              458. 광화문역 5번출구  F  10대이하    41.96
# 1    2019-01-01     0   2159                  2159. 인헌초교  F    20대    27.23
# 2    2019-01-01     0   1362             1362. 보문역6번출구 앞  F    20대    20.18
# 3    2019-01-01     0   3106             3106. 홍남교 두바퀴쉼터  F    20대     7.48
# 4    2019-01-01     0    118            118. 광흥창역 2번출구 앞  F    20대     25.7
# 5    2019-01-01     0    555               555. 구의3동주민센터  F    20대    86.55
# 6    2019-01-01     0   1709            1709. 쌍문역4번출구 주변  F    20대     15.7
# 7    2019-01-01     0   2140              2140. 신림1교 교차로  F    20대    30.93
# 8    2019-01-01     0   2145             2145. 은천초등학교 육교  F    20대     27.8
# 9    2019-01-01     0   1241              1241. 문정 법조단지5  F    20대    65.12
# 10   2019-01-01     0   1246             1246. 문정 법조단지10  F    20대    21.61
# ...

# %%
address=[]
for n in jinsu_df.index:
    length = len(str(jinsu_df['대여소번호'][n]))
    string = '서울특별시' + jinsu_df['대여소명'][n][length+1:]
    address.append(string)

# %%
jinsu_df['수정된주소']=address
jinsu_df
# Out:
#                 대여일자  대여시간  대여소번호                   대여소명   성별  연령대코드     운동량  \
# 0         2019-01-01     0    458         458. 광화문역 5번출구    F  10대이하   41.96
# 1         2019-01-01     0   2159             2159. 인헌초교    F    20대   27.23
# 2         2019-01-01     0   1362        1362. 보문역6번출구 앞    F    20대   20.18
# 3         2019-01-01     0   3106        3106. 홍남교 두바퀴쉼터    F    20대    7.48
# 4         2019-01-01     0    118       118. 광흥창역 2번출구 앞    F    20대    25.7
# ...              ...   ...    ...                    ...  ...    ...     ...
# 14291354  2019-12-31    23    544             544. 광남중학교  NaN  10대이하  340.36
# 14291355  2019-12-31    23    337            337. 창경궁 입구  NaN    20대  106.35
# 14291356  2019-12-31    23    428             428. 명보사거리    F    20대   77.82
# 14291357  2019-12-31    23   1059  1059. 래미안 강동팰리스(102동)    M  10대이하  179.67
# 14291358  2019-12-31    23   1235     1235. 잠실트리지움310동 옆    M    20대  285.44
#
# ...

# %%
del jinsu_df['대여소번호']
del jinsu_df['대여소명']
jinsu_df
# Out:
#                 대여일자  대여시간   성별  연령대코드     운동량   탄소량     이동거리  사용시간       년월  \
# 0         2019-01-01     0    F  10대이하   41.96  0.38   1630.0    29  2019-01
# 1         2019-01-01     0    F    20대   27.23  0.29   1250.0     7  2019-01
# 2         2019-01-01     0    F    20대   20.18  0.23    980.0     5  2019-01
# 3         2019-01-01     0    F    20대    7.48   0.1    420.0     4  2019-01
# 4         2019-01-01     0    F    20대    25.7  0.26   1100.0     7  2019-01
# ...              ...   ...  ...    ...     ...   ...      ...   ...      ...
# 14291354  2019-12-31    23  NaN  10대이하  340.36  3.12  13430.0   146  2019-12
# 14291355  2019-12-31    23  NaN    20대  106.35  0.87   3730.0    26  2019-12
# 14291356  2019-12-31    23    F    20대   77.82  0.91   3930.0    62  2019-12
# 14291357  2019-12-31    23    M  10대이하  179.67  1.62   6980.0   116  2019-12
# 14291358  2019-12-31    23    M    20대  285.44  1.97   8480.0   107  2019-12
#
#                           수정된주소
# ...

# %%
jinsu_df
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\anaconda3\envs\data-anal-env\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~\anaconda3\envs\data-anal-env\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# ...

# %%
data2 = pd.read_csv('data/최종작업파일/2018_bicycle.csv', encoding = 'utf-8')
data2
# Out:
# C:\Users\BIT\anaconda3\envs\data-anal-env\lib\site-packages\IPython\core\interactiveshell.py:3166: DtypeWarning: Columns (1,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          Unnamed: 0        대여일자  대여시간   대여소번호                 대여소명 대여구분코드  성별  \
# 0                 0  01/01/2018   0.0   300.0                정동사거리    정기권   F
# 1                 1  01/01/2018   0.0   505.0       자양사거리 광진아크로텔 앞    정기권   F
# 2                 2  01/01/2018   0.0  1531.0          미아사거리 1번 출구    정기권   F
# 3                 3  01/01/2018   0.0   516.0              광진메디칼 앞    정기권   F
# 4                 4  01/01/2018   0.0  3508.0                화양사거리    정기권   F
# ...             ...         ...   ...     ...                  ...    ...  ..
# 8692601     8692601  2018-12-31  23.0  1623.0        1623. 노원 구민회관    일일권   M
# 8692602     8692602  2018-12-31  23.0   394.0      394. 경희궁 자이 3단지    일일권   M
# ...

# %%
del data2['Unnamed: 0']

# %%
data2.head()
# Out:
#          대여일자  대여시간   대여소번호             대여소명 대여구분코드 성별 연령대코드  이용건수    운동량  \
# 0  01/01/2018   0.0   300.0            정동사거리    정기권  F  ~10대   1.0  37.32
# 1  01/01/2018   0.0   505.0   자양사거리 광진아크로텔 앞    정기권  F   20대   1.0  54.83
# 2  01/01/2018   0.0  1531.0      미아사거리 1번 출구    정기권  F   20대   1.0  78.34
# 3  01/01/2018   0.0   516.0          광진메디칼 앞    정기권  F   20대   1.0  29.95
# 4  01/01/2018   0.0  3508.0            화양사거리    정기권  F   20대   1.0  46.09
#
#     탄소량    이동거리  사용시간       연월
# 0  0.34  1450.0  23.0  2018-01
# 1  0.49  2130.0  15.0  2018-01
# 2  0.73  3140.0  17.0  2018-01
# 3  0.29  1240.0   5.0  2018-01
# 4  0.45  1940.0  43.0  2018-01

# %%
data2.tail()
# Out:
#                대여일자  대여시간   대여소번호              대여소명 대여구분코드 성별 연령대코드  이용건수  \
# 7500786  20/11/2018  23.0  1452.0           겸재교 진입부    일일권  M   30대   1.0
# 7500787  20/11/2018  23.0  2177.0        신대방역 2번 출구    일일권  M   30대   1.0
# 7500788  20/11/2018  23.0   129.0   신촌역(2호선) 6번출구 옆    일일권  M   30대   1.0
# 7500789  20/11/2018  23.0   185.0         마포 신수공원 앞    일일권  M   30대   2.0
# 7500790  20/11/2018  23.0  1248.0            방이초등학교    일일권  M   30대   1.0
#
#             운동량   탄소량     이동거리  사용시간       연월
# 7500786  314.82  2.46  10600.0  42.0  2018-11
# 7500787   96.23  0.75   3240.0  18.0  2018-11
# 7500788   36.07  0.32   1380.0   7.0  2018-11
# 7500789  241.18  2.17   9370.0  86.0  2018-11
# 7500790  124.48  0.93   4030.0  16.0  2018-11

# %%
data2['연월'] = [x[-4:] +'-' + x[3:5] for x in data2['대여일자']]

# %%
data2.head()
# Out:
#          대여일자  대여시간   대여소번호             대여소명 대여구분코드 성별 연령대코드  이용건수    운동량  \
# 0  01/01/2018   0.0   300.0            정동사거리    정기권  F  ~10대   1.0  37.32
# 1  01/01/2018   0.0   505.0   자양사거리 광진아크로텔 앞    정기권  F   20대   1.0  54.83
# 2  01/01/2018   0.0  1531.0      미아사거리 1번 출구    정기권  F   20대   1.0  78.34
# 3  01/01/2018   0.0   516.0          광진메디칼 앞    정기권  F   20대   1.0  29.95
# 4  01/01/2018   0.0  3508.0            화양사거리    정기권  F   20대   1.0  46.09
#
#     탄소량    이동거리  사용시간       연월
# 0  0.34  1450.0  23.0  2018-01
# 1  0.49  2130.0  15.0  2018-01
# 2  0.73  3140.0  17.0  2018-01
# 3  0.29  1240.0   5.0  2018-01
# 4  0.45  1940.0  43.0  2018-01

# %%
data2['연월'].unique()
# Out:
# array(['2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06',
#        '2018-07', '2018-08', '2018-09', '2018-10', '2018-11'],
#       dtype=object)

# %%
data2['대여시간'].isnull().sum()
# Out:
# 0

# %%
data2.tail(100)
# Out:
#          Unnamed: 0        대여일자  대여시간   대여소번호              대여소명 대여구분코드 성별  \
# 7500691     7500691  20/11/2018  23.0   105.0        합정역 5번출구 앞    정기권  M
# 7500692     7500692  20/11/2018  23.0   226.0        샛강역 1번출구 앞    정기권  M
# 7500693     7500693  20/11/2018  23.0  2259.0   잠원역 3번-4번 출구사이     정기권  M
# 7500694     7500694  20/11/2018  23.0  2332.0           선릉역3번출구    정기권  M
# 7500695     7500695  20/11/2018  23.0   421.0            마포구청 앞    정기권  M
# ...             ...         ...   ...     ...               ...    ... ..
# 7500786     7500786  20/11/2018  23.0  1452.0           겸재교 진입부    일일권  M
# 7500787     7500787  20/11/2018  23.0  2177.0        신대방역 2번 출구    일일권  M
# 7500788     7500788  20/11/2018  23.0   129.0   신촌역(2호선) 6번출구 옆    일일권  M
# 7500789     7500789  20/11/2018  23.0   185.0         마포 신수공원 앞    일일권  M
# 7500790     7500790  20/11/2018  23.0  1248.0            방이초등학교    일일권  M
#
#         연령대코드  이용건수     운동량   탄소량     이동거리  사용시간       연월
# ...
