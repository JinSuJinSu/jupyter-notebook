# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17928557524517912504
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 4986830848
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 13400193258751746928
# physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1660 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5"
# ]

# %%
import cv2, sys
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image, ImageEnhance, ImageChops
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
import os
import datetime
import time, random
from tqdm import tqdm

# %%
#  필터링에 필요한 이미지를 받아온다.

image_general = cv2.imread("D:/original_image/genreal/super_general_0_2281.jpg", cv2.IMREAD_UNCHANGED)
image_gray_general = cv2.imread("D:/original_image/genreal/super_general_0_2281.jpg", cv2.IMREAD_GRAYSCALE)


cv2.imshow('image', image_general)
cv2.imshow('image_gray', image_gray_general)
cv2.waitKey(3)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13832/3037312666.py in <module>
#       3
#       4
# ----> 5 cv2.imshow('image', image_general)
#       6 cv2.imshow('image_gray', image_gray_general)
#       7 cv2.waitKey(0)
#
# error: OpenCV(4.5.3) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-c2l3r8zm\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
# Numpy 값이 어떻게 분포되어 있는지 확인한다.
plt.hist(image_gray_general.ravel(), 256, [0, 256])
plt.show()

# %%
# 가우시간 기법에 필요한 과정 중의 하나
blur_general = cv2.GaussianBlur(image_gray_general, ksize=(3,3), sigmaX=1)
ret, thresh1 = cv2.threshold(blur_general, 150, 255, cv2.THRESH_BINARY)

cv2.imshow('thresh1', thresh1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
edged_general = cv2.Canny(thresh1, 10, 255)
contour_general = image_general.copy()

cv2.imshow('edged_general', edged_general)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5,5))
closed_general = cv2.morphologyEx(edged_general, cv2.MORPH_CLOSE , kernel)

contours, hierarchy = cv2.findContours(closed_general,cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
final_result = cv2.drawContours(contour_general, contours, -1, (0,255,0), 3)

cv2.imshow('final_result', final_result)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# 폴더 이름을 리스트 형태로 띄워준다.
folder = "D:/original_image/tapgol_park"
file_list = [x for x in os.listdir(folder)]

# %%
file_list
# Out:
# ['super_tapgol_park1.jpg',
#  'super_tapgol_park10.jpg',
#  'super_tapgol_park100.jpg',
#  'super_tapgol_park1000.jpg',
#  'super_tapgol_park101.jpg',
#  'super_tapgol_park102.jpg',
#  'super_tapgol_park103.jpg',
#  'super_tapgol_park104.jpg',
#  'super_tapgol_park105.jpg',
#  'super_tapgol_park106.jpg',
#  'super_tapgol_park107.jpg',
#  'super_tapgol_park108.jpg',
#  'super_tapgol_park109.jpg',
#  'super_tapgol_park11.jpg',
#  'super_tapgol_park110.jpg',
#  'super_tapgol_park111.jpg',
#  'super_tapgol_park112.jpg',
#  'super_tapgol_park113.jpg',
#  'super_tapgol_park114.jpg',
#  'super_tapgol_park115.jpg',
#  'super_tapgol_park116.jpg',
#  'super_tapgol_park117.jpg',
#  'super_tapgol_park118.jpg',
#  'super_tapgol_park119.jpg',
#  'super_tapgol_park12.jpg',
#  'super_tapgol_park120.jpg',
#  'super_tapgol_park121.jpg',
#  'super_tapgol_park122.jpg',
#  'super_tapgol_park123.jpg',
#  'super_tapgol_park124.jpg',
#  'super_tapgol_park125.jpg',
#  'super_tapgol_park126.jpg',
#  'super_tapgol_park127.jpg',
#  'super_tapgol_park128.jpg',
#  'super_tapgol_park129.jpg',
#  'super_tapgol_park13.jpg',
#  'super_tapgol_park130.jpg',
#  'super_tapgol_park131.jpg',
#  'super_tapgol_park132.jpg',
#  'super_tapgol_park133.jpg',
#  'super_tapgol_park134.jpg',
#  'super_tapgol_park135.jpg',
#  'super_tapgol_park136.jpg',
#  'super_tapgol_park137.jpg',
#  'super_tapgol_park138.jpg',
#  'super_tapgol_park139.jpg',
#  'super_tapgol_park14.jpg',
#  'super_tapgol_park140.jpg',
#  'super_tapgol_park141.jpg',
#  'super_tapgol_park142.jpg',
#  'super_tapgol_park143.jpg',
#  'super_tapgol_park144.jpg',
#  'super_tapgol_park145.jpg',
#  'super_tapgol_park146.jpg',
#  'super_tapgol_park147.jpg',
#  'super_tapgol_park148.jpg',
#  'super_tapgol_park149.jpg',
#  'super_tapgol_park15.jpg',
#  'super_tapgol_park150.jpg',
#  'super_tapgol_park151.jpg',
#  'super_tapgol_park152.jpg',
#  'super_tapgol_park153.jpg',
#  'super_tapgol_park154.jpg',
#  'super_tapgol_park155.jpg',
#  'super_tapgol_park156.jpg',
#  'super_tapgol_park157.jpg',
#  'super_tapgol_park158.jpg',
#  'super_tapgol_park159.jpg',
#  'super_tapgol_park16.jpg',
#  'super_tapgol_park160.jpg',
#  'super_tapgol_park161.jpg',
#  'super_tapgol_park162.jpg',
#  'super_tapgol_park163.jpg',
#  'super_tapgol_park164.jpg',
#  'super_tapgol_park165.jpg',
#  'super_tapgol_park166.jpg',
#  'super_tapgol_park167.jpg',
#  'super_tapgol_park168.jpg',
#  'super_tapgol_park169.jpg',
#  'super_tapgol_park17.jpg',
#  'super_tapgol_park170.jpg',
#  'super_tapgol_park171.jpg',
#  'super_tapgol_park172.jpg',
#  'super_tapgol_park173.jpg',
#  'super_tapgol_park174.jpg',
#  'super_tapgol_park175.jpg',
#  'super_tapgol_park176.jpg',
#  'super_tapgol_park177.jpg',
#  'super_tapgol_park178.jpg',
#  'super_tapgol_park179.jpg',
#  'super_tapgol_park18.jpg',
#  'super_tapgol_park180.jpg',
#  'super_tapgol_park181.jpg',
#  'super_tapgol_park182.jpg',
#  'super_tapgol_park183.jpg',
#  'super_tapgol_park184.jpg',
#  'super_tapgol_park185.jpg',
#  'super_tapgol_park186.jpg',
#  'super_tapgol_park187.jpg',
#  'super_tapgol_park188.jpg',
#  'super_tapgol_park189.jpg',
#  'super_tapgol_park19.jpg',
#  'super_tapgol_park190.jpg',
#  'super_tapgol_park191.jpg',
#  'super_tapgol_park192.jpg',
#  'super_tapgol_park193.jpg',
#  'super_tapgol_park194.jpg',
#  'super_tapgol_park195.jpg',
#  'super_tapgol_park196.jpg',
#  'super_tapgol_park197.jpg',
#  'super_tapgol_park198.jpg',
#  'super_tapgol_park199.jpg',
#  'super_tapgol_park2.jpg',
#  'super_tapgol_park20.jpg',
#  'super_tapgol_park200.jpg',
#  'super_tapgol_park201.jpg',
#  'super_tapgol_park202.jpg',
#  'super_tapgol_park203.jpg',
#  'super_tapgol_park204.jpg',
#  'super_tapgol_park205.jpg',
#  'super_tapgol_park206.jpg',
#  'super_tapgol_park207.jpg',
#  'super_tapgol_park208.jpg',
#  'super_tapgol_park209.jpg',
#  'super_tapgol_park21.jpg',
#  'super_tapgol_park210.jpg',
#  'super_tapgol_park211.jpg',
#  'super_tapgol_park212.jpg',
#  'super_tapgol_park213.jpg',
#  'super_tapgol_park214.jpg',
#  'super_tapgol_park215.jpg',
#  'super_tapgol_park216.jpg',
#  'super_tapgol_park217.jpg',
#  'super_tapgol_park218.jpg',
#  'super_tapgol_park219.jpg',
#  'super_tapgol_park22.jpg',
#  'super_tapgol_park220.jpg',
#  'super_tapgol_park221.jpg',
#  'super_tapgol_park222.jpg',
#  'super_tapgol_park223.jpg',
#  'super_tapgol_park224.jpg',
#  'super_tapgol_park225.jpg',
#  'super_tapgol_park226.jpg',
#  'super_tapgol_park227.jpg',
#  'super_tapgol_park228.jpg',
#  'super_tapgol_park229.jpg',
#  'super_tapgol_park23.jpg',
#  'super_tapgol_park230.jpg',
#  'super_tapgol_park231.jpg',
#  'super_tapgol_park232.jpg',
#  'super_tapgol_park233.jpg',
#  'super_tapgol_park234.jpg',
#  'super_tapgol_park235.jpg',
#  'super_tapgol_park236.jpg',
#  'super_tapgol_park237.jpg',
#  'super_tapgol_park238.jpg',
#  'super_tapgol_park239.jpg',
#  'super_tapgol_park24.jpg',
#  'super_tapgol_park240.jpg',
#  'super_tapgol_park241.jpg',
#  'super_tapgol_park242.jpg',
#  'super_tapgol_park243.jpg',
#  'super_tapgol_park244.jpg',
#  'super_tapgol_park245.jpg',
#  'super_tapgol_park246.jpg',
#  'super_tapgol_park247.jpg',
#  'super_tapgol_park248.jpg',
#  'super_tapgol_park249.jpg',
#  'super_tapgol_park25.jpg',
#  'super_tapgol_park250.jpg',
#  'super_tapgol_park251.jpg',
#  'super_tapgol_park252.jpg',
#  'super_tapgol_park253.jpg',
#  'super_tapgol_park254.jpg',
#  'super_tapgol_park255.jpg',
#  'super_tapgol_park256.jpg',
#  'super_tapgol_park257.jpg',
#  'super_tapgol_park258.jpg',
#  'super_tapgol_park259.jpg',
#  'super_tapgol_park26.jpg',
#  'super_tapgol_park260.jpg',
#  'super_tapgol_park261.jpg',
#  'super_tapgol_park262.jpg',
#  'super_tapgol_park263.jpg',
#  'super_tapgol_park264.jpg',
#  'super_tapgol_park265.jpg',
#  'super_tapgol_park266.jpg',
#  'super_tapgol_park267.jpg',
#  'super_tapgol_park268.jpg',
#  'super_tapgol_park269.jpg',
#  'super_tapgol_park27.jpg',
#  'super_tapgol_park270.jpg',
#  'super_tapgol_park271.jpg',
#  'super_tapgol_park272.jpg',
#  'super_tapgol_park273.jpg',
#  'super_tapgol_park274.jpg',
#  'super_tapgol_park275.jpg',
#  'super_tapgol_park276.jpg',
#  'super_tapgol_park277.jpg',
#  'super_tapgol_park278.jpg',
#  'super_tapgol_park279.jpg',
#  'super_tapgol_park28.jpg',
#  'super_tapgol_park280.jpg',
#  'super_tapgol_park281.jpg',
#  'super_tapgol_park282.jpg',
#  'super_tapgol_park283.jpg',
#  'super_tapgol_park284.jpg',
#  'super_tapgol_park285.jpg',
#  'super_tapgol_park286.jpg',
#  'super_tapgol_park287.jpg',
#  'super_tapgol_park288.jpg',
#  'super_tapgol_park289.jpg',
#  'super_tapgol_park29.jpg',
#  'super_tapgol_park290.jpg',
#  'super_tapgol_park291.jpg',
#  'super_tapgol_park292.jpg',
#  'super_tapgol_park293.jpg',
#  'super_tapgol_park294.jpg',
#  'super_tapgol_park295.jpg',
#  'super_tapgol_park296.jpg',
#  'super_tapgol_park297.jpg',
#  'super_tapgol_park298.jpg',
#  'super_tapgol_park299.jpg',
#  'super_tapgol_park3.jpg',
#  'super_tapgol_park30.jpg',
#  'super_tapgol_park300.jpg',
#  'super_tapgol_park301.jpg',
#  'super_tapgol_park302.jpg',
#  'super_tapgol_park303.jpg',
#  'super_tapgol_park304.jpg',
#  'super_tapgol_park305.jpg',
#  'super_tapgol_park306.jpg',
#  'super_tapgol_park307.jpg',
#  'super_tapgol_park308.jpg',
#  'super_tapgol_park309.jpg',
#  'super_tapgol_park31.jpg',
#  'super_tapgol_park310.jpg',
#  'super_tapgol_park311.jpg',
#  'super_tapgol_park312.jpg',
#  'super_tapgol_park313.jpg',
#  'super_tapgol_park314.jpg',
#  'super_tapgol_park315.jpg',
#  'super_tapgol_park316.jpg',
#  'super_tapgol_park317.jpg',
#  'super_tapgol_park318.jpg',
#  'super_tapgol_park319.jpg',
#  'super_tapgol_park32.jpg',
#  'super_tapgol_park320.jpg',
#  'super_tapgol_park321.jpg',
#  'super_tapgol_park322.jpg',
#  'super_tapgol_park323.jpg',
#  'super_tapgol_park324.jpg',
#  'super_tapgol_park325.jpg',
#  'super_tapgol_park326.jpg',
#  'super_tapgol_park327.jpg',
#  'super_tapgol_park328.jpg',
#  'super_tapgol_park329.jpg',
#  'super_tapgol_park33.jpg',
#  'super_tapgol_park330.jpg',
#  'super_tapgol_park331.jpg',
#  'super_tapgol_park332.jpg',
#  'super_tapgol_park333.jpg',
#  'super_tapgol_park334.jpg',
#  'super_tapgol_park335.jpg',
#  'super_tapgol_park336.jpg',
#  'super_tapgol_park337.jpg',
#  'super_tapgol_park338.jpg',
#  'super_tapgol_park339.jpg',
#  'super_tapgol_park34.jpg',
#  'super_tapgol_park340.jpg',
#  'super_tapgol_park341.jpg',
#  'super_tapgol_park342.jpg',
#  'super_tapgol_park343.jpg',
#  'super_tapgol_park344.jpg',
#  'super_tapgol_park345.jpg',
#  'super_tapgol_park346.jpg',
#  'super_tapgol_park347.jpg',
#  'super_tapgol_park348.jpg',
#  'super_tapgol_park349.jpg',
#  'super_tapgol_park35.jpg',
#  'super_tapgol_park350.jpg',
#  'super_tapgol_park351.jpg',
#  'super_tapgol_park352.jpg',
#  'super_tapgol_park353.jpg',
#  'super_tapgol_park354.jpg',
#  'super_tapgol_park355.jpg',
#  'super_tapgol_park356.jpg',
#  'super_tapgol_park357.jpg',
#  'super_tapgol_park358.jpg',
#  'super_tapgol_park359.jpg',
#  'super_tapgol_park36.jpg',
#  'super_tapgol_park360.jpg',
#  'super_tapgol_park361.jpg',
#  'super_tapgol_park362.jpg',
#  'super_tapgol_park363.jpg',
#  'super_tapgol_park364.jpg',
#  'super_tapgol_park365.jpg',
#  'super_tapgol_park366.jpg',
#  'super_tapgol_park367.jpg',
#  'super_tapgol_park368.jpg',
#  'super_tapgol_park369.jpg',
#  'super_tapgol_park37.jpg',
#  'super_tapgol_park370.jpg',
#  'super_tapgol_park371.jpg',
#  'super_tapgol_park372.jpg',
#  'super_tapgol_park373.jpg',
#  'super_tapgol_park374.jpg',
#  'super_tapgol_park375.jpg',
#  'super_tapgol_park376.jpg',
#  'super_tapgol_park377.jpg',
#  'super_tapgol_park378.jpg',
#  'super_tapgol_park379.jpg',
#  'super_tapgol_park38.jpg',
#  'super_tapgol_park380.jpg',
#  'super_tapgol_park381.jpg',
#  'super_tapgol_park382.jpg',
#  'super_tapgol_park383.jpg',
#  'super_tapgol_park384.jpg',
#  'super_tapgol_park385.jpg',
#  'super_tapgol_park386.jpg',
#  'super_tapgol_park387.jpg',
#  'super_tapgol_park388.jpg',
#  'super_tapgol_park389.jpg',
#  'super_tapgol_park39.jpg',
#  'super_tapgol_park390.jpg',
#  'super_tapgol_park391.jpg',
#  'super_tapgol_park392.jpg',
#  'super_tapgol_park393.jpg',
#  'super_tapgol_park394.jpg',
#  'super_tapgol_park395.jpg',
#  'super_tapgol_park396.jpg',
#  'super_tapgol_park397.jpg',
#  'super_tapgol_park398.jpg',
#  'super_tapgol_park399.jpg',
#  'super_tapgol_park4.jpg',
#  'super_tapgol_park40.jpg',
#  'super_tapgol_park400.jpg',
#  'super_tapgol_park401.jpg',
#  'super_tapgol_park402.jpg',
#  'super_tapgol_park403.jpg',
#  'super_tapgol_park404.jpg',
#  'super_tapgol_park405.jpg',
#  'super_tapgol_park406.jpg',
#  'super_tapgol_park407.jpg',
#  'super_tapgol_park408.jpg',
#  'super_tapgol_park409.jpg',
#  'super_tapgol_park41.jpg',
#  'super_tapgol_park410.jpg',
#  'super_tapgol_park411.jpg',
#  'super_tapgol_park412.jpg',
#  'super_tapgol_park413.jpg',
#  'super_tapgol_park414.jpg',
#  'super_tapgol_park415.jpg',
#  'super_tapgol_park416.jpg',
#  'super_tapgol_park417.jpg',
#  'super_tapgol_park418.jpg',
#  'super_tapgol_park419.jpg',
#  'super_tapgol_park42.jpg',
#  'super_tapgol_park420.jpg',
#  'super_tapgol_park421.jpg',
#  'super_tapgol_park422.jpg',
#  'super_tapgol_park423.jpg',
#  'super_tapgol_park424.jpg',
#  'super_tapgol_park425.jpg',
#  'super_tapgol_park426.jpg',
#  'super_tapgol_park427.jpg',
#  'super_tapgol_park428.jpg',
#  'super_tapgol_park429.jpg',
#  'super_tapgol_park43.jpg',
#  'super_tapgol_park430.jpg',
#  'super_tapgol_park431.jpg',
#  'super_tapgol_park432.jpg',
#  'super_tapgol_park433.jpg',
#  'super_tapgol_park434.jpg',
#  'super_tapgol_park435.jpg',
#  'super_tapgol_park436.jpg',
#  'super_tapgol_park437.jpg',
#  'super_tapgol_park438.jpg',
#  'super_tapgol_park439.jpg',
#  'super_tapgol_park44.jpg',
#  'super_tapgol_park440.jpg',
#  'super_tapgol_park441.jpg',
#  'super_tapgol_park442.jpg',
#  'super_tapgol_park443.jpg',
#  'super_tapgol_park444.jpg',
#  'super_tapgol_park445.jpg',
#  'super_tapgol_park446.jpg',
#  'super_tapgol_park447.jpg',
#  'super_tapgol_park448.jpg',
#  'super_tapgol_park449.jpg',
#  'super_tapgol_park45.jpg',
#  'super_tapgol_park450.jpg',
#  'super_tapgol_park451.jpg',
#  'super_tapgol_park452.jpg',
#  'super_tapgol_park453.jpg',
#  'super_tapgol_park454.jpg',
#  'super_tapgol_park455.jpg',
#  'super_tapgol_park456.jpg',
#  'super_tapgol_park457.jpg',
#  'super_tapgol_park458.jpg',
#  'super_tapgol_park459.jpg',
#  'super_tapgol_park46.jpg',
#  'super_tapgol_park460.jpg',
#  'super_tapgol_park461.jpg',
#  'super_tapgol_park462.jpg',
#  'super_tapgol_park463.jpg',
#  'super_tapgol_park464.jpg',
#  'super_tapgol_park465.jpg',
#  'super_tapgol_park466.jpg',
#  'super_tapgol_park467.jpg',
#  'super_tapgol_park468.jpg',
#  'super_tapgol_park469.jpg',
#  'super_tapgol_park47.jpg',
#  'super_tapgol_park470.jpg',
#  'super_tapgol_park471.jpg',
#  'super_tapgol_park472.jpg',
#  'super_tapgol_park473.jpg',
#  'super_tapgol_park474.jpg',
#  'super_tapgol_park475.jpg',
#  'super_tapgol_park476.jpg',
#  'super_tapgol_park477.jpg',
#  'super_tapgol_park478.jpg',
#  'super_tapgol_park479.jpg',
#  'super_tapgol_park48.jpg',
#  'super_tapgol_park480.jpg',
#  'super_tapgol_park481.jpg',
#  'super_tapgol_park482.jpg',
#  'super_tapgol_park483.jpg',
#  'super_tapgol_park484.jpg',
#  'super_tapgol_park485.jpg',
#  'super_tapgol_park486.jpg',
#  'super_tapgol_park487.jpg',
#  'super_tapgol_park488.jpg',
#  'super_tapgol_park489.jpg',
#  'super_tapgol_park49.jpg',
#  'super_tapgol_park490.jpg',
#  'super_tapgol_park491.jpg',
#  'super_tapgol_park492.jpg',
#  'super_tapgol_park493.jpg',
#  'super_tapgol_park494.jpg',
#  'super_tapgol_park495.jpg',
#  'super_tapgol_park496.jpg',
#  'super_tapgol_park497.jpg',
#  'super_tapgol_park498.jpg',
#  'super_tapgol_park499.jpg',
#  'super_tapgol_park5.jpg',
#  'super_tapgol_park50.jpg',
#  'super_tapgol_park500.jpg',
#  'super_tapgol_park501.jpg',
#  'super_tapgol_park502.jpg',
#  'super_tapgol_park503.jpg',
#  'super_tapgol_park504.jpg',
#  'super_tapgol_park505.jpg',
#  'super_tapgol_park506.jpg',
#  'super_tapgol_park507.jpg',
#  'super_tapgol_park508.jpg',
#  'super_tapgol_park509.jpg',
#  'super_tapgol_park51.jpg',
#  'super_tapgol_park510.jpg',
#  'super_tapgol_park511.jpg',
#  'super_tapgol_park512.jpg',
#  'super_tapgol_park513.jpg',
#  'super_tapgol_park514.jpg',
#  'super_tapgol_park515.jpg',
#  'super_tapgol_park516.jpg',
#  'super_tapgol_park517.jpg',
#  'super_tapgol_park518.jpg',
#  'super_tapgol_park519.jpg',
#  'super_tapgol_park52.jpg',
#  'super_tapgol_park520.jpg',
#  'super_tapgol_park521.jpg',
#  'super_tapgol_park522.jpg',
#  'super_tapgol_park523.jpg',
#  'super_tapgol_park524.jpg',
#  'super_tapgol_park525.jpg',
#  'super_tapgol_park526.jpg',
#  'super_tapgol_park527.jpg',
#  'super_tapgol_park528.jpg',
#  'super_tapgol_park529.jpg',
#  'super_tapgol_park53.jpg',
#  'super_tapgol_park530.jpg',
#  'super_tapgol_park531.jpg',
#  'super_tapgol_park532.jpg',
#  'super_tapgol_park533.jpg',
#  'super_tapgol_park534.jpg',
#  'super_tapgol_park535.jpg',
#  'super_tapgol_park536.jpg',
#  'super_tapgol_park537.jpg',
#  'super_tapgol_park538.jpg',
#  'super_tapgol_park539.jpg',
#  'super_tapgol_park54.jpg',
#  'super_tapgol_park540.jpg',
#  'super_tapgol_park541.jpg',
#  'super_tapgol_park542.jpg',
#  'super_tapgol_park543.jpg',
#  'super_tapgol_park544.jpg',
#  'super_tapgol_park545.jpg',
#  'super_tapgol_park546.jpg',
#  'super_tapgol_park547.jpg',
#  'super_tapgol_park548.jpg',
#  'super_tapgol_park549.jpg',
#  'super_tapgol_park55.jpg',
#  'super_tapgol_park550.jpg',
#  'super_tapgol_park551.jpg',
#  'super_tapgol_park552.jpg',
#  'super_tapgol_park553.jpg',
#  'super_tapgol_park554.jpg',
#  'super_tapgol_park555.jpg',
#  'super_tapgol_park556.jpg',
#  'super_tapgol_park557.jpg',
#  'super_tapgol_park558.jpg',
#  'super_tapgol_park559.jpg',
#  'super_tapgol_park56.jpg',
#  'super_tapgol_park560.jpg',
#  'super_tapgol_park561.jpg',
#  'super_tapgol_park562.jpg',
#  'super_tapgol_park563.jpg',
#  'super_tapgol_park564.jpg',
#  'super_tapgol_park565.jpg',
#  'super_tapgol_park566.jpg',
#  'super_tapgol_park567.jpg',
#  'super_tapgol_park568.jpg',
#  'super_tapgol_park569.jpg',
#  'super_tapgol_park57.jpg',
#  'super_tapgol_park570.jpg',
#  'super_tapgol_park571.jpg',
#  'super_tapgol_park572.jpg',
#  'super_tapgol_park573.jpg',
#  'super_tapgol_park574.jpg',
#  'super_tapgol_park575.jpg',
#  'super_tapgol_park576.jpg',
#  'super_tapgol_park577.jpg',
#  'super_tapgol_park578.jpg',
#  'super_tapgol_park579.jpg',
#  'super_tapgol_park58.jpg',
#  'super_tapgol_park580.jpg',
#  'super_tapgol_park581.jpg',
#  'super_tapgol_park582.jpg',
#  'super_tapgol_park583.jpg',
#  'super_tapgol_park584.jpg',
#  'super_tapgol_park585.jpg',
#  'super_tapgol_park586.jpg',
#  'super_tapgol_park587.jpg',
#  'super_tapgol_park588.jpg',
#  'super_tapgol_park589.jpg',
#  'super_tapgol_park59.jpg',
#  'super_tapgol_park590.jpg',
#  'super_tapgol_park591.jpg',
#  'super_tapgol_park592.jpg',
#  'super_tapgol_park593.jpg',
#  'super_tapgol_park594.jpg',
#  'super_tapgol_park595.jpg',
#  'super_tapgol_park596.jpg',
#  'super_tapgol_park597.jpg',
#  'super_tapgol_park598.jpg',
#  'super_tapgol_park599.jpg',
#  'super_tapgol_park6.jpg',
#  'super_tapgol_park60.jpg',
#  'super_tapgol_park600.jpg',
#  'super_tapgol_park601.jpg',
#  'super_tapgol_park602.jpg',
#  'super_tapgol_park603.jpg',
#  'super_tapgol_park604.jpg',
#  'super_tapgol_park605.jpg',
#  'super_tapgol_park606.jpg',
#  'super_tapgol_park607.jpg',
#  'super_tapgol_park608.jpg',
#  'super_tapgol_park609.jpg',
#  'super_tapgol_park61.jpg',
#  'super_tapgol_park610.jpg',
#  'super_tapgol_park611.jpg',
#  'super_tapgol_park612.jpg',
#  'super_tapgol_park613.jpg',
#  'super_tapgol_park614.jpg',
#  'super_tapgol_park615.jpg',
#  'super_tapgol_park616.jpg',
#  'super_tapgol_park617.jpg',
#  'super_tapgol_park618.jpg',
#  'super_tapgol_park619.jpg',
#  'super_tapgol_park62.jpg',
#  'super_tapgol_park620.jpg',
#  'super_tapgol_park621.jpg',
#  'super_tapgol_park622.jpg',
#  'super_tapgol_park623.jpg',
#  'super_tapgol_park624.jpg',
#  'super_tapgol_park625.jpg',
#  'super_tapgol_park626.jpg',
#  'super_tapgol_park627.jpg',
#  'super_tapgol_park628.jpg',
#  'super_tapgol_park629.jpg',
#  'super_tapgol_park63.jpg',
#  'super_tapgol_park630.jpg',
#  'super_tapgol_park631.jpg',
#  'super_tapgol_park632.jpg',
#  'super_tapgol_park633.jpg',
#  'super_tapgol_park634.jpg',
#  'super_tapgol_park635.jpg',
#  'super_tapgol_park636.jpg',
#  'super_tapgol_park637.jpg',
#  'super_tapgol_park638.jpg',
#  'super_tapgol_park639.jpg',
#  'super_tapgol_park64.jpg',
#  'super_tapgol_park640.jpg',
#  'super_tapgol_park641.jpg',
#  'super_tapgol_park642.jpg',
#  'super_tapgol_park643.jpg',
#  'super_tapgol_park644.jpg',
#  'super_tapgol_park645.jpg',
#  'super_tapgol_park646.jpg',
#  'super_tapgol_park647.jpg',
#  'super_tapgol_park648.jpg',
#  'super_tapgol_park649.jpg',
#  'super_tapgol_park65.jpg',
#  'super_tapgol_park650.jpg',
#  'super_tapgol_park651.jpg',
#  'super_tapgol_park652.jpg',
#  'super_tapgol_park653.jpg',
#  'super_tapgol_park654.jpg',
#  'super_tapgol_park655.jpg',
#  'super_tapgol_park656.jpg',
#  'super_tapgol_park657.jpg',
#  'super_tapgol_park658.jpg',
#  'super_tapgol_park659.jpg',
#  'super_tapgol_park66.jpg',
#  'super_tapgol_park660.jpg',
#  'super_tapgol_park661.jpg',
#  'super_tapgol_park662.jpg',
#  'super_tapgol_park663.jpg',
#  'super_tapgol_park664.jpg',
#  'super_tapgol_park665.jpg',
#  'super_tapgol_park666.jpg',
#  'super_tapgol_park667.jpg',
#  'super_tapgol_park668.jpg',
#  'super_tapgol_park669.jpg',
#  'super_tapgol_park67.jpg',
#  'super_tapgol_park670.jpg',
#  'super_tapgol_park671.jpg',
#  'super_tapgol_park672.jpg',
#  'super_tapgol_park673.jpg',
#  'super_tapgol_park674.jpg',
#  'super_tapgol_park675.jpg',
#  'super_tapgol_park676.jpg',
#  'super_tapgol_park677.jpg',
#  'super_tapgol_park678.jpg',
#  'super_tapgol_park679.jpg',
#  'super_tapgol_park68.jpg',
#  'super_tapgol_park680.jpg',
#  'super_tapgol_park681.jpg',
#  'super_tapgol_park682.jpg',
#  'super_tapgol_park683.jpg',
#  'super_tapgol_park684.jpg',
#  'super_tapgol_park685.jpg',
#  'super_tapgol_park686.jpg',
#  'super_tapgol_park687.jpg',
#  'super_tapgol_park688.jpg',
#  'super_tapgol_park689.jpg',
#  'super_tapgol_park69.jpg',
#  'super_tapgol_park690.jpg',
#  'super_tapgol_park691.jpg',
#  'super_tapgol_park692.jpg',
#  'super_tapgol_park693.jpg',
#  'super_tapgol_park694.jpg',
#  'super_tapgol_park695.jpg',
#  'super_tapgol_park696.jpg',
#  'super_tapgol_park697.jpg',
#  'super_tapgol_park698.jpg',
#  'super_tapgol_park699.jpg',
#  'super_tapgol_park7.jpg',
#  'super_tapgol_park70.jpg',
#  'super_tapgol_park700.jpg',
#  'super_tapgol_park701.jpg',
#  'super_tapgol_park702.jpg',
#  'super_tapgol_park703.jpg',
#  'super_tapgol_park704.jpg',
#  'super_tapgol_park705.jpg',
#  'super_tapgol_park706.jpg',
#  'super_tapgol_park707.jpg',
#  'super_tapgol_park708.jpg',
#  'super_tapgol_park709.jpg',
#  'super_tapgol_park71.jpg',
#  'super_tapgol_park710.jpg',
#  'super_tapgol_park711.jpg',
#  'super_tapgol_park712.jpg',
#  'super_tapgol_park713.jpg',
#  'super_tapgol_park714.jpg',
#  'super_tapgol_park715.jpg',
#  'super_tapgol_park716.jpg',
#  'super_tapgol_park717.jpg',
#  'super_tapgol_park718.jpg',
#  'super_tapgol_park719.jpg',
#  'super_tapgol_park72.jpg',
#  'super_tapgol_park720.jpg',
#  'super_tapgol_park721.jpg',
#  'super_tapgol_park722.jpg',
#  'super_tapgol_park723.jpg',
#  'super_tapgol_park724.jpg',
#  'super_tapgol_park725.jpg',
#  'super_tapgol_park726.jpg',
#  'super_tapgol_park727.jpg',
#  'super_tapgol_park728.jpg',
#  'super_tapgol_park729.jpg',
#  'super_tapgol_park73.jpg',
#  'super_tapgol_park730.jpg',
#  'super_tapgol_park731.jpg',
#  'super_tapgol_park732.jpg',
#  'super_tapgol_park733.jpg',
#  'super_tapgol_park734.jpg',
#  'super_tapgol_park735.jpg',
#  'super_tapgol_park736.jpg',
#  'super_tapgol_park737.jpg',
#  'super_tapgol_park738.jpg',
#  'super_tapgol_park739.jpg',
#  'super_tapgol_park74.jpg',
#  'super_tapgol_park740.jpg',
#  'super_tapgol_park741.jpg',
#  'super_tapgol_park742.jpg',
#  'super_tapgol_park743.jpg',
#  'super_tapgol_park744.jpg',
#  'super_tapgol_park745.jpg',
#  'super_tapgol_park746.jpg',
#  'super_tapgol_park747.jpg',
#  'super_tapgol_park748.jpg',
#  'super_tapgol_park749.jpg',
#  'super_tapgol_park75.jpg',
#  'super_tapgol_park750.jpg',
#  'super_tapgol_park751.jpg',
#  'super_tapgol_park752.jpg',
#  'super_tapgol_park753.jpg',
#  'super_tapgol_park754.jpg',
#  'super_tapgol_park755.jpg',
#  'super_tapgol_park756.jpg',
#  'super_tapgol_park757.jpg',
#  'super_tapgol_park758.jpg',
#  'super_tapgol_park759.jpg',
#  'super_tapgol_park76.jpg',
#  'super_tapgol_park760.jpg',
#  'super_tapgol_park761.jpg',
#  'super_tapgol_park762.jpg',
#  'super_tapgol_park763.jpg',
#  'super_tapgol_park764.jpg',
#  'super_tapgol_park765.jpg',
#  'super_tapgol_park766.jpg',
#  'super_tapgol_park767.jpg',
#  'super_tapgol_park768.jpg',
#  'super_tapgol_park769.jpg',
#  'super_tapgol_park77.jpg',
#  'super_tapgol_park770.jpg',
#  'super_tapgol_park771.jpg',
#  'super_tapgol_park772.jpg',
#  'super_tapgol_park773.jpg',
#  'super_tapgol_park774.jpg',
#  'super_tapgol_park775.jpg',
#  'super_tapgol_park776.jpg',
#  'super_tapgol_park777.jpg',
#  'super_tapgol_park778.jpg',
#  'super_tapgol_park779.jpg',
#  'super_tapgol_park78.jpg',
#  'super_tapgol_park780.jpg',
#  'super_tapgol_park781.jpg',
#  'super_tapgol_park782.jpg',
#  'super_tapgol_park783.jpg',
#  'super_tapgol_park784.jpg',
#  'super_tapgol_park785.jpg',
#  'super_tapgol_park786.jpg',
#  'super_tapgol_park787.jpg',
#  'super_tapgol_park788.jpg',
#  'super_tapgol_park789.jpg',
#  'super_tapgol_park79.jpg',
#  'super_tapgol_park790.jpg',
#  'super_tapgol_park791.jpg',
#  'super_tapgol_park792.jpg',
#  'super_tapgol_park793.jpg',
#  'super_tapgol_park794.jpg',
#  'super_tapgol_park795.jpg',
#  'super_tapgol_park796.jpg',
#  'super_tapgol_park797.jpg',
#  'super_tapgol_park798.jpg',
#  'super_tapgol_park799.jpg',
#  'super_tapgol_park8.jpg',
#  'super_tapgol_park80.jpg',
#  'super_tapgol_park800.jpg',
#  'super_tapgol_park801.jpg',
#  'super_tapgol_park802.jpg',
#  'super_tapgol_park803.jpg',
#  'super_tapgol_park804.jpg',
#  'super_tapgol_park805.jpg',
#  'super_tapgol_park806.jpg',
#  'super_tapgol_park807.jpg',
#  'super_tapgol_park808.jpg',
#  'super_tapgol_park809.jpg',
#  'super_tapgol_park81.jpg',
#  'super_tapgol_park810.jpg',
#  'super_tapgol_park811.jpg',
#  'super_tapgol_park812.jpg',
#  'super_tapgol_park813.jpg',
#  'super_tapgol_park814.jpg',
#  'super_tapgol_park815.jpg',
#  'super_tapgol_park816.jpg',
#  'super_tapgol_park817.jpg',
#  'super_tapgol_park818.jpg',
#  'super_tapgol_park819.jpg',
#  'super_tapgol_park82.jpg',
#  'super_tapgol_park820.jpg',
#  'super_tapgol_park821.jpg',
#  'super_tapgol_park822.jpg',
#  'super_tapgol_park823.jpg',
#  'super_tapgol_park824.jpg',
#  'super_tapgol_park825.jpg',
#  'super_tapgol_park826.jpg',
#  'super_tapgol_park827.jpg',
#  'super_tapgol_park828.jpg',
#  'super_tapgol_park829.jpg',
#  'super_tapgol_park83.jpg',
#  'super_tapgol_park830.jpg',
#  'super_tapgol_park831.jpg',
#  'super_tapgol_park832.jpg',
#  'super_tapgol_park833.jpg',
#  'super_tapgol_park834.jpg',
#  'super_tapgol_park835.jpg',
#  'super_tapgol_park836.jpg',
#  'super_tapgol_park837.jpg',
#  'super_tapgol_park838.jpg',
#  'super_tapgol_park839.jpg',
#  'super_tapgol_park84.jpg',
#  'super_tapgol_park840.jpg',
#  'super_tapgol_park841.jpg',
#  'super_tapgol_park842.jpg',
#  'super_tapgol_park843.jpg',
#  'super_tapgol_park844.jpg',
#  'super_tapgol_park845.jpg',
#  'super_tapgol_park846.jpg',
#  'super_tapgol_park847.jpg',
#  'super_tapgol_park848.jpg',
#  'super_tapgol_park849.jpg',
#  'super_tapgol_park85.jpg',
#  'super_tapgol_park850.jpg',
#  'super_tapgol_park851.jpg',
#  'super_tapgol_park852.jpg',
#  'super_tapgol_park853.jpg',
#  'super_tapgol_park854.jpg',
#  'super_tapgol_park855.jpg',
#  'super_tapgol_park856.jpg',
#  'super_tapgol_park857.jpg',
#  'super_tapgol_park858.jpg',
#  'super_tapgol_park859.jpg',
#  'super_tapgol_park86.jpg',
#  'super_tapgol_park860.jpg',
#  'super_tapgol_park861.jpg',
#  'super_tapgol_park862.jpg',
#  'super_tapgol_park863.jpg',
#  'super_tapgol_park864.jpg',
#  'super_tapgol_park865.jpg',
#  'super_tapgol_park866.jpg',
#  'super_tapgol_park867.jpg',
#  'super_tapgol_park868.jpg',
#  'super_tapgol_park869.jpg',
#  'super_tapgol_park87.jpg',
#  'super_tapgol_park870.jpg',
#  'super_tapgol_park871.jpg',
#  'super_tapgol_park872.jpg',
#  'super_tapgol_park873.jpg',
#  'super_tapgol_park874.jpg',
#  'super_tapgol_park875.jpg',
#  'super_tapgol_park876.jpg',
#  'super_tapgol_park877.jpg',
#  'super_tapgol_park878.jpg',
#  'super_tapgol_park879.jpg',
#  'super_tapgol_park88.jpg',
#  'super_tapgol_park880.jpg',
#  'super_tapgol_park881.jpg',
#  'super_tapgol_park882.jpg',
#  'super_tapgol_park883.jpg',
#  'super_tapgol_park884.jpg',
#  'super_tapgol_park885.jpg',
#  'super_tapgol_park886.jpg',
#  'super_tapgol_park887.jpg',
#  'super_tapgol_park888.jpg',
#  'super_tapgol_park889.jpg',
#  'super_tapgol_park89.jpg',
#  'super_tapgol_park890.jpg',
#  'super_tapgol_park891.jpg',
#  'super_tapgol_park892.jpg',
#  'super_tapgol_park893.jpg',
#  'super_tapgol_park894.jpg',
#  'super_tapgol_park895.jpg',
#  'super_tapgol_park896.jpg',
#  'super_tapgol_park897.jpg',
#  'super_tapgol_park898.jpg',
#  'super_tapgol_park899.jpg',
#  'super_tapgol_park9.jpg',
#  'super_tapgol_park90.jpg',
#  'super_tapgol_park900.jpg',
#  'super_tapgol_park901.jpg',
#  'super_tapgol_park902.jpg',
#  'super_tapgol_park903.jpg',
#  'super_tapgol_park904.jpg',
#  'super_tapgol_park905.jpg',
#  'super_tapgol_park906.jpg',
#  'super_tapgol_park907.jpg',
#  'super_tapgol_park908.jpg',
#  'super_tapgol_park909.jpg',
#  'super_tapgol_park91.jpg',
#  'super_tapgol_park910.jpg',
#  'super_tapgol_park911.jpg',
#  'super_tapgol_park912.jpg',
#  'super_tapgol_park913.jpg',
#  'super_tapgol_park914.jpg',
#  'super_tapgol_park915.jpg',
#  'super_tapgol_park916.jpg',
#  'super_tapgol_park917.jpg',
#  'super_tapgol_park918.jpg',
#  'super_tapgol_park919.jpg',
#  'super_tapgol_park92.jpg',
#  'super_tapgol_park920.jpg',
#  'super_tapgol_park921.jpg',
#  'super_tapgol_park922.jpg',
#  'super_tapgol_park923.jpg',
#  'super_tapgol_park924.jpg',
#  'super_tapgol_park925.jpg',
#  'super_tapgol_park926.jpg',
#  'super_tapgol_park927.jpg',
#  'super_tapgol_park928.jpg',
#  'super_tapgol_park929.jpg',
#  'super_tapgol_park93.jpg',
#  'super_tapgol_park930.jpg',
#  'super_tapgol_park931.jpg',
#  'super_tapgol_park932.jpg',
#  'super_tapgol_park933.jpg',
#  'super_tapgol_park934.jpg',
#  'super_tapgol_park935.jpg',
#  'super_tapgol_park936.jpg',
#  'super_tapgol_park937.jpg',
#  'super_tapgol_park938.jpg',
#  'super_tapgol_park939.jpg',
#  'super_tapgol_park94.jpg',
#  'super_tapgol_park940.jpg',
#  'super_tapgol_park941.jpg',
#  'super_tapgol_park942.jpg',
#  'super_tapgol_park943.jpg',
#  'super_tapgol_park944.jpg',
#  'super_tapgol_park945.jpg',
#  'super_tapgol_park946.jpg',
#  'super_tapgol_park947.jpg',
#  'super_tapgol_park948.jpg',
#  'super_tapgol_park949.jpg',
#  'super_tapgol_park95.jpg',
#  'super_tapgol_park950.jpg',
#  'super_tapgol_park951.jpg',
#  'super_tapgol_park952.jpg',
#  'super_tapgol_park953.jpg',
#  'super_tapgol_park954.jpg',
#  'super_tapgol_park955.jpg',
#  'super_tapgol_park956.jpg',
#  'super_tapgol_park957.jpg',
#  'super_tapgol_park958.jpg',
#  'super_tapgol_park959.jpg',
#  'super_tapgol_park96.jpg',
#  'super_tapgol_park960.jpg',
#  'super_tapgol_park961.jpg',
#  'super_tapgol_park962.jpg',
#  'super_tapgol_park963.jpg',
#  'super_tapgol_park964.jpg',
#  'super_tapgol_park965.jpg',
#  'super_tapgol_park966.jpg',
#  'super_tapgol_park967.jpg',
#  'super_tapgol_park968.jpg',
#  'super_tapgol_park969.jpg',
#  'super_tapgol_park97.jpg',
#  'super_tapgol_park970.jpg',
#  'super_tapgol_park971.jpg',
#  'super_tapgol_park972.jpg',
#  'super_tapgol_park973.jpg',
#  'super_tapgol_park974.jpg',
#  'super_tapgol_park975.jpg',
#  'super_tapgol_park976.jpg',
#  'super_tapgol_park977.jpg',
#  'super_tapgol_park978.jpg',
#  'super_tapgol_park979.jpg',
#  'super_tapgol_park98.jpg',
#  'super_tapgol_park980.jpg',
#  'super_tapgol_park981.jpg',
#  'super_tapgol_park982.jpg',
#  'super_tapgol_park983.jpg',
#  'super_tapgol_park984.jpg',
#  'super_tapgol_park985.jpg',
#  'super_tapgol_park986.jpg',
#  'super_tapgol_park987.jpg',
#  'super_tapgol_park988.jpg',
#  'super_tapgol_park989.jpg',
#  'super_tapgol_park99.jpg',
#  'super_tapgol_park990.jpg',
#  'super_tapgol_park991.jpg',
#  'super_tapgol_park992.jpg',
#  'super_tapgol_park993.jpg',
#  'super_tapgol_park994.jpg',
#  'super_tapgol_park995.jpg',
#  'super_tapgol_park996.jpg',
#  'super_tapgol_park997.jpg',
#  'super_tapgol_park998.jpg',
#  'super_tapgol_park999.jpg']

# %%
cnt=0
# 필터링을 거쳐 필터링 잘된 사진들만 골라 이미지를 띄워준다.
for i in tqdm(range(len(file_list))):
    image_general = cv2.imread("D:/original_image/tapgol_park/" + file_list[i], cv2.IMREAD_UNCHANGED)
    image_gray_general = cv2.imread("D:/original_image/tapgol_park/" + file_list[i], cv2.IMREAD_GRAYSCALE)
    image_general = cv2.resize(image_general, dsize=(240, 240), interpolation=cv2.INTER_LINEAR)
    image_gray_general = cv2.resize(image_gray_general, dsize=(240, 240), interpolation=cv2.INTER_LINEAR)
    
    blur_general = cv2.GaussianBlur(image_gray_general, ksize=(3,3), sigmaX=1)
    ret, thresh1 = cv2.threshold(blur_general, 200, 255, cv2.THRESH_BINARY)
    edged_general = cv2.Canny(thresh1, 10, 250)
    contour_general = image_general.copy()
    
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5,5))
    closed_general = cv2.morphologyEx(edged_general, cv2.MORPH_CLOSE , kernel)
    
    contours, hierarchy = cv2.findContours(closed_general,cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    final_result = cv2.drawContours(contour_general, contours, -1, (0,255,0), 3)
    
    contours_xy = np.array(contours)
    
    for j in range(len(contours_xy)):
        x_min, x_max = 0,0
        y_min, y_max = 0,0
        x_value = list()
        y_value = list()

        for k in range(len(contours_xy[j])):
            x_value.append(contours_xy[j][k][0][0]) #네번째 괄호가 0일때 x의 값
            y_value.append(contours_xy[j][k][0][1]) #네번째 괄호가 0일때 x의 값

        x_min = min(x_value)
        x_max = max(x_value)
        y_min = min(y_value)
        y_max = max(y_value)

        x = x_min
        y = y_min
        w = x_max-x_min
        h = y_max-y_min


        if w<150 or h<150:
            pass
        else:
            time.sleep(0.01)
            cnt+=1
            img_trim = image_general[y:y+h, x:x+w]
            cv2.imwrite("D:/filtering_image/tapgol_park/super_tapgol_park" + str(i) + ".jpg", img_trim)
# Out:
#   0%|                                                                                         | 0/1000 [00:00<?, ?it/s]C:\Users\lemon\anaconda3\envs\project-env\lib\site-packages\ipykernel_launcher.py:19: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# 100%|█████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:03<00:00, 289.69it/s]

# %%
folder = "D:/filtering_image/general"
file_list = [x for x in os.listdir(folder)]

# %%
file_list
# Out:
# ['super_general101.jpg',
#  'super_general103.jpg',
#  'super_general105.jpg',
#  'super_general109.jpg',
#  'super_general11.jpg',
#  'super_general111.jpg',
#  'super_general117.jpg',
#  'super_general118.jpg',
#  'super_general12.jpg',
#  'super_general120.jpg',
#  'super_general121.jpg',
#  'super_general122.jpg',
#  'super_general126.jpg',
#  'super_general127.jpg',
#  'super_general128.jpg',
#  'super_general130.jpg',
#  'super_general135.jpg',
#  'super_general140.jpg',
#  'super_general145.jpg',
#  'super_general146.jpg',
#  'super_general150.jpg',
#  'super_general152.jpg',
#  'super_general155.jpg',
#  'super_general157.jpg',
#  'super_general16.jpg',
#  'super_general161.jpg',
#  'super_general164.jpg',
#  'super_general167.jpg',
#  'super_general172.jpg',
#  'super_general173.jpg',
#  'super_general175.jpg',
#  'super_general176.jpg',
#  'super_general178.jpg',
#  'super_general179.jpg',
#  'super_general180.jpg',
#  'super_general182.jpg',
#  'super_general183.jpg',
#  'super_general185.jpg',
#  'super_general186.jpg',
#  'super_general187.jpg',
#  'super_general188.jpg',
#  'super_general19.jpg',
#  'super_general190.jpg',
#  'super_general194.jpg',
#  'super_general197.jpg',
#  'super_general199.jpg',
#  'super_general2.jpg',
#  'super_general202.jpg',
#  'super_general205.jpg',
#  'super_general207.jpg',
#  'super_general211.jpg',
#  'super_general214.jpg',
#  'super_general218.jpg',
#  'super_general22.jpg',
#  'super_general225.jpg',
#  'super_general226.jpg',
#  'super_general228.jpg',
#  'super_general229.jpg',
#  'super_general23.jpg',
#  'super_general231.jpg',
#  'super_general234.jpg',
#  'super_general235.jpg',
#  'super_general238.jpg',
#  'super_general239.jpg',
#  'super_general24.jpg',
#  'super_general240.jpg',
#  'super_general242.jpg',
#  'super_general244.jpg',
#  'super_general245.jpg',
#  'super_general249.jpg',
#  'super_general25.jpg',
#  'super_general253.jpg',
#  'super_general257.jpg',
#  'super_general259.jpg',
#  'super_general260.jpg',
#  'super_general261.jpg',
#  'super_general262.jpg',
#  'super_general263.jpg',
#  'super_general270.jpg',
#  'super_general271.jpg',
#  'super_general272.jpg',
#  'super_general273.jpg',
#  'super_general275.jpg',
#  'super_general276.jpg',
#  'super_general277.jpg',
#  'super_general281.jpg',
#  'super_general286.jpg',
#  'super_general287.jpg',
#  'super_general288.jpg',
#  'super_general29.jpg',
#  'super_general291.jpg',
#  'super_general294.jpg',
#  'super_general295.jpg',
#  'super_general296.jpg',
#  'super_general298.jpg',
#  'super_general302.jpg',
#  'super_general303.jpg',
#  'super_general306.jpg',
#  'super_general312.jpg',
#  'super_general318.jpg',
#  'super_general319.jpg',
#  'super_general320.jpg',
#  'super_general323.jpg',
#  'super_general324.jpg',
#  'super_general325.jpg',
#  'super_general330.jpg',
#  'super_general333.jpg',
#  'super_general334.jpg',
#  'super_general335.jpg',
#  'super_general336.jpg',
#  'super_general337.jpg',
#  'super_general340.jpg',
#  'super_general344.jpg',
#  'super_general347.jpg',
#  'super_general349.jpg',
#  'super_general35.jpg',
#  'super_general352.jpg',
#  'super_general355.jpg',
#  'super_general358.jpg',
#  'super_general360.jpg',
#  'super_general362.jpg',
#  'super_general364.jpg',
#  'super_general365.jpg',
#  'super_general372.jpg',
#  'super_general374.jpg',
#  'super_general376.jpg',
#  'super_general377.jpg',
#  'super_general380.jpg',
#  'super_general382.jpg',
#  'super_general39.jpg',
#  'super_general390.jpg',
#  'super_general391.jpg',
#  'super_general392.jpg',
#  'super_general394.jpg',
#  'super_general395.jpg',
#  'super_general396.jpg',
#  'super_general404.jpg',
#  'super_general406.jpg',
#  'super_general407.jpg',
#  'super_general408.jpg',
#  'super_general415.jpg',
#  'super_general416.jpg',
#  'super_general418.jpg',
#  'super_general420.jpg',
#  'super_general423.jpg',
#  'super_general424.jpg',
#  'super_general425.jpg',
#  'super_general434.jpg',
#  'super_general436.jpg',
#  'super_general438.jpg',
#  'super_general439.jpg',
#  'super_general443.jpg',
#  'super_general444.jpg',
#  'super_general445.jpg',
#  'super_general446.jpg',
#  'super_general447.jpg',
#  'super_general449.jpg',
#  'super_general453.jpg',
#  'super_general454.jpg',
#  'super_general456.jpg',
#  'super_general458.jpg',
#  'super_general460.jpg',
#  'super_general463.jpg',
#  'super_general465.jpg',
#  'super_general470.jpg',
#  'super_general471.jpg',
#  'super_general472.jpg',
#  'super_general475.jpg',
#  'super_general476.jpg',
#  'super_general478.jpg',
#  'super_general479.jpg',
#  'super_general480.jpg',
#  'super_general485.jpg',
#  'super_general492.jpg',
#  'super_general496.jpg',
#  'super_general497.jpg',
#  'super_general498.jpg',
#  'super_general5.jpg',
#  'super_general50.jpg',
#  'super_general504.jpg',
#  'super_general506.jpg',
#  'super_general512.jpg',
#  'super_general513.jpg',
#  'super_general516.jpg',
#  'super_general517.jpg',
#  'super_general519.jpg',
#  'super_general52.jpg',
#  'super_general524.jpg',
#  'super_general529.jpg',
#  'super_general53.jpg',
#  'super_general530.jpg',
#  'super_general531.jpg',
#  'super_general534.jpg',
#  'super_general538.jpg',
#  'super_general539.jpg',
#  'super_general543.jpg',
#  'super_general549.jpg',
#  'super_general550.jpg',
#  'super_general553.jpg',
#  'super_general557.jpg',
#  'super_general558.jpg',
#  'super_general561.jpg',
#  'super_general562.jpg',
#  'super_general567.jpg',
#  'super_general569.jpg',
#  'super_general570.jpg',
#  'super_general575.jpg',
#  'super_general577.jpg',
#  'super_general578.jpg',
#  'super_general579.jpg',
#  'super_general58.jpg',
#  'super_general581.jpg',
#  'super_general587.jpg',
#  'super_general589.jpg',
#  'super_general590.jpg',
#  'super_general591.jpg',
#  'super_general597.jpg',
#  'super_general599.jpg',
#  'super_general604.jpg',
#  'super_general606.jpg',
#  'super_general61.jpg',
#  'super_general614.jpg',
#  'super_general617.jpg',
#  'super_general623.jpg',
#  'super_general625.jpg',
#  'super_general626.jpg',
#  'super_general63.jpg',
#  'super_general630.jpg',
#  'super_general631.jpg',
#  'super_general632.jpg',
#  'super_general635.jpg',
#  'super_general641.jpg',
#  'super_general643.jpg',
#  'super_general644.jpg',
#  'super_general647.jpg',
#  'super_general648.jpg',
#  'super_general650.jpg',
#  'super_general653.jpg',
#  'super_general658.jpg',
#  'super_general661.jpg',
#  'super_general662.jpg',
#  'super_general664.jpg',
#  'super_general665.jpg',
#  'super_general666.jpg',
#  'super_general667.jpg',
#  'super_general668.jpg',
#  'super_general671.jpg',
#  'super_general678.jpg',
#  'super_general680.jpg',
#  'super_general681.jpg',
#  'super_general685.jpg',
#  'super_general687.jpg',
#  'super_general69.jpg',
#  'super_general692.jpg',
#  'super_general695.jpg',
#  'super_general696.jpg',
#  'super_general699.jpg',
#  'super_general700.jpg',
#  'super_general701.jpg',
#  'super_general702.jpg',
#  'super_general704.jpg',
#  'super_general706.jpg',
#  'super_general707.jpg',
#  'super_general709.jpg',
#  'super_general712.jpg',
#  'super_general716.jpg',
#  'super_general720.jpg',
#  'super_general721.jpg',
#  'super_general724.jpg',
#  'super_general725.jpg',
#  'super_general733.jpg',
#  'super_general734.jpg',
#  'super_general74.jpg',
#  'super_general744.jpg',
#  'super_general750.jpg',
#  'super_general752.jpg',
#  'super_general753.jpg',
#  'super_general756.jpg',
#  'super_general757.jpg',
#  'super_general760.jpg',
#  'super_general761.jpg',
#  'super_general771.jpg',
#  'super_general772.jpg',
#  'super_general773.jpg',
#  'super_general774.jpg',
#  'super_general778.jpg',
#  'super_general779.jpg',
#  'super_general781.jpg',
#  'super_general782.jpg',
#  'super_general785.jpg',
#  'super_general786.jpg',
#  'super_general789.jpg',
#  'super_general792.jpg',
#  'super_general795.jpg',
#  'super_general797.jpg',
#  'super_general798.jpg',
#  'super_general799.jpg',
#  'super_general80.jpg',
#  'super_general800.jpg',
#  'super_general805.jpg',
#  'super_general81.jpg',
#  'super_general811.jpg',
#  'super_general812.jpg',
#  'super_general815.jpg',
#  'super_general816.jpg',
#  'super_general817.jpg',
#  'super_general822.jpg',
#  'super_general824.jpg',
#  'super_general825.jpg',
#  'super_general829.jpg',
#  'super_general835.jpg',
#  'super_general837.jpg',
#  'super_general844.jpg',
#  'super_general849.jpg',
#  'super_general852.jpg',
#  'super_general858.jpg',
#  'super_general859.jpg',
#  'super_general860.jpg',
#  'super_general866.jpg',
#  'super_general867.jpg',
#  'super_general868.jpg',
#  'super_general869.jpg',
#  'super_general872.jpg',
#  'super_general874.jpg',
#  'super_general880.jpg',
#  'super_general882.jpg',
#  'super_general886.jpg',
#  'super_general887.jpg',
#  'super_general888.jpg',
#  'super_general889.jpg',
#  'super_general890.jpg',
#  'super_general892.jpg',
#  'super_general895.jpg',
#  'super_general897.jpg',
#  'super_general898.jpg',
#  'super_general904.jpg',
#  'super_general907.jpg',
#  'super_general910.jpg',
#  'super_general912.jpg',
#  'super_general913.jpg',
#  'super_general915.jpg',
#  'super_general916.jpg',
#  'super_general918.jpg',
#  'super_general919.jpg',
#  'super_general923.jpg',
#  'super_general924.jpg',
#  'super_general925.jpg',
#  'super_general926.jpg',
#  'super_general929.jpg',
#  'super_general930.jpg',
#  'super_general936.jpg',
#  'super_general937.jpg',
#  'super_general938.jpg',
#  'super_general947.jpg',
#  'super_general948.jpg',
#  'super_general949.jpg',
#  'super_general952.jpg',
#  'super_general953.jpg',
#  'super_general954.jpg',
#  'super_general956.jpg',
#  'super_general958.jpg',
#  'super_general96.jpg',
#  'super_general962.jpg',
#  'super_general963.jpg',
#  'super_general965.jpg',
#  'super_general966.jpg',
#  'super_general969.jpg',
#  'super_general97.jpg',
#  'super_general970.jpg',
#  'super_general972.jpg',
#  'super_general973.jpg',
#  'super_general98.jpg',
#  'super_general980.jpg',
#  'super_general982.jpg',
#  'super_general983.jpg',
#  'super_general984.jpg',
#  'super_general985.jpg',
#  'super_general987.jpg',
#  'super_general988.jpg',
#  'super_general989.jpg',
#  'super_general99.jpg',
#  'super_general994.jpg',
#  'super_general995.jpg',
#  'super_general999.jpg']

# %%
# 데이터가 부족할 경우 쓸 수 있는 ImageDataGenraotr 기법
datagen = ImageDataGenerator(
        rotation_range=2,
        width_shift_range=0.05,
        height_shift_range=0.05,
        shear_range=0.05,
        zoom_range = 0.1,
        horizontal_flip=False,
        fill_mode="nearest")

# %%
for i in tqdm(range(len(file_list))):
    image = load_img("D:/filtering_image/general/" + file_list[i])  # PIL 이미지
    
    x = img_to_array(image)  # (3, 300, 300) 크기의 NumPy 배열
    x = x.reshape((1,) + x.shape)  # (1, 3, 300, 300) 크기의 NumPy 배열

#     아래 .flow() 함수는 임의 변환된 이미지를 배치 단위로 생성해서
#     지정된 `preview/` 폴더에 저장합니다.
    i = 0
    for batch in datagen.flow(x, batch_size=5,
                              save_to_dir="D:/detecting_image/general", save_prefix="super_general", save_format="jpg"):
        i += 1
        time.sleep(0.01)
        if i > 2:
            break  # 이미지 뻥튀기
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 384/384 [00:38<00:00, 10.10it/s]

# %%
detection_folder = "D:/song_image/tapgol_park"
detection_list = [x for x in os.listdir(detection_folder)]

# %%
for i in tqdm(range(len(detection_list))):
    new_image = cv2.imread("D:/song_image/tapgol_park/" + detection_list[i], cv2.IMREAD_UNCHANGED)
    new_image = cv2.resize(new_image, dsize=(240, 240), interpolation=cv2.INTER_LINEAR)
    cv2.imwrite("D:/song_image/tapgol_park/super_tapgol_park" +str(i+1) + ".jpg", new_image)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1200/1200 [00:04<00:00, 276.46it/s]

# %%
sample_foler="D:/song_image/indep_door"
sample_list = [x for x in os.listdir(sample_foler)]

# %%
# 데이터 프레임을 머신러인 Train split 방법으로 사용하지 못할 경우 해당 코드도 괜찮은 방법 중의 하나이다.
not_train_list = random.sample(sample_list, int(len(sample_list)*0.4))

# %%
train_list = [x for x in sample_list if x not in not_train_list]

# %%
train_list
# Out:
# ['super_indep_door100.jpg',
#  'super_indep_door1001.jpg',
#  'super_indep_door1003.jpg',
#  'super_indep_door1004.jpg',
#  'super_indep_door1005.jpg',
#  'super_indep_door1006.jpg',
#  'super_indep_door1008.jpg',
#  'super_indep_door101.jpg',
#  'super_indep_door1010.jpg',
#  'super_indep_door1013.jpg',
#  'super_indep_door1015.jpg',
#  'super_indep_door1016.jpg',
#  'super_indep_door1017.jpg',
#  'super_indep_door1018.jpg',
#  'super_indep_door1019.jpg',
#  'super_indep_door102.jpg',
#  'super_indep_door1020.jpg',
#  'super_indep_door1021.jpg',
#  'super_indep_door1026.jpg',
#  'super_indep_door1027.jpg',
#  'super_indep_door1028.jpg',
#  'super_indep_door1029.jpg',
#  'super_indep_door1030.jpg',
#  'super_indep_door1031.jpg',
#  'super_indep_door1033.jpg',
#  'super_indep_door1034.jpg',
#  'super_indep_door1035.jpg',
#  'super_indep_door1036.jpg',
#  'super_indep_door1038.jpg',
#  'super_indep_door1041.jpg',
#  'super_indep_door1043.jpg',
#  'super_indep_door1045.jpg',
#  'super_indep_door1048.jpg',
#  'super_indep_door1049.jpg',
#  'super_indep_door105.jpg',
#  'super_indep_door1051.jpg',
#  'super_indep_door1052.jpg',
#  'super_indep_door1053.jpg',
#  'super_indep_door1054.jpg',
#  'super_indep_door1055.jpg',
#  'super_indep_door1058.jpg',
#  'super_indep_door1059.jpg',
#  'super_indep_door106.jpg',
#  'super_indep_door1060.jpg',
#  'super_indep_door1062.jpg',
#  'super_indep_door1064.jpg',
#  'super_indep_door1065.jpg',
#  'super_indep_door1066.jpg',
#  'super_indep_door1067.jpg',
#  'super_indep_door1068.jpg',
#  'super_indep_door1069.jpg',
#  'super_indep_door107.jpg',
#  'super_indep_door1071.jpg',
#  'super_indep_door1072.jpg',
#  'super_indep_door1073.jpg',
#  'super_indep_door1076.jpg',
#  'super_indep_door1077.jpg',
#  'super_indep_door1079.jpg',
#  'super_indep_door108.jpg',
#  'super_indep_door1080.jpg',
#  'super_indep_door1083.jpg',
#  'super_indep_door1084.jpg',
#  'super_indep_door1085.jpg',
#  'super_indep_door1086.jpg',
#  'super_indep_door1087.jpg',
#  'super_indep_door1089.jpg',
#  'super_indep_door1090.jpg',
#  'super_indep_door1093.jpg',
#  'super_indep_door1094.jpg',
#  'super_indep_door1095.jpg',
#  'super_indep_door1098.jpg',
#  'super_indep_door1100.jpg',
#  'super_indep_door1101.jpg',
#  'super_indep_door1102.jpg',
#  'super_indep_door1103.jpg',
#  'super_indep_door1106.jpg',
#  'super_indep_door1107.jpg',
#  'super_indep_door1108.jpg',
#  'super_indep_door1109.jpg',
#  'super_indep_door1113.jpg',
#  'super_indep_door1114.jpg',
#  'super_indep_door1118.jpg',
#  'super_indep_door1119.jpg',
#  'super_indep_door1123.jpg',
#  'super_indep_door1125.jpg',
#  'super_indep_door1126.jpg',
#  'super_indep_door1127.jpg',
#  'super_indep_door1128.jpg',
#  'super_indep_door1129.jpg',
#  'super_indep_door1130.jpg',
#  'super_indep_door1132.jpg',
#  'super_indep_door1133.jpg',
#  'super_indep_door1136.jpg',
#  'super_indep_door1139.jpg',
#  'super_indep_door114.jpg',
#  'super_indep_door1142.jpg',
#  'super_indep_door1144.jpg',
#  'super_indep_door1145.jpg',
#  'super_indep_door1147.jpg',
#  'super_indep_door1148.jpg',
#  'super_indep_door1151.jpg',
#  'super_indep_door1152.jpg',
#  'super_indep_door1153.jpg',
#  'super_indep_door1155.jpg',
#  'super_indep_door1156.jpg',
#  'super_indep_door1157.jpg',
#  'super_indep_door1158.jpg',
#  'super_indep_door1159.jpg',
#  'super_indep_door1161.jpg',
#  'super_indep_door1164.jpg',
#  'super_indep_door1165.jpg',
#  'super_indep_door1168.jpg',
#  'super_indep_door1170.jpg',
#  'super_indep_door1171.jpg',
#  'super_indep_door1172.jpg',
#  'super_indep_door1173.jpg',
#  'super_indep_door1174.jpg',
#  'super_indep_door1175.jpg',
#  'super_indep_door1177.jpg',
#  'super_indep_door1178.jpg',
#  'super_indep_door1179.jpg',
#  'super_indep_door118.jpg',
#  'super_indep_door1180.jpg',
#  'super_indep_door1181.jpg',
#  'super_indep_door1183.jpg',
#  'super_indep_door1184.jpg',
#  'super_indep_door1187.jpg',
#  'super_indep_door1188.jpg',
#  'super_indep_door1189.jpg',
#  'super_indep_door119.jpg',
#  'super_indep_door1190.jpg',
#  'super_indep_door1191.jpg',
#  'super_indep_door1192.jpg',
#  'super_indep_door1194.jpg',
#  'super_indep_door1195.jpg',
#  'super_indep_door1196.jpg',
#  'super_indep_door12.jpg',
#  'super_indep_door120.jpg',
#  'super_indep_door1200.jpg',
#  'super_indep_door121.jpg',
#  'super_indep_door122.jpg',
#  'super_indep_door123.jpg',
#  'super_indep_door126.jpg',
#  'super_indep_door127.jpg',
#  'super_indep_door128.jpg',
#  'super_indep_door13.jpg',
#  'super_indep_door131.jpg',
#  'super_indep_door132.jpg',
#  'super_indep_door133.jpg',
#  'super_indep_door135.jpg',
#  'super_indep_door136.jpg',
#  'super_indep_door137.jpg',
#  'super_indep_door138.jpg',
#  'super_indep_door139.jpg',
#  'super_indep_door14.jpg',
#  'super_indep_door140.jpg',
#  'super_indep_door141.jpg',
#  'super_indep_door144.jpg',
#  'super_indep_door148.jpg',
#  'super_indep_door15.jpg',
#  'super_indep_door150.jpg',
#  'super_indep_door151.jpg',
#  'super_indep_door153.jpg',
#  'super_indep_door16.jpg',
#  'super_indep_door160.jpg',
#  'super_indep_door161.jpg',
#  'super_indep_door162.jpg',
#  'super_indep_door164.jpg',
#  'super_indep_door165.jpg',
#  'super_indep_door166.jpg',
#  'super_indep_door167.jpg',
#  'super_indep_door168.jpg',
#  'super_indep_door169.jpg',
#  'super_indep_door170.jpg',
#  'super_indep_door172.jpg',
#  'super_indep_door173.jpg',
#  'super_indep_door175.jpg',
#  'super_indep_door176.jpg',
#  'super_indep_door177.jpg',
#  'super_indep_door178.jpg',
#  'super_indep_door179.jpg',
#  'super_indep_door18.jpg',
#  'super_indep_door180.jpg',
#  'super_indep_door181.jpg',
#  'super_indep_door182.jpg',
#  'super_indep_door183.jpg',
#  'super_indep_door184.jpg',
#  'super_indep_door186.jpg',
#  'super_indep_door189.jpg',
#  'super_indep_door19.jpg',
#  'super_indep_door191.jpg',
#  'super_indep_door194.jpg',
#  'super_indep_door195.jpg',
#  'super_indep_door197.jpg',
#  'super_indep_door2.jpg',
#  'super_indep_door201.jpg',
#  'super_indep_door202.jpg',
#  'super_indep_door203.jpg',
#  'super_indep_door205.jpg',
#  'super_indep_door207.jpg',
#  'super_indep_door208.jpg',
#  'super_indep_door209.jpg',
#  'super_indep_door210.jpg',
#  'super_indep_door211.jpg',
#  'super_indep_door213.jpg',
#  'super_indep_door214.jpg',
#  'super_indep_door216.jpg',
#  'super_indep_door217.jpg',
#  'super_indep_door218.jpg',
#  'super_indep_door219.jpg',
#  'super_indep_door22.jpg',
#  'super_indep_door221.jpg',
#  'super_indep_door222.jpg',
#  'super_indep_door224.jpg',
#  'super_indep_door228.jpg',
#  'super_indep_door229.jpg',
#  'super_indep_door23.jpg',
#  'super_indep_door232.jpg',
#  'super_indep_door234.jpg',
#  'super_indep_door235.jpg',
#  'super_indep_door237.jpg',
#  'super_indep_door238.jpg',
#  'super_indep_door240.jpg',
#  'super_indep_door243.jpg',
#  'super_indep_door244.jpg',
#  'super_indep_door245.jpg',
#  'super_indep_door247.jpg',
#  'super_indep_door248.jpg',
#  'super_indep_door249.jpg',
#  'super_indep_door251.jpg',
#  'super_indep_door254.jpg',
#  'super_indep_door258.jpg',
#  'super_indep_door259.jpg',
#  'super_indep_door26.jpg',
#  'super_indep_door266.jpg',
#  'super_indep_door269.jpg',
#  'super_indep_door27.jpg',
#  'super_indep_door272.jpg',
#  'super_indep_door274.jpg',
#  'super_indep_door275.jpg',
#  'super_indep_door277.jpg',
#  'super_indep_door278.jpg',
#  'super_indep_door279.jpg',
#  'super_indep_door280.jpg',
#  'super_indep_door282.jpg',
#  'super_indep_door283.jpg',
#  'super_indep_door285.jpg',
#  'super_indep_door287.jpg',
#  'super_indep_door289.jpg',
#  'super_indep_door29.jpg',
#  'super_indep_door291.jpg',
#  'super_indep_door297.jpg',
#  'super_indep_door298.jpg',
#  'super_indep_door299.jpg',
#  'super_indep_door3.jpg',
#  'super_indep_door301.jpg',
#  'super_indep_door305.jpg',
#  'super_indep_door306.jpg',
#  'super_indep_door307.jpg',
#  'super_indep_door309.jpg',
#  'super_indep_door31.jpg',
#  'super_indep_door310.jpg',
#  'super_indep_door311.jpg',
#  'super_indep_door313.jpg',
#  'super_indep_door315.jpg',
#  'super_indep_door316.jpg',
#  'super_indep_door317.jpg',
#  'super_indep_door319.jpg',
#  'super_indep_door32.jpg',
#  'super_indep_door320.jpg',
#  'super_indep_door321.jpg',
#  'super_indep_door324.jpg',
#  'super_indep_door329.jpg',
#  'super_indep_door33.jpg',
#  'super_indep_door332.jpg',
#  'super_indep_door333.jpg',
#  'super_indep_door334.jpg',
#  'super_indep_door337.jpg',
#  'super_indep_door34.jpg',
#  'super_indep_door340.jpg',
#  'super_indep_door341.jpg',
#  'super_indep_door343.jpg',
#  'super_indep_door344.jpg',
#  'super_indep_door345.jpg',
#  'super_indep_door347.jpg',
#  'super_indep_door349.jpg',
#  'super_indep_door35.jpg',
#  'super_indep_door351.jpg',
#  'super_indep_door352.jpg',
#  'super_indep_door353.jpg',
#  'super_indep_door355.jpg',
#  'super_indep_door356.jpg',
#  'super_indep_door357.jpg',
#  'super_indep_door358.jpg',
#  'super_indep_door359.jpg',
#  'super_indep_door36.jpg',
#  'super_indep_door360.jpg',
#  'super_indep_door361.jpg',
#  'super_indep_door362.jpg',
#  'super_indep_door366.jpg',
#  'super_indep_door368.jpg',
#  'super_indep_door369.jpg',
#  'super_indep_door370.jpg',
#  'super_indep_door371.jpg',
#  'super_indep_door372.jpg',
#  'super_indep_door374.jpg',
#  'super_indep_door375.jpg',
#  'super_indep_door376.jpg',
#  'super_indep_door378.jpg',
#  'super_indep_door38.jpg',
#  'super_indep_door380.jpg',
#  'super_indep_door381.jpg',
#  'super_indep_door384.jpg',
#  'super_indep_door386.jpg',
#  'super_indep_door387.jpg',
#  'super_indep_door388.jpg',
#  'super_indep_door389.jpg',
#  'super_indep_door390.jpg',
#  'super_indep_door393.jpg',
#  'super_indep_door395.jpg',
#  'super_indep_door396.jpg',
#  'super_indep_door397.jpg',
#  'super_indep_door398.jpg',
#  'super_indep_door399.jpg',
#  'super_indep_door40.jpg',
#  'super_indep_door402.jpg',
#  'super_indep_door403.jpg',
#  'super_indep_door404.jpg',
#  'super_indep_door406.jpg',
#  'super_indep_door409.jpg',
#  'super_indep_door410.jpg',
#  'super_indep_door413.jpg',
#  'super_indep_door414.jpg',
#  'super_indep_door415.jpg',
#  'super_indep_door416.jpg',
#  'super_indep_door417.jpg',
#  'super_indep_door419.jpg',
#  'super_indep_door42.jpg',
#  'super_indep_door420.jpg',
#  'super_indep_door421.jpg',
#  'super_indep_door422.jpg',
#  'super_indep_door423.jpg',
#  'super_indep_door424.jpg',
#  'super_indep_door425.jpg',
#  'super_indep_door426.jpg',
#  'super_indep_door428.jpg',
#  'super_indep_door429.jpg',
#  'super_indep_door43.jpg',
#  'super_indep_door433.jpg',
#  'super_indep_door434.jpg',
#  'super_indep_door436.jpg',
#  'super_indep_door437.jpg',
#  'super_indep_door439.jpg',
#  'super_indep_door44.jpg',
#  'super_indep_door441.jpg',
#  'super_indep_door442.jpg',
#  'super_indep_door443.jpg',
#  'super_indep_door444.jpg',
#  'super_indep_door445.jpg',
#  'super_indep_door447.jpg',
#  'super_indep_door448.jpg',
#  'super_indep_door451.jpg',
#  'super_indep_door454.jpg',
#  'super_indep_door455.jpg',
#  'super_indep_door456.jpg',
#  'super_indep_door458.jpg',
#  'super_indep_door459.jpg',
#  'super_indep_door464.jpg',
#  'super_indep_door465.jpg',
#  'super_indep_door467.jpg',
#  'super_indep_door468.jpg',
#  'super_indep_door470.jpg',
#  'super_indep_door471.jpg',
#  'super_indep_door473.jpg',
#  'super_indep_door475.jpg',
#  'super_indep_door476.jpg',
#  'super_indep_door48.jpg',
#  'super_indep_door481.jpg',
#  'super_indep_door483.jpg',
#  'super_indep_door486.jpg',
#  'super_indep_door489.jpg',
#  'super_indep_door49.jpg',
#  'super_indep_door490.jpg',
#  'super_indep_door492.jpg',
#  'super_indep_door493.jpg',
#  'super_indep_door494.jpg',
#  'super_indep_door495.jpg',
#  'super_indep_door496.jpg',
#  'super_indep_door498.jpg',
#  'super_indep_door50.jpg',
#  'super_indep_door501.jpg',
#  'super_indep_door502.jpg',
#  'super_indep_door504.jpg',
#  'super_indep_door505.jpg',
#  'super_indep_door506.jpg',
#  'super_indep_door507.jpg',
#  'super_indep_door51.jpg',
#  'super_indep_door512.jpg',
#  'super_indep_door513.jpg',
#  'super_indep_door514.jpg',
#  'super_indep_door515.jpg',
#  'super_indep_door516.jpg',
#  'super_indep_door52.jpg',
#  'super_indep_door520.jpg',
#  'super_indep_door523.jpg',
#  'super_indep_door524.jpg',
#  'super_indep_door525.jpg',
#  'super_indep_door527.jpg',
#  'super_indep_door528.jpg',
#  'super_indep_door529.jpg',
#  'super_indep_door530.jpg',
#  'super_indep_door531.jpg',
#  'super_indep_door533.jpg',
#  'super_indep_door534.jpg',
#  'super_indep_door535.jpg',
#  'super_indep_door537.jpg',
#  'super_indep_door538.jpg',
#  'super_indep_door539.jpg',
#  'super_indep_door54.jpg',
#  'super_indep_door544.jpg',
#  'super_indep_door545.jpg',
#  'super_indep_door547.jpg',
#  'super_indep_door548.jpg',
#  'super_indep_door55.jpg',
#  'super_indep_door551.jpg',
#  'super_indep_door552.jpg',
#  'super_indep_door553.jpg',
#  'super_indep_door554.jpg',
#  'super_indep_door556.jpg',
#  'super_indep_door559.jpg',
#  'super_indep_door56.jpg',
#  'super_indep_door560.jpg',
#  'super_indep_door561.jpg',
#  'super_indep_door562.jpg',
#  'super_indep_door565.jpg',
#  'super_indep_door567.jpg',
#  'super_indep_door568.jpg',
#  'super_indep_door569.jpg',
#  'super_indep_door570.jpg',
#  'super_indep_door571.jpg',
#  'super_indep_door572.jpg',
#  'super_indep_door575.jpg',
#  'super_indep_door578.jpg',
#  'super_indep_door579.jpg',
#  'super_indep_door58.jpg',
#  'super_indep_door585.jpg',
#  'super_indep_door587.jpg',
#  'super_indep_door589.jpg',
#  'super_indep_door59.jpg',
#  'super_indep_door590.jpg',
#  'super_indep_door591.jpg',
#  'super_indep_door595.jpg',
#  'super_indep_door599.jpg',
#  'super_indep_door6.jpg',
#  'super_indep_door60.jpg',
#  'super_indep_door600.jpg',
#  'super_indep_door601.jpg',
#  'super_indep_door602.jpg',
#  'super_indep_door603.jpg',
#  'super_indep_door604.jpg',
#  'super_indep_door605.jpg',
#  'super_indep_door607.jpg',
#  'super_indep_door609.jpg',
#  'super_indep_door61.jpg',
#  'super_indep_door610.jpg',
#  'super_indep_door611.jpg',
#  'super_indep_door612.jpg',
#  'super_indep_door616.jpg',
#  'super_indep_door619.jpg',
#  'super_indep_door62.jpg',
#  'super_indep_door620.jpg',
#  'super_indep_door621.jpg',
#  'super_indep_door622.jpg',
#  'super_indep_door623.jpg',
#  'super_indep_door624.jpg',
#  'super_indep_door625.jpg',
#  'super_indep_door627.jpg',
#  'super_indep_door630.jpg',
#  'super_indep_door631.jpg',
#  'super_indep_door632.jpg',
#  'super_indep_door633.jpg',
#  'super_indep_door634.jpg',
#  'super_indep_door636.jpg',
#  'super_indep_door637.jpg',
#  'super_indep_door638.jpg',
#  'super_indep_door640.jpg',
#  'super_indep_door642.jpg',
#  'super_indep_door647.jpg',
#  'super_indep_door649.jpg',
#  'super_indep_door65.jpg',
#  'super_indep_door650.jpg',
#  'super_indep_door653.jpg',
#  'super_indep_door654.jpg',
#  'super_indep_door655.jpg',
#  'super_indep_door657.jpg',
#  'super_indep_door658.jpg',
#  'super_indep_door661.jpg',
#  'super_indep_door662.jpg',
#  'super_indep_door664.jpg',
#  'super_indep_door665.jpg',
#  'super_indep_door666.jpg',
#  'super_indep_door668.jpg',
#  'super_indep_door669.jpg',
#  'super_indep_door67.jpg',
#  'super_indep_door675.jpg',
#  'super_indep_door676.jpg',
#  'super_indep_door678.jpg',
#  'super_indep_door679.jpg',
#  'super_indep_door68.jpg',
#  'super_indep_door681.jpg',
#  'super_indep_door682.jpg',
#  'super_indep_door683.jpg',
#  'super_indep_door684.jpg',
#  'super_indep_door685.jpg',
#  'super_indep_door687.jpg',
#  'super_indep_door688.jpg',
#  'super_indep_door69.jpg',
#  'super_indep_door692.jpg',
#  'super_indep_door693.jpg',
#  'super_indep_door694.jpg',
#  'super_indep_door695.jpg',
#  'super_indep_door699.jpg',
#  'super_indep_door700.jpg',
#  'super_indep_door702.jpg',
#  'super_indep_door704.jpg',
#  'super_indep_door705.jpg',
#  'super_indep_door707.jpg',
#  'super_indep_door708.jpg',
#  'super_indep_door709.jpg',
#  'super_indep_door71.jpg',
#  'super_indep_door714.jpg',
#  'super_indep_door715.jpg',
#  'super_indep_door716.jpg',
#  'super_indep_door718.jpg',
#  'super_indep_door719.jpg',
#  'super_indep_door720.jpg',
#  'super_indep_door721.jpg',
#  'super_indep_door722.jpg',
#  'super_indep_door723.jpg',
#  'super_indep_door725.jpg',
#  'super_indep_door726.jpg',
#  'super_indep_door729.jpg',
#  'super_indep_door73.jpg',
#  'super_indep_door731.jpg',
#  'super_indep_door732.jpg',
#  'super_indep_door733.jpg',
#  'super_indep_door734.jpg',
#  'super_indep_door735.jpg',
#  'super_indep_door737.jpg',
#  'super_indep_door738.jpg',
#  'super_indep_door739.jpg',
#  'super_indep_door74.jpg',
#  'super_indep_door743.jpg',
#  'super_indep_door744.jpg',
#  'super_indep_door745.jpg',
#  'super_indep_door746.jpg',
#  'super_indep_door749.jpg',
#  'super_indep_door75.jpg',
#  'super_indep_door753.jpg',
#  'super_indep_door755.jpg',
#  'super_indep_door758.jpg',
#  'super_indep_door76.jpg',
#  'super_indep_door760.jpg',
#  'super_indep_door761.jpg',
#  'super_indep_door763.jpg',
#  'super_indep_door765.jpg',
#  'super_indep_door766.jpg',
#  'super_indep_door767.jpg',
#  'super_indep_door769.jpg',
#  'super_indep_door77.jpg',
#  'super_indep_door773.jpg',
#  'super_indep_door777.jpg',
#  'super_indep_door778.jpg',
#  'super_indep_door780.jpg',
#  'super_indep_door781.jpg',
#  'super_indep_door783.jpg',
#  'super_indep_door786.jpg',
#  'super_indep_door79.jpg',
#  'super_indep_door790.jpg',
#  'super_indep_door792.jpg',
#  'super_indep_door793.jpg',
#  'super_indep_door794.jpg',
#  'super_indep_door795.jpg',
#  'super_indep_door796.jpg',
#  'super_indep_door798.jpg',
#  'super_indep_door801.jpg',
#  'super_indep_door802.jpg',
#  'super_indep_door803.jpg',
#  'super_indep_door806.jpg',
#  'super_indep_door808.jpg',
#  'super_indep_door81.jpg',
#  'super_indep_door810.jpg',
#  'super_indep_door811.jpg',
#  'super_indep_door812.jpg',
#  'super_indep_door815.jpg',
#  'super_indep_door816.jpg',
#  'super_indep_door817.jpg',
#  'super_indep_door818.jpg',
#  'super_indep_door819.jpg',
#  'super_indep_door82.jpg',
#  'super_indep_door821.jpg',
#  'super_indep_door822.jpg',
#  'super_indep_door823.jpg',
#  'super_indep_door824.jpg',
#  'super_indep_door825.jpg',
#  'super_indep_door826.jpg',
#  'super_indep_door827.jpg',
#  'super_indep_door83.jpg',
#  'super_indep_door831.jpg',
#  'super_indep_door832.jpg',
#  'super_indep_door833.jpg',
#  'super_indep_door835.jpg',
#  'super_indep_door836.jpg',
#  'super_indep_door837.jpg',
#  'super_indep_door839.jpg',
#  'super_indep_door84.jpg',
#  'super_indep_door842.jpg',
#  'super_indep_door844.jpg',
#  'super_indep_door845.jpg',
#  'super_indep_door846.jpg',
#  'super_indep_door847.jpg',
#  'super_indep_door848.jpg',
#  'super_indep_door849.jpg',
#  'super_indep_door85.jpg',
#  'super_indep_door851.jpg',
#  'super_indep_door852.jpg',
#  'super_indep_door855.jpg',
#  'super_indep_door856.jpg',
#  'super_indep_door857.jpg',
#  'super_indep_door859.jpg',
#  'super_indep_door862.jpg',
#  'super_indep_door864.jpg',
#  'super_indep_door865.jpg',
#  'super_indep_door866.jpg',
#  'super_indep_door868.jpg',
#  'super_indep_door869.jpg',
#  'super_indep_door870.jpg',
#  'super_indep_door871.jpg',
#  'super_indep_door872.jpg',
#  'super_indep_door873.jpg',
#  'super_indep_door875.jpg',
#  'super_indep_door876.jpg',
#  'super_indep_door877.jpg',
#  'super_indep_door878.jpg',
#  'super_indep_door879.jpg',
#  'super_indep_door881.jpg',
#  'super_indep_door884.jpg',
#  'super_indep_door885.jpg',
#  'super_indep_door887.jpg',
#  'super_indep_door888.jpg',
#  'super_indep_door889.jpg',
#  'super_indep_door890.jpg',
#  'super_indep_door892.jpg',
#  'super_indep_door893.jpg',
#  'super_indep_door895.jpg',
#  'super_indep_door896.jpg',
#  'super_indep_door898.jpg',
#  'super_indep_door899.jpg',
#  'super_indep_door90.jpg',
#  'super_indep_door901.jpg',
#  'super_indep_door905.jpg',
#  'super_indep_door906.jpg',
#  'super_indep_door907.jpg',
#  'super_indep_door912.jpg',
#  'super_indep_door916.jpg',
#  'super_indep_door917.jpg',
#  'super_indep_door918.jpg',
#  'super_indep_door920.jpg',
#  'super_indep_door923.jpg',
#  'super_indep_door924.jpg',
#  'super_indep_door925.jpg',
#  'super_indep_door926.jpg',
#  'super_indep_door93.jpg',
#  'super_indep_door932.jpg',
#  'super_indep_door935.jpg',
#  'super_indep_door936.jpg',
#  'super_indep_door937.jpg',
#  'super_indep_door939.jpg',
#  'super_indep_door94.jpg',
#  'super_indep_door943.jpg',
#  'super_indep_door944.jpg',
#  'super_indep_door945.jpg',
#  'super_indep_door947.jpg',
#  'super_indep_door948.jpg',
#  'super_indep_door949.jpg',
#  'super_indep_door95.jpg',
#  'super_indep_door950.jpg',
#  'super_indep_door952.jpg',
#  'super_indep_door953.jpg',
#  'super_indep_door955.jpg',
#  'super_indep_door957.jpg',
#  'super_indep_door959.jpg',
#  'super_indep_door96.jpg',
#  'super_indep_door961.jpg',
#  'super_indep_door962.jpg',
#  'super_indep_door963.jpg',
#  'super_indep_door967.jpg',
#  'super_indep_door969.jpg',
#  'super_indep_door97.jpg',
#  'super_indep_door970.jpg',
#  'super_indep_door971.jpg',
#  'super_indep_door972.jpg',
#  'super_indep_door973.jpg',
#  'super_indep_door974.jpg',
#  'super_indep_door975.jpg',
#  'super_indep_door978.jpg',
#  'super_indep_door979.jpg',
#  'super_indep_door98.jpg',
#  'super_indep_door980.jpg',
#  'super_indep_door981.jpg',
#  'super_indep_door983.jpg',
#  'super_indep_door984.jpg',
#  'super_indep_door985.jpg',
#  'super_indep_door986.jpg',
#  'super_indep_door988.jpg',
#  'super_indep_door991.jpg',
#  'super_indep_door993.jpg',
#  'super_indep_door995.jpg',
#  'super_indep_door997.jpg',
#  'super_indep_door998.jpg']

# %%
validation_list = random.sample(not_train_list, int(len(not_train_list)/2))
validation_list
# Out:
# ['super_indep_door509.jpg',
#  'super_indep_door614.jpg',
#  'super_indep_door580.jpg',
#  'super_indep_door487.jpg',
#  'super_indep_door928.jpg',
#  'super_indep_door1091.jpg',
#  'super_indep_door588.jpg',
#  'super_indep_door500.jpg',
#  'super_indep_door482.jpg',
#  'super_indep_door1197.jpg',
#  'super_indep_door853.jpg',
#  'super_indep_door613.jpg',
#  'super_indep_door829.jpg',
#  'super_indep_door933.jpg',
#  'super_indep_door273.jpg',
#  'super_indep_door385.jpg',
#  'super_indep_door1146.jpg',
#  'super_indep_door260.jpg',
#  'super_indep_door190.jpg',
#  'super_indep_door449.jpg',
#  'super_indep_door373.jpg',
#  'super_indep_door125.jpg',
#  'super_indep_door20.jpg',
#  'super_indep_door597.jpg',
#  'super_indep_door284.jpg',
#  'super_indep_door646.jpg',
#  'super_indep_door909.jpg',
#  'super_indep_door804.jpg',
#  'super_indep_door779.jpg',
#  'super_indep_door134.jpg',
#  'super_indep_door147.jpg',
#  'super_indep_door1032.jpg',
#  'super_indep_door608.jpg',
#  'super_indep_door64.jpg',
#  'super_indep_door641.jpg',
#  'super_indep_door215.jpg',
#  'super_indep_door430.jpg',
#  'super_indep_door938.jpg',
#  'super_indep_door227.jpg',
#  'super_indep_door782.jpg',
#  'super_indep_door484.jpg',
#  'super_indep_door908.jpg',
#  'super_indep_door1138.jpg',
#  'super_indep_door159.jpg',
#  'super_indep_door1082.jpg',
#  'super_indep_door192.jpg',
#  'super_indep_door1199.jpg',
#  'super_indep_door365.jpg',
#  'super_indep_door882.jpg',
#  'super_indep_door86.jpg',
#  'super_indep_door336.jpg',
#  'super_indep_door1120.jpg',
#  'super_indep_door469.jpg',
#  'super_indep_door130.jpg',
#  'super_indep_door854.jpg',
#  'super_indep_door841.jpg',
#  'super_indep_door187.jpg',
#  'super_indep_door740.jpg',
#  'super_indep_door860.jpg',
#  'super_indep_door558.jpg',
#  'super_indep_door1117.jpg',
#  'super_indep_door1078.jpg',
#  'super_indep_door542.jpg',
#  'super_indep_door265.jpg',
#  'super_indep_door391.jpg',
#  'super_indep_door257.jpg',
#  'super_indep_door460.jpg',
#  'super_indep_door691.jpg',
#  'super_indep_door323.jpg',
#  'super_indep_door644.jpg',
#  'super_indep_door497.jpg',
#  'super_indep_door103.jpg',
#  'super_indep_door911.jpg',
#  'super_indep_door996.jpg',
#  'super_indep_door1124.jpg',
#  'super_indep_door966.jpg',
#  'super_indep_door577.jpg',
#  'super_indep_door1140.jpg',
#  'super_indep_door990.jpg',
#  'super_indep_door342.jpg',
#  'super_indep_door659.jpg',
#  'super_indep_door1112.jpg',
#  'super_indep_door813.jpg',
#  'super_indep_door592.jpg',
#  'super_indep_door789.jpg',
#  'super_indep_door367.jpg',
#  'super_indep_door1097.jpg',
#  'super_indep_door799.jpg',
#  'super_indep_door776.jpg',
#  'super_indep_door919.jpg',
#  'super_indep_door660.jpg',
#  'super_indep_door9.jpg',
#  'super_indep_door163.jpg',
#  'super_indep_door37.jpg',
#  'super_indep_door754.jpg',
#  'super_indep_door267.jpg',
#  'super_indep_door576.jpg',
#  'super_indep_door1121.jpg',
#  'super_indep_door546.jpg',
#  'super_indep_door88.jpg',
#  'super_indep_door155.jpg',
#  'super_indep_door294.jpg',
#  'super_indep_door1099.jpg',
#  'super_indep_door809.jpg',
#  'super_indep_door5.jpg',
#  'super_indep_door532.jpg',
#  'super_indep_door914.jpg',
#  'super_indep_door648.jpg',
#  'super_indep_door838.jpg',
#  'super_indep_door28.jpg',
#  'super_indep_door522.jpg',
#  'super_indep_door768.jpg',
#  'super_indep_door645.jpg',
#  'super_indep_door1050.jpg',
#  'super_indep_door904.jpg',
#  'super_indep_door427.jpg',
#  'super_indep_door711.jpg',
#  'super_indep_door820.jpg',
#  'super_indep_door741.jpg',
#  'super_indep_door286.jpg',
#  'super_indep_door510.jpg',
#  'super_indep_door1.jpg',
#  'super_indep_door326.jpg',
#  'super_indep_door225.jpg',
#  'super_indep_door976.jpg',
#  'super_indep_door25.jpg',
#  'super_indep_door710.jpg',
#  'super_indep_door1131.jpg',
#  'super_indep_door987.jpg',
#  'super_indep_door759.jpg',
#  'super_indep_door446.jpg',
#  'super_indep_door112.jpg',
#  'super_indep_door511.jpg',
#  'super_indep_door1182.jpg',
#  'super_indep_door296.jpg',
#  'super_indep_door840.jpg',
#  'super_indep_door1111.jpg',
#  'super_indep_door24.jpg',
#  'super_indep_door517.jpg',
#  'super_indep_door593.jpg',
#  'super_indep_door922.jpg',
#  'super_indep_door21.jpg',
#  'super_indep_door30.jpg',
#  'super_indep_door1037.jpg',
#  'super_indep_door1042.jpg',
#  'super_indep_door261.jpg',
#  'super_indep_door643.jpg',
#  'super_indep_door1105.jpg',
#  'super_indep_door586.jpg',
#  'super_indep_door674.jpg',
#  'super_indep_door1135.jpg',
#  'super_indep_door940.jpg',
#  'super_indep_door146.jpg',
#  'super_indep_door563.jpg',
#  'super_indep_door233.jpg',
#  'super_indep_door1047.jpg',
#  'super_indep_door956.jpg',
#  'super_indep_door304.jpg',
#  'super_indep_door596.jpg',
#  'super_indep_door814.jpg',
#  'super_indep_door346.jpg',
#  'super_indep_door902.jpg',
#  'super_indep_door805.jpg',
#  'super_indep_door474.jpg',
#  'super_indep_door521.jpg',
#  'super_indep_door1122.jpg',
#  'super_indep_door1046.jpg',
#  'super_indep_door271.jpg',
#  'super_indep_door989.jpg',
#  'super_indep_door303.jpg',
#  'super_indep_door1000.jpg',
#  'super_indep_door171.jpg',
#  'super_indep_door1025.jpg',
#  'super_indep_door785.jpg',
#  'super_indep_door185.jpg',
#  'super_indep_door1154.jpg',
#  'super_indep_door331.jpg',
#  'super_indep_door555.jpg',
#  'super_indep_door770.jpg',
#  'super_indep_door508.jpg',
#  'super_indep_door453.jpg',
#  'super_indep_door742.jpg',
#  'super_indep_door281.jpg',
#  'super_indep_door686.jpg',
#  'super_indep_door354.jpg',
#  'super_indep_door915.jpg',
#  'super_indep_door293.jpg',
#  'super_indep_door145.jpg',
#  'super_indep_door418.jpg',
#  'super_indep_door1176.jpg',
#  'super_indep_door350.jpg',
#  'super_indep_door757.jpg',
#  'super_indep_door874.jpg',
#  'super_indep_door206.jpg',
#  'super_indep_door584.jpg',
#  'super_indep_door519.jpg',
#  'super_indep_door174.jpg',
#  'super_indep_door70.jpg',
#  'super_indep_door828.jpg',
#  'super_indep_door142.jpg',
#  'super_indep_door747.jpg',
#  'super_indep_door104.jpg',
#  'super_indep_door143.jpg',
#  'super_indep_door392.jpg',
#  'super_indep_door1022.jpg',
#  'super_indep_door717.jpg',
#  'super_indep_door461.jpg',
#  'super_indep_door628.jpg',
#  'super_indep_door479.jpg',
#  'super_indep_door450.jpg',
#  'super_indep_door377.jpg',
#  'super_indep_door680.jpg',
#  'super_indep_door302.jpg',
#  'super_indep_door405.jpg',
#  'super_indep_door921.jpg',
#  'super_indep_door784.jpg',
#  'super_indep_door617.jpg',
#  'super_indep_door775.jpg',
#  'super_indep_door115.jpg',
#  'super_indep_door129.jpg',
#  'super_indep_door968.jpg',
#  'super_indep_door566.jpg',
#  'super_indep_door212.jpg',
#  'super_indep_door574.jpg',
#  'super_indep_door236.jpg',
#  'super_indep_door964.jpg',
#  'super_indep_door1116.jpg',
#  'super_indep_door300.jpg',
#  'super_indep_door57.jpg',
#  'super_indep_door149.jpg',
#  'super_indep_door1074.jpg',
#  'super_indep_door1143.jpg',
#  'super_indep_door594.jpg',
#  'super_indep_door960.jpg',
#  'super_indep_door80.jpg',
#  'super_indep_door462.jpg',
#  'super_indep_door673.jpg',
#  'super_indep_door930.jpg',
#  'super_indep_door764.jpg',
#  'super_indep_door256.jpg']

# %%
test_list = [x for x in not_train_list if x not in validation_list]
test_list
# Out:
# ['super_indep_door1039.jpg',
#  'super_indep_door629.jpg',
#  'super_indep_door157.jpg',
#  'super_indep_door606.jpg',
#  'super_indep_door1185.jpg',
#  'super_indep_door394.jpg',
#  'super_indep_door934.jpg',
#  'super_indep_door1070.jpg',
#  'super_indep_door288.jpg',
#  'super_indep_door858.jpg',
#  'super_indep_door1092.jpg',
#  'super_indep_door635.jpg',
#  'super_indep_door1056.jpg',
#  'super_indep_door199.jpg',
#  'super_indep_door843.jpg',
#  'super_indep_door696.jpg',
#  'super_indep_door672.jpg',
#  'super_indep_door728.jpg',
#  'super_indep_door772.jpg',
#  'super_indep_door241.jpg',
#  'super_indep_door478.jpg',
#  'super_indep_door239.jpg',
#  'super_indep_door543.jpg',
#  'super_indep_door46.jpg',
#  'super_indep_door431.jpg',
#  'super_indep_door242.jpg',
#  'super_indep_door1011.jpg',
#  'super_indep_door348.jpg',
#  'super_indep_door400.jpg',
#  'super_indep_door690.jpg',
#  'super_indep_door363.jpg',
#  'super_indep_door91.jpg',
#  'super_indep_door671.jpg',
#  'super_indep_door752.jpg',
#  'super_indep_door1115.jpg',
#  'super_indep_door325.jpg',
#  'super_indep_door308.jpg',
#  'super_indep_door154.jpg',
#  'super_indep_door503.jpg',
#  'super_indep_door41.jpg',
#  'super_indep_door263.jpg',
#  'super_indep_door1104.jpg',
#  'super_indep_door66.jpg',
#  'super_indep_door1186.jpg',
#  'super_indep_door1002.jpg',
#  'super_indep_door335.jpg',
#  'super_indep_door891.jpg',
#  'super_indep_door230.jpg',
#  'super_indep_door787.jpg',
#  'super_indep_door290.jpg',
#  'super_indep_door903.jpg',
#  'super_indep_door364.jpg',
#  'super_indep_door900.jpg',
#  'super_indep_door292.jpg',
#  'super_indep_door910.jpg',
#  'super_indep_door598.jpg',
#  'super_indep_door276.jpg',
#  'super_indep_door7.jpg',
#  'super_indep_door1198.jpg',
#  'super_indep_door941.jpg',
#  'super_indep_door667.jpg',
#  'super_indep_door762.jpg',
#  'super_indep_door883.jpg',
#  'super_indep_door466.jpg',
#  'super_indep_door412.jpg',
#  'super_indep_door999.jpg',
#  'super_indep_door330.jpg',
#  'super_indep_door200.jpg',
#  'super_indep_door549.jpg',
#  'super_indep_door110.jpg',
#  'super_indep_door1057.jpg',
#  'super_indep_door800.jpg',
#  'super_indep_door886.jpg',
#  'super_indep_door117.jpg',
#  'super_indep_door894.jpg',
#  'super_indep_door312.jpg',
#  'super_indep_door39.jpg',
#  'super_indep_door488.jpg',
#  'super_indep_door252.jpg',
#  'super_indep_door338.jpg',
#  'super_indep_door942.jpg',
#  'super_indep_door1088.jpg',
#  'super_indep_door698.jpg',
#  'super_indep_door440.jpg',
#  'super_indep_door1150.jpg',
#  'super_indep_door1007.jpg',
#  'super_indep_door253.jpg',
#  'super_indep_door92.jpg',
#  'super_indep_door573.jpg',
#  'super_indep_door929.jpg',
#  'super_indep_door408.jpg',
#  'super_indep_door850.jpg',
#  'super_indep_door656.jpg',
#  'super_indep_door791.jpg',
#  'super_indep_door982.jpg',
#  'super_indep_door1166.jpg',
#  'super_indep_door830.jpg',
#  'super_indep_door701.jpg',
#  'super_indep_door540.jpg',
#  'super_indep_door1163.jpg',
#  'super_indep_door557.jpg',
#  'super_indep_door152.jpg',
#  'super_indep_door788.jpg',
#  'super_indep_door109.jpg',
#  'super_indep_door318.jpg',
#  'super_indep_door651.jpg',
#  'super_indep_door485.jpg',
#  'super_indep_door435.jpg',
#  'super_indep_door379.jpg',
#  'super_indep_door401.jpg',
#  'super_indep_door1134.jpg',
#  'super_indep_door111.jpg',
#  'super_indep_door931.jpg',
#  'super_indep_door78.jpg',
#  'super_indep_door11.jpg',
#  'super_indep_door156.jpg',
#  'super_indep_door861.jpg',
#  'super_indep_door954.jpg',
#  'super_indep_door198.jpg',
#  'super_indep_door951.jpg',
#  'super_indep_door223.jpg',
#  'super_indep_door262.jpg',
#  'super_indep_door913.jpg',
#  'super_indep_door583.jpg',
#  'super_indep_door958.jpg',
#  'super_indep_door1009.jpg',
#  'super_indep_door1063.jpg',
#  'super_indep_door53.jpg',
#  'super_indep_door582.jpg',
#  'super_indep_door8.jpg',
#  'super_indep_door771.jpg',
#  'super_indep_door295.jpg',
#  'super_indep_door1141.jpg',
#  'super_indep_door4.jpg',
#  'super_indep_door751.jpg',
#  'super_indep_door750.jpg',
#  'super_indep_door89.jpg',
#  'super_indep_door863.jpg',
#  'super_indep_door72.jpg',
#  'super_indep_door697.jpg',
#  'super_indep_door196.jpg',
#  'super_indep_door491.jpg',
#  'super_indep_door581.jpg',
#  'super_indep_door226.jpg',
#  'super_indep_door927.jpg',
#  'super_indep_door618.jpg',
#  'super_indep_door727.jpg',
#  'super_indep_door1096.jpg',
#  'super_indep_door994.jpg',
#  'super_indep_door965.jpg',
#  'super_indep_door255.jpg',
#  'super_indep_door339.jpg',
#  'super_indep_door477.jpg',
#  'super_indep_door1044.jpg',
#  'super_indep_door480.jpg',
#  'super_indep_door897.jpg',
#  'super_indep_door1162.jpg',
#  'super_indep_door724.jpg',
#  'super_indep_door264.jpg',
#  'super_indep_door689.jpg',
#  'super_indep_door615.jpg',
#  'super_indep_door526.jpg',
#  'super_indep_door1024.jpg',
#  'super_indep_door383.jpg',
#  'super_indep_door706.jpg',
#  'super_indep_door322.jpg',
#  'super_indep_door1012.jpg',
#  'super_indep_door328.jpg',
#  'super_indep_door1169.jpg',
#  'super_indep_door639.jpg',
#  'super_indep_door116.jpg',
#  'super_indep_door1081.jpg',
#  'super_indep_door677.jpg',
#  'super_indep_door756.jpg',
#  'super_indep_door730.jpg',
#  'super_indep_door880.jpg',
#  'super_indep_door652.jpg',
#  'super_indep_door452.jpg',
#  'super_indep_door231.jpg',
#  'super_indep_door63.jpg',
#  'super_indep_door1193.jpg',
#  'super_indep_door472.jpg',
#  'super_indep_door411.jpg',
#  'super_indep_door1014.jpg',
#  'super_indep_door712.jpg',
#  'super_indep_door188.jpg',
#  'super_indep_door158.jpg',
#  'super_indep_door946.jpg',
#  'super_indep_door1075.jpg',
#  'super_indep_door807.jpg',
#  'super_indep_door774.jpg',
#  'super_indep_door541.jpg',
#  'super_indep_door113.jpg',
#  'super_indep_door1061.jpg',
#  'super_indep_door1110.jpg',
#  'super_indep_door670.jpg',
#  'super_indep_door748.jpg',
#  'super_indep_door10.jpg',
#  'super_indep_door626.jpg',
#  'super_indep_door564.jpg',
#  'super_indep_door407.jpg',
#  'super_indep_door992.jpg',
#  'super_indep_door1149.jpg',
#  'super_indep_door1040.jpg',
#  'super_indep_door1137.jpg',
#  'super_indep_door246.jpg',
#  'super_indep_door432.jpg',
#  'super_indep_door703.jpg',
#  'super_indep_door268.jpg',
#  'super_indep_door87.jpg',
#  'super_indep_door834.jpg',
#  'super_indep_door736.jpg',
#  'super_indep_door204.jpg',
#  'super_indep_door250.jpg',
#  'super_indep_door713.jpg',
#  'super_indep_door17.jpg',
#  'super_indep_door797.jpg',
#  'super_indep_door499.jpg',
#  'super_indep_door314.jpg',
#  'super_indep_door47.jpg',
#  'super_indep_door457.jpg',
#  'super_indep_door327.jpg',
#  'super_indep_door438.jpg',
#  'super_indep_door518.jpg',
#  'super_indep_door45.jpg',
#  'super_indep_door124.jpg',
#  'super_indep_door382.jpg',
#  'super_indep_door1023.jpg',
#  'super_indep_door1160.jpg',
#  'super_indep_door867.jpg',
#  'super_indep_door270.jpg',
#  'super_indep_door550.jpg',
#  'super_indep_door193.jpg',
#  'super_indep_door99.jpg',
#  'super_indep_door977.jpg',
#  'super_indep_door220.jpg',
#  'super_indep_door463.jpg',
#  'super_indep_door536.jpg',
#  'super_indep_door1167.jpg',
#  'super_indep_door663.jpg']

# %%
for file in tqdm(test_list):
    image = Image.open("D:/song_image/indep_door/" + file)
    image.save("D:/image/test/indep_door/" + file)
    
for file in tqdm(validation_list):
    image = Image.open("D:/song_image/indep_door/" + file)
    image.save("D:/image/validation/indep_door/" + file)
    
for file in tqdm(train_list):
    image = Image.open("D:/song_image/indep_door/" + file)
    image.save("D:/image/train/indep_door/" + file)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 240/240 [00:00<00:00, 266.92it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 240/240 [00:00<00:00, 345.06it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 720/720 [00:02<00:00, 308.76it/s]
